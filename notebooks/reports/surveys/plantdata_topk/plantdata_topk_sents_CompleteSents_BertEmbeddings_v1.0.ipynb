# %%
from torch import cuda
import torch.nn as nn
import transformers
from transformers import DistilBertTokenizer, DistilBertModel
import warnings
import torch
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm

# %%
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
bert = DistilBertModel.from_pretrained('distilbert-base-uncased')

# %%
class BERT(nn.Module):
    def __init__(self, bert):
        
        super(BERT, self).__init__()
        
        self.bert = bert
        self.dropout = nn.Dropout(0.1)
        self.relu =  nn.ReLU()
        self.fc1 = nn.Linear(768, 512)
        self.fc2 = nn.Linear(512, 2)

    def forward(self, **kwargs):

        cls_hs = self.bert(**kwargs)
        hidden_state = cls_hs[0]
        pooler = hidden_state[:, 0]
        
        x = self.fc1(pooler)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return self.fc1(pooler)

# %%
model = BERT(bert)

try:
    model_save_name = 'saved_weights_BERT_description_classifier.pt'
    path = "../../../models/saved_weights/" + model_save_name
    model.load_state_dict(torch.load(path, 
                                        map_location=torch.device('cpu')))
    print('Local Success')
except:
    raise ValueError

model = model.to(device)
# Out:
# Local Success

# %%
def embeddings(span, model, pred_values=False, truncation=True, threshold=False):
    with torch.no_grad():
        inputs = tokenizer(span, return_tensors="pt", truncation=truncation)
        return model(**inputs)

def similarity(GroundTruth, Prediction):
    GroundTruth = embeddings(GroundTruth, model=model)
    Prediction = embeddings(Prediction, model=model)
    return cosine_similarity(GroundTruth, Prediction)[0][0]

# %%
root = "../../../data/interim/"

df_andrei = pd.read_csv(root + "DF_Andrei.csv", header=[0, 1], index_col=0) 
df_pierre = pd.read_csv(root + "DF_Pierre.csv", header=[0, 1], index_col=0) 
df_daniel = pd.read_csv(root + "DF_Daniel.csv", header=[0, 1], index_col=0)

# %% [markdown]
# ### Load Sentences

# %%
root = "../../../data/processed/"
sentences_all = {}

f = open(F"{root}Sentences_Pierre.pkl", 'rb')
sentences_Pierre = pickle.load(f)
sentences_all |= sentences_Pierre 

f = open(F"{root}Sentences_Andrei.pkl", 'rb')
sentences_Andrei = pickle.load(f)
sentences_all |= sentences_Andrei 

f = open(F"{root}Sentences_Kissling.pkl", 'rb')
sentences_Kissling = pickle.load(f)
sentences_all |= sentences_Kissling 

# Drop duplicates
for species, sentences in sentences_all.items():
    sentences_all[species] = list(set(sentences))

# %% [markdown]
# ### Match Data

# %%
# k= 5
# google_form_lst = []

# for idx, (species, sentences) in enumerate(tqdm(sentences_all.items(), leave=True, desc="Species")):

#     # if idx > 1:
#     #     continue
#     if species != 'Dypsis thiryana':
#         continue
    
#     df_select = [df_andrei, df_pierre, df_daniel]
#     if species in df_andrei.index:
#         df_select = df_select[0]
#     elif species in df_pierre.index:
#         df_select = df_select[1]
#     elif species in df_daniel.index:
#         df_select = df_select[2]
#     else:
#         raise ValueError

#     for gt_main_trait in df_select.columns.get_level_values(0).unique():
#         if gt_main_trait == 'Measurement':
#             df_subset = df_select[df_select.index == species][gt_main_trait]
#             # Not really efficient, use PD?
    
#             subtraits = list(df_subset.columns)
#             values = df_subset.values[0]
#             for sub_trait, value in zip(subtraits, values):

#                 df_sent  = F"{sub_trait}: {value}"

#                 top_list = []

#                 for sentence in tqdm(sentences, leave=False, desc="Sentences"):
#                     gt_sim = similarity(df_sent, sentence)
#                     if not gt_sim:
#                         sentence = np.NaN
#                     top_list.append((gt_sim, sentence))

#                 top_list.sort(reverse=True)
#                 # top_k_list = [sentence for (_, sentence) in top_list[0:k]]
#                 gt_sim_sum = 0
#                 top_k_list = []
#                 for (gt_sim, sentence) in top_list[0:k]:
#                     gt_sim_sum += gt_sim
#                     top_k_list.append(sentence)

#                 # Non Nan for normalization
#                 None_NaNs = k - top_k_list.count(np.NaN) + 2e-26 # Float division               

#                 google_form_lst.append((species, gt_main_trait, sub_trait, [df_sent], *top_k_list, df_sent.capitalize(), gt_sim_sum/None_NaNs))
#         else:
#             df_subset = df_select[df_select.index == species][gt_main_trait]
#             present_traits = df_subset.loc[:, df_subset.any()].columns.values
            
#             # df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)
            
#             # NEW VERSION SINGLE TRAIT
#             size = present_traits.shape
#             if not size[0]:
#                 continue
#             df_sent = F"{gt_main_trait} {present_traits[0]}"
#             # print(df_sent)

#             top_list = []

#             for sentence in tqdm(sentences, leave=False, desc="Sentences"):
#                 gt_sim = similarity(df_sent, sentence)

#                 if not gt_sim:
#                     sentence = np.NaN

#                 # print(gt_sim, sentence, df_sent)
#                 top_list.append((gt_sim, sentence))

#             top_list.sort(reverse=True)

#             # print(top_list)

#             # top_k_list = [sentence for (_, sentence) in top_list[0:k]]
#             gt_sim_sum = 0
#             top_k_list = []
#             for (gt_sim, sentence) in top_list[0:k]:
#                 gt_sim_sum += gt_sim
#                 top_k_list.append(sentence)

#             # Non Nan for normalization
#             None_NaNs = k - top_k_list.count(np.NaN) + 2e-26 # Float division       

#             # GoogleSent = gt_main_trait + ': ' + ', '.join(list(present_traits))
#             GoogleSent = F"{gt_main_trait}: {present_traits[0]}"
#             google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list, GoogleSent.capitalize(), gt_sim_sum/None_NaNs))
# Out:
# Species: 100%|██████████| 647/647 [00:12<00:00, 50.31it/s]

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5', 'GoogleSentence', 'Sim Sum'])
df_google
# Out:
#             Species                Main Trait  \
# 0   Dypsis thiryana  Fruit Colour Description
# 1   Dypsis thiryana              Fruit Colour
# 2   Dypsis thiryana                     Crown
# 3   Dypsis thiryana                Fruit Size
# 4   Dypsis thiryana               Fruit Shape
# 5   Dypsis thiryana           Conspicuousness
# 6   Dypsis thiryana               Measurement
# 7   Dypsis thiryana               Measurement
# 8   Dypsis thiryana               Measurement
# 9   Dypsis thiryana               Measurement
# 10  Dypsis thiryana               Measurement
# 11  Dypsis thiryana               Measurement
# 12  Dypsis thiryana               Measurement
# 13  Dypsis thiryana               Measurement
# 14  Dypsis thiryana               Measurement
# 15  Dypsis thiryana               Measurement
# 16  Dypsis thiryana               Measurement
# 17  Dypsis thiryana               Measurement
#
#                            GT Main Trait  \
# 0               Fruit Colour Description
# 1                           Fruit Colour
# 2                                  Crown
# 3                             Fruit Size
# 4                            Fruit Shape
# 5                        Conspicuousness
# 6          Maximum Stem Height in Meters
# 7   Maximum Stem Diameter in Centimeters
# 8                    Maximum Leaf Number
# 9    Maximum Leaf Blade Length in Meters
# 10       Maximum Rachis Length in Meters
# 11      Maximum Petiole Length in Meters
# 12   Average Fruit Length in Centimeters
# 13   Minimum Fruit Length in Centimeters
# 14   Maximum Fruit Length in Centimeters
# 15    Average Fruit Width in Centimeters
# 16    Minimum Fruit Width in Centimeters
# 17    Maximum Fruit Width in Centimeters
#
#                                   GT Sub Traits  \
# 0                                         [red]
# 1                                         [red]
# 2                                 [understorey]
# 3                                       [small]
# 4                                     [globose]
# 5                                 [conspicuous]
# 6          [Maximum Stem Height in Meters: 1.0]
# 7   [Maximum Stem Diameter in Centimeters: 0.6]
# 8                   [Maximum Leaf Number: 10.0]
# 9   [Maximum Leaf Blade Length in Meters: 0.48]
# 10       [Maximum Rachis Length in Meters: 0.3]
# 11      [Maximum Petiole Length in Meters: 0.2]
# 12   [Average Fruit Length in Centimeters: 1.0]
# 13   [Minimum Fruit Length in Centimeters: 0.9]
# 14   [Maximum Fruit Length in Centimeters: 1.1]
# 15    [Average Fruit Width in Centimeters: 0.4]
# 16    [Minimum Fruit Width in Centimeters: 0.3]
# 17    [Maximum Fruit Width in Centimeters: 0.5]
#
#                                                     1  \
# 0                                    Rank: FLOWERING.
# 1                                    Rank: FLOWERING.
# 2                                    Rank: FLOWERING.
# 3                   Clustering palm, in tufts of 2-4.
# 4                   Clustering palm, in tufts of 2-4.
# 5                                       Groundcovers.
# 6   This is an extremely thin palm with extremely ...
# 7          Leaves. pinnate with two or more leaflets.
# 8          Leaves. pinnate with two or more leaflets.
# 9          Leaves. pinnate with two or more leaflets.
# 10  This is an extremely thin palm with extremely ...
# 11  This is an extremely thin palm with extremely ...
# 12         Leaves. pinnate with two or more leaflets.
# 13         Leaves. pinnate with two or more leaflets.
# 14         Leaves. pinnate with two or more leaflets.
# 15         Leaves. pinnate with two or more leaflets.
# 16         Leaves. pinnate with two or more leaflets.
# 17         Leaves. pinnate with two or more leaflets.
#
#                                                     2  \
# 0                                     Rank: SEEDLING.
# 1          Leaves. pinnate with two or more leaflets.
# 2                                       Groundcovers.
# 3          Leaves. pinnate with two or more leaflets.
# 4                    Clustering palm in tufts of 2-4.
# 5                                    Rank: FLOWERING.
# 6                                     Rank: SEEDLING.
# 7   Pinnate leaves, leaflets unequally jagged and ...
# 8                                    Rank: FLOWERING.
# 9   Pinnate leaves, leaflets unequally jagged and ...
# 10                                    Rank: SEEDLING.
# 11                  Clustering palm, in tufts of 2-4.
# 12  Pinnate leaves, leaflets unequally jagged and ...
# 13  Pinnate leaves, leaflets unequally jagged and ...
# 14  Pinnate leaves, leaflets unequally jagged and ...
# 15                  Clustering palm, in tufts of 2-4.
# 16  Pinnate leaves, leaflets unequally jagged and ...
# 17  Pinnate leaves, leaflets unequally jagged and ...
#
#                                                     3  \
# 0   The from is extremely thin, almost less than a...
# 1                   Clustering palm, in tufts of 2-4.
# 2                                              Clear.
# 3                    Clustering palm in tufts of 2-4.
# 4                                    Rank: FLOWERING.
# 5                                               Sans.
# 6                                    Rank: FLOWERING.
# 7   This is an extremely thin palm with extremely ...
# 8   The from is extremely thin, almost less than a...
# 9   This is an extremely thin palm with extremely ...
# 10  It is about 40cms tall and is more glossy gree...
# 11                   Clustering palm in tufts of 2-4.
# 12  This is an extremely thin palm with extremely ...
# 13  This is an extremely thin palm with extremely ...
# 14  This is an extremely thin palm with extremely ...
# 15  Pinnate leaves, leaflets unequally jagged and ...
# 16                  Clustering palm, in tufts of 2-4.
# 17  This is an extremely thin palm with extremely ...
#
#                                                     4  \
# 0   .The larger one is soon to have a pair of infl...
# 1   The from is extremely thin, almost less than a...
# 2                                            Present.
# 3                                    Rank: FLOWERING.
# 4          Leaves. pinnate with two or more leaflets.
# 5                                            Present.
# 6   The from is extremely thin, almost less than a...
# 7                   Clustering palm, in tufts of 2-4.
# 8   Pinnate leaves, leaflets unequally jagged and ...
# 9   The from is extremely thin, almost less than a...
# 10                  Clustering palm, in tufts of 2-4.
# 11  It is about 40cms tall and is more glossy gree...
# 12                  Clustering palm, in tufts of 2-4.
# 13                  Clustering palm, in tufts of 2-4.
# 14  The from is extremely thin, almost less than a...
# 15                   Clustering palm in tufts of 2-4.
# 16  The from is extremely thin, almost less than a...
# 17  The from is extremely thin, almost less than a...
#
#                                                     5  \
# 0          Leaves. pinnate with two or more leaflets.
# 1                    Clustering palm in tufts of 2-4.
# 2                                               Sans.
# 3   Pinnate leaves, leaflets unequally jagged and ...
# 4   Pinnate leaves, leaflets unequally jagged and ...
# 5                                     Rank: SEEDLING.
# 6                   Clustering palm, in tufts of 2-4.
# 7                    Clustering palm in tufts of 2-4.
# 8   This is an extremely thin palm with extremely ...
# 9                   Clustering palm, in tufts of 2-4.
# 10        It has bifurcated , hard to tell from pics.
# 11                                    Rank: SEEDLING.
# 12                   Clustering palm in tufts of 2-4.
# 13  The from is extremely thin, almost less than a...
# 14                  Clustering palm, in tufts of 2-4.
# 15  This is an extremely thin palm with extremely ...
# 16                   Clustering palm in tufts of 2-4.
# 17                  Clustering palm, in tufts of 2-4.
#
#                                GoogleSentence   Sim Sum
# 0               Fruit colour description: red  0.826880
# 1                           Fruit colour: red  0.838760
# 2                          Crown: understorey  0.826209
# 3                           Fruit size: small  0.855436
# 4                        Fruit shape: globose  0.867743
# 5                Conspicuousness: conspicuous  0.778821
# 6          Maximum stem height in meters: 1.0  0.829054
# 7   Maximum stem diameter in centimeters: 0.6  0.853949
# 8                   Maximum leaf number: 10.0  0.882855
# 9   Maximum leaf blade length in meters: 0.48  0.874254
# 10       Maximum rachis length in meters: 0.3  0.783886
# 11      Maximum petiole length in meters: 0.2  0.819737
# 12   Average fruit length in centimeters: 1.0  0.862938
# 13   Minimum fruit length in centimeters: 0.9  0.860637
# 14   Maximum fruit length in centimeters: 1.1  0.858885
# 15    Average fruit width in centimeters: 0.4  0.867404
# 16    Minimum fruit width in centimeters: 0.3  0.862677
# 17    Maximum fruit width in centimeters: 0.5  0.863569

# %% [markdown]
# ### Google DF

# %%
root = "../../../data/processed/"
df_google = pd.read_csv(root + "top_sents_all_AllSentencesAgainstTrait_BERT_AllData.csv", index_col=0) 

root = "../../../data/interim/"
df_google.to_csv(root + "DF_GoogleForms_Bert_AllData.csv")

# %%
df_google\
    .dropna()\
    .sort_values(by=['Sim Sum'], ascending=False)
# Out:
#                      Species        Main Trait     GT Main Trait  \
# 1815        Clausena anisata    inflorescences    inflorescences
# 7952        Bursera simaruba  Leaf composition  Leaf composition
# 8528         Randia aculeata        Leaf shape        Leaf shape
# 5958      Prosopis juliflora  Leaf composition  Leaf composition
# 5959      Prosopis juliflora        Leaf shape        Leaf shape
# ...                      ...               ...               ...
# 2432  Croton psedopulchellus         sexuality         sexuality
# 1383      Cajanus kerstingii         sexuality         sexuality
# 218            Acacia kirkii         sexuality         sexuality
# 5792    Pericopsis laxiflora         sexuality         sexuality
# 7655  Xeroderris stuhlmannii         sexuality         sexuality
#
#                                      GT Sub Traits  \
# 1815      ['Panicle of flowers or inflorescences']
# 7952                               ['5-9 pinnate']
# 8528                       ['spathulate, obovate']
# 5958        ['bi-pinnate, 20-40 leaflets per jug']
# 5959                           ['linear, obovate']
# ...                                            ...
# 2432                        ['Terminal sexuality']
# 1383                        ['Axillary sexuality']
# 218                         ['Axillary sexuality']
# 5792  ['Axillary sexuality', 'Terminal sexuality']
# 7655                        ['Terminal sexuality']
#
#                                                       1  \
# 1815  Flowers Inflorescence axillary racemes, flower...
# 7952  Leaf type: odd-pinnately compound, made up of ...
# 8528                            Leaf shape: orbiculate.
# 5958  Leaves, are twice-compound with mostly two, so...
# 5959  Leaflets linear -oblong, apex sub-obtuse, mucr...
# ...                                                 ...
# 2432                  Seed germination takes 3-4 weeks.
# 1383  The leaves are faintly striate and a glandular...
# 218                                               Sans.
# 5792               Definition: whole plant arborescent.
# 7655                               Wing-Bean, Wing-Pod.
#
#                                                       2  \
# 1815  Flowers : Inflorescence axillary racemes , flo...
# 7952                       Leaf shape: ovate to oblong.
# 8528                            Leaf venation: pinnate.
# 5958  Leaves bipinnate, glabrous or pubescent, 1-3 p...
# 5959  Leaves, are twice-compound with mostly two, so...
# ...                                                 ...
# 2432  A pale white/yellow-flowered, shrubby, perenni...
# 1383                    Perennial, Not climbing, Shrub.
# 218   It has a spreading, flat-topped crown, growing...
# 5792  A tree or shrub, common growth reaches between...
# 7655              Medium-sized to large spreading tree.
#
#                                                       3  \
# 1815  Flowers in axillary, cymose panicles, yellow o...
# 7952  Leaf blade length: 4 to 8 inches, leaflets are...
# 8528  Leaves opposite on main branches but congested...
# 5958  Â  Leaves, petiolate 1-4 cm, bipinnate with gl...
# 5959  Leaves alternate, bipinnate, with 1-3 pairs of...
# ...                                                 ...
# 2432                    Male flowers:pedicels 2â3 mm.
# 1383  Morphology Branchlets and undersurface of leav...
# 218   Vachellia kirkii is a multi-trunked shrub or t...
# 5792  Trunk usually twisted, rarely straight and wit...
# 7655  Morphology A medium-sized to large, spreading ...
#
#                                                       4  \
# 1815  Flowers: Bunches of small creamy-yellow âsta...
# 7952  Leaves: Alternate , pinnately compound, 6-8" Ã...
# 8528                                 Leaf type: simple.
# 5958            Leaves medium to large, 8â16 cm long.
# 5959  Leaflets oblong , apex obtuse , pubescent, 10â...
# ...                                                 ...
# 2432  A much-branched shrub, or small tree up to 5 m...
# 1383  A shrub 3â7 ft. high with stems less angular...
# 218           Seeds blackish-olive, 5-7 x 4Â·5-5Â·5 mm.
# 5792  Leaves, alternate arrangement, 4 - 6 pairs, up...
# 7655  Fruit: a large, flattened pod, 10-18 x 3-4.5 c...
#
#                                                       5  \
# 1815  Inflorescence of elongate puberulous panicles,...
# 7952  The leaves are compound ranging from 3 to 9 le...
# 8528                               Leaf margin: entire.
# 5958  Leaves arising from very condensed short-shoot...
# 5959                 Leaflets oblong and sub-pubescent.
# ...                                                 ...
# 2432  The flowers are in compact heads at the ends o...
# 1383  Branchlets and undersurface of leaves shortly ...
# 218                             Leaves: rhachis 3-8 cm.
# 5792  Leaves, alternate arrangement, 4 - 6 pairs, up...
# 7655  Bark: grey-brown, fairly smooth to rough, flak...
#
#                                          GoogleSentence   Sim Sum
# 1815  Inflorescences: panicle of flowers or inflores...  0.966772
# 7952                      Leaf composition: 5-9 pinnate  0.964268
# 8528                    Leaf shape: spathulate, obovate  0.963610
# 5958  Leaf composition: bi-pinnate, 20-40 leaflets p...  0.962056
# 5959                        Leaf shape: linear, obovate  0.961554
# ...                                                 ...       ...
# 2432                      Sexuality: terminal sexuality  0.647814
# 1383                      Sexuality: axillary sexuality  0.640310
# 218                       Sexuality: axillary sexuality  0.638355
# 5792                      Sexuality: axillary sexuality  0.627646
# 7655                      Sexuality: terminal sexuality  0.611866
#
# [12380 rows x 11 columns]

# %%
df_google_thresh = df_google[df_google["Sim Sum"] > 0.9]

for i in range(1, 11, 2):
    df_google_subset = df_google_thresh\
                                     .sample(n=20, axis=0, random_state=333+i)

    df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset_{i+1}.csv', sep='\t')

df_google_subset = df_google[df_google["Sim Sum"] > 0.9].sample(n=20, axis=0, random_state=123)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset_demo_BERT.csv', sep='\t')
