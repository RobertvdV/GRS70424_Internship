# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn import metrics
import json
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.corpus import stopwords
import collections
from itertools import groupby
import pickle
import re
import matplotlib.colors as mcolors
import warnings
import requests
import csv

# %% [markdown]
# ### Load the Data

# %%
root = "../../data/external/"

# Data Pierre
file_name = root + 'Dataset_Pierre.csv'
df_Pierre = pd.read_csv(file_name, header=[0, 1]) 
df_Pierre = df_Pierre.iloc[: , 1:]
df_Pierre = df_Pierre.set_index(df_Pierre['Species']['species'])

# Data Andrei
file_name = root + 'Dataset_Andrei.csv'
df_Andrei = pd.read_csv(file_name)

# Get Dummies to match DF Pierre
df_Andrei_dummies = pd.get_dummies(df_Andrei.iloc[:, 2:])
# Set species back
df_Andrei_dummies = df_Andrei_dummies.set_index(df_Andrei['Species'])

# Create tuple list for multi index
Andrei_multi_index = []
for top_index in df_Andrei.columns:
    for sub_index in df_Andrei_dummies.columns:
        if top_index in sub_index:

            sub_index = sub_index.split('_')[-1]
            Andrei_multi_index.append((top_index, sub_index))

# Set Mutli index
df_Andrei_dummies.columns = pd.MultiIndex.from_tuples(Andrei_multi_index)

# Data Palms
file_name = root + 'Dataset_Kissling.txt'
df_Daniel = pd.read_csv(file_name,
                 sep='\t', encoding='Latin-1')
palm_species = df_Daniel[~df_Daniel.isnull().any(axis=1)]['SpecName'].values
df_Daniel.set_index('SpecName', inplace=True)

# %% [markdown]
# ### Helper Functions

# %%
def jaccard_similarity(A, B):
    """Calculates the Jaccard similarity two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    A = set(A)
    B = set(B)
    
    # Get intersection of two sets
    nominator = A.intersection(B)

    # Find union of two sets
    denominator = A.union(B)

    # Take the ratio of sizes
    similarity = len(nominator)/len(denominator)

    return similarity

nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}
colors = [color[4:] for color in mcolors.TABLEAU_COLORS.keys()]
colors.extend([color for color in mcolors.CSS4_COLORS.keys()])
colors.extend(
    [
        'whitish', 'bluish', 'reddish', 'greenish', 'backish', 'greyish',
        'backish', 'purplish', 'yellowish', 'orangish', 'brownish', 'pinkish'
    ]
)

def resentesize(lst):

    sentence = ''

    # Loop every 2 items 
    for item1, item2 in zip(lst[::2], lst[1::2]):
        
        # Set verb
        verb = 'has'
        chunk = item2.split(' ')[-1]
        if chunk not in nouns or chunk in colors:
            verb = 'is'

        sentence += f'{item1.capitalize()} {verb} {item2}. '
    
    return sentence


def get_wiki_main_image(title):
    url = 'https://en.wikipedia.org/w/api.php'
    data = {
        'action' :'query',
        'format' : 'json',
        'formatversion' : 2,
        'prop' : 'pageimages|pageterms',
        'piprop' : 'original',
        'titles' : title
    }
    response = requests.get(url, data)
    json_data = json.loads(response.text)
    return json_data['query']['pages'][0]['original']['source'] if len(json_data['query']['pages']) >0 else 'Not found'

# %% [markdown]
# ## Retokize the Data

# %%
# Init empty dict for retok
species_datalist = collections.defaultdict(list)

root = "../../data/processed/"
file_name = root + 'Triples_Pierre.txt'

with open(file_name) as f:
   json_data = json.load(f)

for idx, (k, lst) in enumerate(json_data.items()):
    for l in lst:

        # Flatten list of lists
        flat_list = [item for sublist in l for item in sublist]
        # Retokens some sentence with multiple 'species'
        flat_list_multiple_sents = [list(v) for k, v in groupby(flat_list, lambda x: x != 'species') if k]
        
        for sentence in flat_list_multiple_sents:
            # Insert species
            sentence.insert(0, 'species')
            species_datalist[k].append(sentence)

file_name = root + 'Triples_Andrei.txt'

with open(file_name) as f:
   json_data = json.load(f)

for idx, (k, lst) in enumerate(json_data.items()):
    for l in lst:

        # Flatten list of lists
        flat_list = [item for sublist in l for item in sublist]
        # Retokens some sentence with multiple 'species'
        flat_list_multiple_sents = [list(v) for k, v in groupby(flat_list, lambda x: x != 'species') if k]
        
        for sentence in flat_list_multiple_sents:
            # Insert species
            sentence.insert(0, 'species')
            species_datalist[k].append(sentence)

# %% [markdown]
# ## Match Data

# %%
k= 5
google_form_lst = []

for idx, (species, sentences) in enumerate(tqdm(species_datalist.items())):

    # if idx >= 1:
    #     continue
    
    df_select = [df_Andrei_dummies, df_Pierre]
    if species in df_Andrei_dummies.index:
        df_select = df_select[0]
    elif species in df_Pierre.index:
        df_select = df_select[1]
    else:
        raise ValueError

    for gt_main_trait in df_select.columns.get_level_values(0).unique():
        df_subset = df_select[df_select.index == species][gt_main_trait]
        present_traits = df_subset.loc[:, df_subset.any()].columns.values
        df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)

        top_list = []

        for sentence in sentences:
            # sentence = ' '.join(sentence)
            sentence = resentesize(sentence)
            gt_sim = jaccard_similarity(sentence, df_sent)
            top_list.append((gt_sim, sentence))

        top_list.sort(reverse=True)
        top_k_list = [sentence for (_, sentence) in top_list[0:k]]

        google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list))
# Out:
# 100%|██████████| 401/401 [00:41<00:00,  9.66it/s]

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5'])
df_google
# Out:
#                      Species      Main Trait   GT Main Trait  \
# 0     Acacia amythethophylla         Species         Species
# 1     Acacia amythethophylla      plant type      plant type
# 2     Acacia amythethophylla     phyllotaxis     phyllotaxis
# 3     Acacia amythethophylla  trunk and root  trunk and root
# 4     Acacia amythethophylla           latex           latex
# ...                      ...             ...             ...
# 9978        Guaiacum sanctum      Fruit type      Fruit type
# 9979        Guaiacum sanctum     Fruit shape     Fruit shape
# 9980        Guaiacum sanctum    Fruit colour    Fruit colour
# 9981        Guaiacum sanctum     Aril colour     Aril colour
# 9982        Guaiacum sanctum     Seed colour     Seed colour
#
#                  GT Sub Traits  \
# 0                    [species]
# 1                [Tree, Shrub]
# 2      [Phyllotaxis alternate]
# 3     [Base of trunk straight]
# 4                 [No exudate]
# ...                        ...
# 9978                 [capsule]
# 9979    [3-5-locular, globose]
# 9980          [yellow, orange]
# 9981                     [red]
# 9982                   [brown]
#
#                                                       1  \
# 0     Species is seeds. Seeds has seed. Seed has ceb...
# 1     Species has trunk. Trunk has bark. Bark has tr...
# 2     Species is soils. Soils has soil. Soil is poor...
# 3     Species has stem. Stem has bark. Bark has stem...
# 4     Species has plant. Plant has plant. Plant has ...
# ...                                                 ...
# 9978  Species is fruits. Fruits has palm. Palm has f...
# 9979  Species is flowers. Flowers has flower. Flower...
# 9980  Species has fruit. Fruit has color. Color has ...
# 9981  Species is plants. Plants has plant. Plant is ...
# 9982  Species is flowers. Flowers has flower. Flower...
#
#                                                       2  \
# 0     Species has seed. Seed has pod. Pod has seed p...
# 1     Species is soils. Soils has soil. Soil is poor...
# 2     Species is plants. Plants has plant. Plant has...
# 3     Species has trunk. Trunk has bark. Bark has tr...
# 4     Species is stipules. Stipules has stipule. Sti...
# ...                                                 ...
# 9978  Species is flowers. Flowers has flower. Flower...
# 9979  Species is flowers. Flowers has flower. Flower...
# 9980  Species is flowers. Flowers has flower. Flower...
# 9981  Species is plants. Plants has plant. Plant is ...
# 9982  Species is branches. Branches has branch. Bran...
#
#                                                       3  \
# 0     Species has seed. Seed has dale. Dale has seed...
# 1     Species has plant. Plant has sugar. Sugar has ...
# 2     Species has plant. Plant has plant. Plant has ...
# 3     Species has root. Root has bark. Bark has root...
# 4     Species has plant. Plant has plant. Plant has ...
# ...                                                 ...
# 9978  Species has soil. Soil has soil. Soil has drou...
# 9979  Species is flowers. Flowers has flower. Flower...
# 9980  Species is flowers. Flowers has flower. Flower...
# 9981  Species has soil. Soil has soil. Soil has drou...
# 9982  Species is soils. Soils has soil. Soil has dra...
#
#                                                       4  \
# 0     Species is seeds. Seeds has seed. Seed has sto...
# 1     Species has trunk. Trunk has bark. Bark has tr...
# 2     Species has plant. Plant has analysis. Analysi...
# 3     Species is fruits. Fruits has fruit. Fruit is ...
# 4     Species has stem. Stem has extraction. Extract...
# ...                                                 ...
# 9978  Species is fruits. Fruits has fruit. Fruit is ...
# 9979  Species is flowers. Flowers has flower. Flower...
# 9980  Species has gametophyte. Gametophyte has gener...
# 9981  Species is soils. Soils has soil. Soil has dra...
# 9982  Species is seeds. Seeds has seed. Seed is brow...
#
#                                                       5
# 0     Species is pinnae. Pinnae is pinnae. Pinnae is...
# 1     Species has fruit. Fruit has fruit. Fruit has ...
# 2     Species has plant. Plant has analysis. Analysi...
# 3     Species has stem. Stem has bark. Bark has stem...
# 4     Species has stem. Stem has bark. Bark has stem...
# ...                                                 ...
# 9978  Species is tissues. Tissues has tissue. Tissue...
# 9979  Species is flowers. Flowers has flower. Flower...
# 9980  Species has fruit. Fruit has fruit. Fruit has ...
# 9981  Species has soil. Soil has soil. Soil has drain.
# 9982  Species is plants. Plants has plant. Plant is ...
#
# [9983 rows x 9 columns]

# %%
df_google.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait.csv')

# %%
df_google_subset = df_google\
                    .dropna()\
                    .sample(n=20, axis=0, random_state=123)\

df_google_subset
# Out:
#                           Species      Main Trait   GT Main Trait  \
# 9864             Casearia tremula   Leaf position   Leaf position
# 9427       Erythroxylum havanense     Fruit shape     Fruit shape
# 3594        Fadogia erythrophloea           fruit           fruit
# 7511  Securidaca longipedunculata     leaf margin     leaf margin
# 2968         Detarium microcarpum     blade color     blade color
# 2136              Cola cordifolia      leaf blade      leaf blade
# 3250          Erythrina sigmoidea         Species         Species
# 8902          Ziziphus abyssinica  trunk and root  trunk and root
# 7434     Sarcocephalus latifolius         petiole         petiole
# 9497           Libidibia coriaria   Stamen number   Stamen number
# 2389          Combretum nioroense       leaf apex       leaf apex
# 9575                 Vitex cymosa       Life form       Life form
# 6138         Neocarya macrophylla       leaf base       leaf base
# 232                 Acacia kirkii            bark            bark
# 4185        Garcinia livingstonei         petiole         petiole
# 7          Acacia amythethophylla            bark            bark
# 2479        Commiphora kerstingii           latex           latex
# 8632         Vernonia thomsoniana      bark color      bark color
# 9480           Libidibia coriaria   Leaf position   Leaf position
# 2205        Combretum adenogonium           crown           crown
#
#                                           GT Sub Traits  \
# 9864                                        [alternate]
# 9427                                         [elongate]
# 3594                       [Berry, or berry-like fruit]
# 7511                               [Smooth leaf margin]
# 2968                           [Leaf blade discoloured]
# 2136                     [orbicular blade, lobed blade]
# 3250                                          [species]
# 8902                           [Base of trunk straight]
# 7434                                  [Petiolated leaf]
# 9497                                               [10]
# 2389  [Leaf apex sharp corner, Leaf apex with wide c...
# 9575                                             [tree]
# 6138             [Rounded leaf base, Leaf base cordate]
# 232   [Smooth bark, Finely fissured bark, Presence o...
# 4185                                  [Petiolated leaf]
# 7     [Presence of spines or prickles on the trunk, ...
# 2479                                      [White latex]
# 8632                              [Slice in light bark]
# 9480                                        [alternate]
# 2205                     [Regular density of the crown]
#
#                                                       1  \
# 9864  Species has plant. Plant has plant. Plant has ...
# 9427  Species is plants. Plants has plant. Plant is ...
# 3594  Species is flowers. Flowers has flower. Flower...
# 7511  Species is plants. Plants has plant. Plant of ...
# 2968  Species has seed. Seed has flour. Flour has se...
# 2136  Species has flower. Flower is colour. Colour i...
# 3250  Species is cells. Cells has cell. Cell has cem...
# 8902  Species has root. Root has bark. Bark has root...
# 7434  Species has plant. Plant has plant. Plant has ...
# 9497  Species is plants. Plants has plant. Plant has...
# 2389  Species has plant. Plant is lifeform. Lifeform...
# 9575  Species has plant. Plant is lifeform. Lifeform...
# 6138  Species has plant. Plant has plant. Plant has ...
# 232   Species is plants. Plants has plant. Plant of ...
# 4185  Species is plants. Plants has plant. Plant of ...
# 7     Species has stem. Stem has bark. Bark has stem...
# 2479  Species is plants. Plants has plant. Plant has...
# 8632  Species has root. Root has root. Root is thick...
# 9480  Species is plants. Plants has plant. Plant has...
# 2205  Species has root. Root has root. Root is root ...
#
#                                                       2  \
# 9864  Species is plants. Plants has plant. Plant of ...
# 9427  Species is plants. Plants has plant. Plant has...
# 3594  Species is flowers. Flowers has flower. Flower...
# 7511  Species has plant. Plant has form. Form has gr...
# 2968  Species is seeds. Seeds has flour. Flour has s...
# 2136  Species has fruit. Fruit has fruit. Fruit has ...
# 3250  Species is cells. Cells has line. Line has cel...
# 8902  Species has soil. Soil has soil. Soil has deep...
# 7434  Species has plant. Plant has plant. Plant is t...
# 9497  Species is plants. Plants has plant. Plant is ...
# 2389  Species has plant. Plant has plant. Plant has ...
# 9575  Species has leaf. Leaf has leaf. Leaf is long....
# 6138  Species is plants. Plants has plant. Plant has...
# 232   Species is stipules. Stipules has stipule. Sti...
# 4185  Species has plant. Plant has plant. Plant has ...
# 7     Species has trunk. Trunk has bark. Bark has tr...
# 2479  Species has plant. Plant has name. Name has pl...
# 8632  Species has plant. Plant is specie. Specie is ...
# 9480  Species is plants. Plants has plant. Plant of ...
# 2205  Species is flowers. Flowers has flower. Flower...
#
#                                                       3  \
# 9864  Species is seeds. Seeds has seed. Seed is angl...
# 9427  Species is plants. Plants has plant. Plant and...
# 3594  Species is buds. Buds has bud. Bud is peduncul...
# 7511  Species has fruit. Fruit has fruit. Fruit has ...
# 2968  Species has seed. Seed has flour. Flour has se...
# 2136  Species is plants. Plants has plant. Plant has...
# 3250  Species has seed. Seed has seed. Seed has coll...
# 8902  Species is plants. Plants has plant. Plant has...
# 7434  Species has plant. Plant has plant. Plant is t...
# 9497  Species is plants. Plants has plant. Plant and...
# 2389  Species is stems. Stems has stem. Stem has gro...
# 9575  Species has leaf. Leaf has leaf. Leaf is intri...
# 6138  Species has fruit. Fruit has herb. Herb has fr...
# 232   Species is stipules. Stipules has stipule. Sti...
# 4185  Species is plants. Plants has plant. Plant of ...
# 7     Species has plant. Plant has part. Part has pl...
# 2479  Species has plant. Plant has plant. Plant is c...
# 8632  Species is stems. Stems has stem. Stem is pale...
# 9480  Species has pinna. Pinna has pinna. Pinna is o...
# 2205  Species has plant. Plant has part. Part has pl...
#
#                                                       4  \
# 9864  Species is plants. Plants has plant. Plant has...
# 9427  Species is plants. Plants has plant. Plant and...
# 3594  Species is fruits. Fruits has fruit. Fruit has...
# 7511  Species has plant. Plant has plant. Plant is f...
# 2968  Species has seed. Seed has flour. Flour has se...
# 2136  Species has fruit. Fruit has fruit. Fruit is s...
# 3250  Species has cell. Cell has line. Line has cell...
# 8902  Species has root. Root has bark. Bark has root...
# 7434  Species is plants. Plants has plant. Plant is ...
# 9497  Species is plants. Plants has plant. Plant and...
# 2389  Species has plant. Plant has plant. Plant has ...
# 9575  Species has flower. Flower has flower. Flower ...
# 6138  Species has fruit. Fruit has fruit. Fruit of n...
# 232   Species is plants. Plants has plant. Plant has...
# 4185  Species is soils. Soils has soil. Soil has fer...
# 7     Species has root. Root has bark. Bark has root...
# 2479  Species has plant. Plant has form. Form has pl...
# 8632  Species is corollas. Corollas has corolla. Cor...
# 9480  Species is petals. Petals has petal. Petal is ...
# 2205  Species has inflorescence. Inflorescence has i...
#
#                                                       5
# 9864  Species has style. Style has style. Style is s...
# 9427  Species is plants. Plants has plant. Plant is ...
# 3594  Species is plants. Plants has plant. Plant is ...
# 7511  Species is plants. Plants has plant. Plant of ...
# 2968  Species has seed. Seed has flour. Flour has se...
# 2136  Species has fruit. Fruit has fruit. Fruit is r...
# 3250  Species is soils. Soils has soil. Soil is rocky.
# 8902  Species is fruits. Fruits has fruit. Fruit has...
# 7434  Species is tissues. Tissues has tissue. Tissue...
# 9497  Species is petals. Petals has petal. Petal is ...
# 2389  Species is plants. Plants has plant. Plant is ...
# 9575  Species is flowers. Flowers has flower. Flower...
# 6138  Species has fruit. Fruit has fruit. Fruit of n...
# 232   Species is glands. Glands has gland. Gland is ...
# 4185  Species is plants. Plants has plant. Plant has...
# 7     Species has plant. Plant has part. Part has pl...
# 2479  Species has leaf. Leaf has scar. Scar is leaf-...
# 8632  Species is involucres. Involucres has involucr...
# 9480  Species is leaflets. Leaflets has leaflet. Lea...
# 2205  Species is plants. Plants has plant. Plant of ...

# %%
random_sample_species = df_google_subset['Species'].values

images_links = {}
for species in tqdm(random_sample_species):
    species_ = species.replace(' ', '_')
    try:
        img_url = get_wiki_main_image(species_)
        if img_url[-3:] != 'jpg':
            img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        # if img_url[-3:].isupper():
        #     img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        images_links[species] = img_url
    except:
        images_links[species] = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'

# df_google_subset = df_google[df_google['Species'].isin(random_sample_species)]
df_google_subset = df_google_subset.set_index('Species')
df_google_subset["URL"] = pd.Series(images_links)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset.csv', sep='\t')#, quoting=csv.QUOTE_ALL)
# Out:
# 100%|██████████| 20/20 [00:03<00:00,  5.61it/s]

# %%
df_google_subset
# Out:
#                                  Main Trait   GT Main Trait  \
# Species
# Casearia tremula              Leaf position   Leaf position
# Erythroxylum havanense          Fruit shape     Fruit shape
# Fadogia erythrophloea                 fruit           fruit
# Securidaca longipedunculata     leaf margin     leaf margin
# Detarium microcarpum            blade color     blade color
# Cola cordifolia                  leaf blade      leaf blade
# Erythrina sigmoidea                 Species         Species
# Ziziphus abyssinica          trunk and root  trunk and root
# Sarcocephalus latifolius            petiole         petiole
# Libidibia coriaria            Stamen number   Stamen number
# Combretum nioroense               leaf apex       leaf apex
# Vitex cymosa                      Life form       Life form
# Neocarya macrophylla              leaf base       leaf base
# Acacia kirkii                          bark            bark
# Garcinia livingstonei               petiole         petiole
# Acacia amythethophylla                 bark            bark
# Commiphora kerstingii                 latex           latex
# Vernonia thomsoniana             bark color      bark color
# Libidibia coriaria            Leaf position   Leaf position
# Combretum adenogonium                 crown           crown
#
#                                                                  GT Sub Traits  \
# Species
# Casearia tremula                                                   [alternate]
# Erythroxylum havanense                                              [elongate]
# Fadogia erythrophloea                             [Berry, or berry-like fruit]
# Securidaca longipedunculata                               [Smooth leaf margin]
# Detarium microcarpum                                  [Leaf blade discoloured]
# Cola cordifolia                                 [orbicular blade, lobed blade]
# Erythrina sigmoidea                                                  [species]
# Ziziphus abyssinica                                   [Base of trunk straight]
# Sarcocephalus latifolius                                     [Petiolated leaf]
# Libidibia coriaria                                                        [10]
# Combretum nioroense          [Leaf apex sharp corner, Leaf apex with wide c...
# Vitex cymosa                                                            [tree]
# Neocarya macrophylla                    [Rounded leaf base, Leaf base cordate]
# Acacia kirkii                [Smooth bark, Finely fissured bark, Presence o...
# Garcinia livingstonei                                        [Petiolated leaf]
# Acacia amythethophylla       [Presence of spines or prickles on the trunk, ...
# Commiphora kerstingii                                            [White latex]
# Vernonia thomsoniana                                     [Slice in light bark]
# Libidibia coriaria                                                 [alternate]
# Combretum adenogonium                           [Regular density of the crown]
#
#                                                                              1  \
# Species
# Casearia tremula             Species has plant. Plant has plant. Plant has ...
# Erythroxylum havanense       Species is plants. Plants has plant. Plant is ...
# Fadogia erythrophloea        Species is flowers. Flowers has flower. Flower...
# Securidaca longipedunculata  Species is plants. Plants has plant. Plant of ...
# Detarium microcarpum         Species has seed. Seed has flour. Flour has se...
# Cola cordifolia              Species has flower. Flower is colour. Colour i...
# Erythrina sigmoidea          Species is cells. Cells has cell. Cell has cem...
# Ziziphus abyssinica          Species has root. Root has bark. Bark has root...
# Sarcocephalus latifolius     Species has plant. Plant has plant. Plant has ...
# Libidibia coriaria           Species is plants. Plants has plant. Plant has...
# Combretum nioroense          Species has plant. Plant is lifeform. Lifeform...
# Vitex cymosa                 Species has plant. Plant is lifeform. Lifeform...
# Neocarya macrophylla         Species has plant. Plant has plant. Plant has ...
# Acacia kirkii                Species is plants. Plants has plant. Plant of ...
# Garcinia livingstonei        Species is plants. Plants has plant. Plant of ...
# Acacia amythethophylla       Species has stem. Stem has bark. Bark has stem...
# Commiphora kerstingii        Species is plants. Plants has plant. Plant has...
# Vernonia thomsoniana         Species has root. Root has root. Root is thick...
# Libidibia coriaria           Species is plants. Plants has plant. Plant has...
# Combretum adenogonium        Species has root. Root has root. Root is root ...
#
#                                                                              2  \
# Species
# Casearia tremula             Species is plants. Plants has plant. Plant of ...
# Erythroxylum havanense       Species is plants. Plants has plant. Plant has...
# Fadogia erythrophloea        Species is flowers. Flowers has flower. Flower...
# Securidaca longipedunculata  Species has plant. Plant has form. Form has gr...
# Detarium microcarpum         Species is seeds. Seeds has flour. Flour has s...
# Cola cordifolia              Species has fruit. Fruit has fruit. Fruit has ...
# Erythrina sigmoidea          Species is cells. Cells has line. Line has cel...
# Ziziphus abyssinica          Species has soil. Soil has soil. Soil has deep...
# Sarcocephalus latifolius     Species has plant. Plant has plant. Plant is t...
# Libidibia coriaria           Species is plants. Plants has plant. Plant is ...
# Combretum nioroense          Species has plant. Plant has plant. Plant has ...
# Vitex cymosa                 Species has leaf. Leaf has leaf. Leaf is long....
# Neocarya macrophylla         Species is plants. Plants has plant. Plant has...
# Acacia kirkii                Species is stipules. Stipules has stipule. Sti...
# Garcinia livingstonei        Species has plant. Plant has plant. Plant has ...
# Acacia amythethophylla       Species has trunk. Trunk has bark. Bark has tr...
# Commiphora kerstingii        Species has plant. Plant has name. Name has pl...
# Vernonia thomsoniana         Species has plant. Plant is specie. Specie is ...
# Libidibia coriaria           Species is plants. Plants has plant. Plant of ...
# Combretum adenogonium        Species is flowers. Flowers has flower. Flower...
#
#                                                                              3  \
# Species
# Casearia tremula             Species is seeds. Seeds has seed. Seed is angl...
# Erythroxylum havanense       Species is plants. Plants has plant. Plant and...
# Fadogia erythrophloea        Species is buds. Buds has bud. Bud is peduncul...
# Securidaca longipedunculata  Species has fruit. Fruit has fruit. Fruit has ...
# Detarium microcarpum         Species has seed. Seed has flour. Flour has se...
# Cola cordifolia              Species is plants. Plants has plant. Plant has...
# Erythrina sigmoidea          Species has seed. Seed has seed. Seed has coll...
# Ziziphus abyssinica          Species is plants. Plants has plant. Plant has...
# Sarcocephalus latifolius     Species has plant. Plant has plant. Plant is t...
# Libidibia coriaria           Species is plants. Plants has plant. Plant and...
# Combretum nioroense          Species is stems. Stems has stem. Stem has gro...
# Vitex cymosa                 Species has leaf. Leaf has leaf. Leaf is intri...
# Neocarya macrophylla         Species has fruit. Fruit has herb. Herb has fr...
# Acacia kirkii                Species is stipules. Stipules has stipule. Sti...
# Garcinia livingstonei        Species is plants. Plants has plant. Plant of ...
# Acacia amythethophylla       Species has plant. Plant has part. Part has pl...
# Commiphora kerstingii        Species has plant. Plant has plant. Plant is c...
# Vernonia thomsoniana         Species is stems. Stems has stem. Stem is pale...
# Libidibia coriaria           Species has pinna. Pinna has pinna. Pinna is o...
# Combretum adenogonium        Species has plant. Plant has part. Part has pl...
#
#                                                                              4  \
# Species
# Casearia tremula             Species is plants. Plants has plant. Plant has...
# Erythroxylum havanense       Species is plants. Plants has plant. Plant and...
# Fadogia erythrophloea        Species is fruits. Fruits has fruit. Fruit has...
# Securidaca longipedunculata  Species has plant. Plant has plant. Plant is f...
# Detarium microcarpum         Species has seed. Seed has flour. Flour has se...
# Cola cordifolia              Species has fruit. Fruit has fruit. Fruit is s...
# Erythrina sigmoidea          Species has cell. Cell has line. Line has cell...
# Ziziphus abyssinica          Species has root. Root has bark. Bark has root...
# Sarcocephalus latifolius     Species is plants. Plants has plant. Plant is ...
# Libidibia coriaria           Species is plants. Plants has plant. Plant and...
# Combretum nioroense          Species has plant. Plant has plant. Plant has ...
# Vitex cymosa                 Species has flower. Flower has flower. Flower ...
# Neocarya macrophylla         Species has fruit. Fruit has fruit. Fruit of n...
# Acacia kirkii                Species is plants. Plants has plant. Plant has...
# Garcinia livingstonei        Species is soils. Soils has soil. Soil has fer...
# Acacia amythethophylla       Species has root. Root has bark. Bark has root...
# Commiphora kerstingii        Species has plant. Plant has form. Form has pl...
# Vernonia thomsoniana         Species is corollas. Corollas has corolla. Cor...
# Libidibia coriaria           Species is petals. Petals has petal. Petal is ...
# Combretum adenogonium        Species has inflorescence. Inflorescence has i...
#
#                                                                              5  \
# Species
# Casearia tremula             Species has style. Style has style. Style is s...
# Erythroxylum havanense       Species is plants. Plants has plant. Plant is ...
# Fadogia erythrophloea        Species is plants. Plants has plant. Plant is ...
# Securidaca longipedunculata  Species is plants. Plants has plant. Plant of ...
# Detarium microcarpum         Species has seed. Seed has flour. Flour has se...
# Cola cordifolia              Species has fruit. Fruit has fruit. Fruit is r...
# Erythrina sigmoidea          Species is soils. Soils has soil. Soil is rocky.
# Ziziphus abyssinica          Species is fruits. Fruits has fruit. Fruit has...
# Sarcocephalus latifolius     Species is tissues. Tissues has tissue. Tissue...
# Libidibia coriaria           Species is petals. Petals has petal. Petal is ...
# Combretum nioroense          Species is plants. Plants has plant. Plant is ...
# Vitex cymosa                 Species is flowers. Flowers has flower. Flower...
# Neocarya macrophylla         Species has fruit. Fruit has fruit. Fruit of n...
# Acacia kirkii                Species is glands. Glands has gland. Gland is ...
# Garcinia livingstonei        Species is plants. Plants has plant. Plant has...
# Acacia amythethophylla       Species has plant. Plant has part. Part has pl...
# Commiphora kerstingii        Species has leaf. Leaf has scar. Scar is leaf-...
# Vernonia thomsoniana         Species is involucres. Involucres has involucr...
# Libidibia coriaria           Species is leaflets. Leaflets has leaflet. Lea...
# Combretum adenogonium        Species is plants. Plants has plant. Plant of ...
#
#                                                                            URL
# Species
# Casearia tremula             https://upload.wikimedia.org/wikipedia/commons...
# Erythroxylum havanense       https://upload.wikimedia.org/wikipedia/commons...
# Fadogia erythrophloea        https://upload.wikimedia.org/wikipedia/commons...
# Securidaca longipedunculata  https://upload.wikimedia.org/wikipedia/commons...
# Detarium microcarpum         https://upload.wikimedia.org/wikipedia/commons...
# Cola cordifolia              https://upload.wikimedia.org/wikipedia/commons...
# Erythrina sigmoidea          https://upload.wikimedia.org/wikipedia/commons...
# Ziziphus abyssinica          https://upload.wikimedia.org/wikipedia/commons...
# Sarcocephalus latifolius     https://upload.wikimedia.org/wikipedia/commons...
# Libidibia coriaria           https://upload.wikimedia.org/wikipedia/commons...
# Combretum nioroense          https://upload.wikimedia.org/wikipedia/commons...
# Vitex cymosa                 https://upload.wikimedia.org/wikipedia/commons...
# Neocarya macrophylla         https://upload.wikimedia.org/wikipedia/commons...
# Acacia kirkii                https://upload.wikimedia.org/wikipedia/commons...
# Garcinia livingstonei        https://upload.wikimedia.org/wikipedia/commons...
# Acacia amythethophylla       https://upload.wikimedia.org/wikipedia/commons...
# Commiphora kerstingii        https://upload.wikimedia.org/wikipedia/commons...
# Vernonia thomsoniana         https://upload.wikimedia.org/wikipedia/commons...
# Libidibia coriaria           https://upload.wikimedia.org/wikipedia/commons...
# Combretum adenogonium        https://upload.wikimedia.org/wikipedia/commons...
