# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn import metrics
import json
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.corpus import stopwords
import collections
from itertools import groupby
import pickle
import re
import matplotlib.colors as mcolors
import warnings
import requests
import csv
from sklearn.preprocessing import MultiLabelBinarizer
from functools import reduce
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Global Variables & Functions

# %% [markdown]
# #### Variables

# %%
nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}

with open('../../data/supportive/colour_list.json', 'r') as f:
  colors = json.load(f)

with open('../../data/supportive/trait_dictionary.json', 'r') as f:
  traits_dict = json.load(f)
traits_list = list(traits_dict.keys())
traits_list += [trait.lower() for lst in list(traits_dict.values()) for trait in lst]

# %% [markdown]
# #### Functions

# %%
def corresponding_keys(val, dictionary):
    """returns the corresponding key of a single value 
    assuming the values are lists.

    Args:
        val (string): string present in the dict
        dictionary (dict): dict with lists of stings as values

    Returns:
        list: list of matching keys
    """
    # Init list
    keys = []
    # Search the dict
    for k, v in dictionary.items():
        if val in v:
            keys.append(k)
    return keys
    
def jaccard_similarity(A, B):
    """Calculates the Jaccard similarity two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    A = set(A)
    B = set(B)
    
    # Get intersection of two sets
    nominator = A.intersection(B)

    # Find union of two sets
    denominator = A.union(B)

    # Take the ratio of sizes
    similarity = len(nominator)/len(denominator)

    return similarity


def similarity(groundtruth, pred):
    """Calculates the normal similarity between two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    groundtruth = set(groundtruth)
    pred = set(pred)

    # Find intersection of two sets
    nominator = groundtruth.intersection(pred)

    # Find union of two sets
    denominator = groundtruth

    # Take the ratio of sizes
    similarity = len(nominator)/(len(denominator))

    return similarity

def resentesize(lst):

    sentence = ''

    # Loop every 2 items 
    for item1, item2 in zip(lst[::2], lst[1::2]):
        
        # Set verb
        verb = 'has'
        chunk = item2.split(' ')[-1]
        if chunk not in nouns or chunk in colors:
            verb = 'is'

        sentence += f'{item1.capitalize()} {verb} {item2}. '
    
    return sentence


def get_wiki_main_image(title):
    url = 'https://en.wikipedia.org/w/api.php'
    data = {
        'action' :'query',
        'format' : 'json',
        'formatversion' : 2,
        'prop' : 'pageimages|pageterms',
        'piprop' : 'original',
        'titles' : title
    }
    response = requests.get(url, data)
    json_data = json.loads(response.text)
    return json_data['query']['pages'][0]['original']['source'] if len(json_data['query']['pages']) >0 else 'Not found'

# %% [markdown]
# ### Load GT Data

# %%
root = "../../data/external/"

# %% [markdown]
# #### Data Andrei

# %%
file_name = root + 'Dataset_Andrei.csv'
df_Andrei = pd.read_csv(file_name)

# Get Dummies to match DF Pierre
df_Andrei_dummies = pd.get_dummies(df_Andrei.iloc[:, 2:])
# Set species back
df_Andrei_dummies = df_Andrei_dummies.set_index(df_Andrei['Species'])

# Create tuple list for multi index
Andrei_multi_index = []
for top_index in df_Andrei.columns:
    for sub_index in df_Andrei_dummies.columns:
        if top_index in sub_index:

            sub_index = sub_index.split('_')[-1]
            Andrei_multi_index.append((top_index, sub_index))

# Set Mutli index
df_Andrei_dummies.columns = pd.MultiIndex.from_tuples(Andrei_multi_index)
df_Andrei_dummies
# Out:
#                            Life form      Leaf position                      \
#                                liana tree     alternate alternate, opposite
# Species
# Avicennia germinans                0    1             0                   0
# Metopium brownei                   0    1             1                   0
# Handroanthus billbergii            0    1             0                   0
# Bourreria succulenta               0    1             1                   0
# Bursera karsteniana                0    1             1                   0
# Bursera simaruba                   0    1             1                   0
# Bursera tomentosa                  0    1             1                   0
# Cynophalla flexuosa                1    0             1                   0
# Cynophalla hastata                 0    1             1                   0
# Quadrella indica                   0    1             1                   0
# Quadrella odoratissima             0    1             1                   0
# Crossopetalum rhacoma              0    1             0                   0
# Maytenus tetragona                 0    1             1                   0
# Maytenus versluysii                0    1             1                   0
# Clusia rosea                       0    1             0                   0
# Conocarpus erectus                 0    1             1                   0
# Laguncularia racemosa              0    1             0                   0
# Erythroxylum havanense             0    1             1                   0
# Croton niveus                      0    1             1                   0
# Hippomane mancinella               0    1             1                   0
# Libidibia coriaria                 0    1             1                   0
# Pithecellobium unguis-cati         0    1             1                   0
# Prosopis juliflora                 0    1             1                   0
# Vachellia tortuosa                 0    1             1                   0
# Vitex compressa                    0    1             0                   0
# Vitex cymosa                       0    1             0                   0
# Trichilia trifolia                 0    1             1                   0
# Eugenia procera                    0    1             0                   0
# Guapira pacurero                   0    1             0                   0
# Coccoloba swartzii                 0    1             1                   0
# Coccoloba uvifera                  0    1             1                   0
# Krugiodendron ferreum              0    1             0                   1
# Rhizophora mangle                  0    1             0                   0
# Guettarda roupalifolia             0    1             0                   0
# Randia aculeata                    0    1             0                   0
# Amyris ignea                       0    1             1                   0
# Zanthoxylum monophyllum            0    1             1                   0
# Casearia tremula                   0    1             1                   0
# Schoepfia schreberi                0    1             1                   0
# Jacquinia arborea                  0    1             1                   0
# Guaiacum officinale                0    1             0                   0
# Guaiacum sanctum                   0    1             0                   0
#
#                                                            \
#                            opposite opposite, whorls of 3
# Species
# Avicennia germinans               1                     0
# Metopium brownei                  0                     0
# Handroanthus billbergii           1                     0
# Bourreria succulenta              0                     0
# Bursera karsteniana               0                     0
# Bursera simaruba                  0                     0
# Bursera tomentosa                 0                     0
# Cynophalla flexuosa               0                     0
# Cynophalla hastata                0                     0
# Quadrella indica                  0                     0
# Quadrella odoratissima            0                     0
# Crossopetalum rhacoma             0                     0
# Maytenus tetragona                0                     0
# Maytenus versluysii               0                     0
# Clusia rosea                      1                     0
# Conocarpus erectus                0                     0
# Laguncularia racemosa             1                     0
# Erythroxylum havanense            0                     0
# Croton niveus                     0                     0
# Hippomane mancinella              0                     0
# Libidibia coriaria                0                     0
# Pithecellobium unguis-cati        0                     0
# Prosopis juliflora                0                     0
# Vachellia tortuosa                0                     0
# Vitex compressa                   1                     0
# Vitex cymosa                      1                     0
# Trichilia trifolia                0                     0
# Eugenia procera                   1                     0
# Guapira pacurero                  1                     0
# Coccoloba swartzii                0                     0
# Coccoloba uvifera                 0                     0
# Krugiodendron ferreum             0                     0
# Rhizophora mangle                 1                     0
# Guettarda roupalifolia            1                     0
# Randia aculeata                   0                     1
# Amyris ignea                      0                     0
# Zanthoxylum monophyllum           0                     0
# Casearia tremula                  0                     0
# Schoepfia schreberi               0                     0
# Jacquinia arborea                 0                     0
# Guaiacum officinale               1                     0
# Guaiacum sanctum                  1                     0
#
#                                                             Leaf composition  \
#                            opposite, whorls of 3, alternate        3 palmate
# Species
# Avicennia germinans                                       0                0
# Metopium brownei                                          0                0
# Handroanthus billbergii                                   0                0
# Bourreria succulenta                                      0                0
# Bursera karsteniana                                       0                0
# Bursera simaruba                                          0                0
# Bursera tomentosa                                         0                0
# Cynophalla flexuosa                                       0                0
# Cynophalla hastata                                        0                0
# Quadrella indica                                          0                0
# Quadrella odoratissima                                    0                0
# Crossopetalum rhacoma                                     1                0
# Maytenus tetragona                                        0                0
# Maytenus versluysii                                       0                0
# Clusia rosea                                              0                0
# Conocarpus erectus                                        0                0
# Laguncularia racemosa                                     0                0
# Erythroxylum havanense                                    0                0
# Croton niveus                                             0                0
# Hippomane mancinella                                      0                0
# Libidibia coriaria                                        0                0
# Pithecellobium unguis-cati                                0                0
# Prosopis juliflora                                        0                0
# Vachellia tortuosa                                        0                0
# Vitex compressa                                           0                0
# Vitex cymosa                                              0                0
# Trichilia trifolia                                        0                1
# Eugenia procera                                           0                0
# Guapira pacurero                                          0                0
# Coccoloba swartzii                                        0                0
# Coccoloba uvifera                                         0                0
# Krugiodendron ferreum                                     0                0
# Rhizophora mangle                                         0                0
# Guettarda roupalifolia                                    0                0
# Randia aculeata                                           0                0
# Amyris ignea                                              0                0
# Zanthoxylum monophyllum                                   0                0
# Casearia tremula                                          0                0
# Schoepfia schreberi                                       0                0
# Jacquinia arborea                                         0                0
# Guaiacum officinale                                       0                0
# Guaiacum sanctum                                          0                0
#
#                                                     ... Aril colour            \
#                            3-5 palmate 3-5 pinnate  ...      orange red white
# Species                                             ...
# Avicennia germinans                  0           0  ...           0   0     0
# Metopium brownei                     0           1  ...           0   0     0
# Handroanthus billbergii              0           1  ...           0   0     0
# Bourreria succulenta                 0           0  ...           0   0     0
# Bursera karsteniana                  0           0  ...           0   0     0
# Bursera simaruba                     0           0  ...           0   0     0
# Bursera tomentosa                    0           0  ...           0   0     0
# Cynophalla flexuosa                  0           0  ...           0   0     1
# Cynophalla hastata                   0           0  ...           0   0     1
# Quadrella indica                     0           0  ...           0   0     1
# Quadrella odoratissima               0           0  ...           0   0     1
# Crossopetalum rhacoma                0           0  ...           0   0     0
# Maytenus tetragona                   0           0  ...           0   0     1
# Maytenus versluysii                  0           0  ...           0   0     1
# Clusia rosea                         0           0  ...           1   0     0
# Conocarpus erectus                   0           0  ...           0   0     0
# Laguncularia racemosa                0           0  ...           0   0     0
# Erythroxylum havanense               0           0  ...           0   0     0
# Croton niveus                        0           0  ...           0   0     0
# Hippomane mancinella                 0           0  ...           0   0     0
# Libidibia coriaria                   0           0  ...           0   0     0
# Pithecellobium unguis-cati           0           0  ...           0   0     1
# Prosopis juliflora                   0           0  ...           0   0     0
# Vachellia tortuosa                   0           0  ...           0   0     0
# Vitex compressa                      1           0  ...           0   0     0
# Vitex cymosa                         1           0  ...           0   0     0
# Trichilia trifolia                   0           0  ...           1   0     0
# Eugenia procera                      0           0  ...           0   0     0
# Guapira pacurero                     0           0  ...           0   0     0
# Coccoloba swartzii                   0           0  ...           0   0     0
# Coccoloba uvifera                    0           0  ...           0   0     0
# Krugiodendron ferreum                0           0  ...           0   0     0
# Rhizophora mangle                    0           0  ...           0   0     0
# Guettarda roupalifolia               0           0  ...           0   0     0
# Randia aculeata                      0           0  ...           0   0     0
# Amyris ignea                         0           0  ...           0   0     0
# Zanthoxylum monophyllum              0           0  ...           0   0     0
# Casearia tremula                     0           0  ...           1   0     0
# Schoepfia schreberi                  0           0  ...           0   0     0
# Jacquinia arborea                    0           0  ...           0   0     0
# Guaiacum officinale                  0           0  ...           0   1     0
# Guaiacum sanctum                     0           0  ...           0   1     0
#
#                                        Seed colour                         \
#                            yellow-geen       black brown green grey white
# Species
# Avicennia germinans                  0           0     0     1    0     0
# Metopium brownei                     0           0     0     0    0     0
# Handroanthus billbergii              0           0     0     0    0     0
# Bourreria succulenta                 0           0     0     0    0     0
# Bursera karsteniana                  0           0     0     0    0     0
# Bursera simaruba                     0           0     0     0    0     0
# Bursera tomentosa                    0           0     0     0    0     0
# Cynophalla flexuosa                  0           1     0     0    0     0
# Cynophalla hastata                   0           1     0     0    0     0
# Quadrella indica                     0           1     0     0    0     0
# Quadrella odoratissima               0           1     0     0    0     0
# Crossopetalum rhacoma                0           0     0     0    0     0
# Maytenus tetragona                   0           1     0     0    0     0
# Maytenus versluysii                  0           1     0     0    0     0
# Clusia rosea                         0           0     0     0    0     0
# Conocarpus erectus                   0           0     0     0    0     0
# Laguncularia racemosa                0           0     0     1    0     0
# Erythroxylum havanense               0           0     0     0    0     0
# Croton niveus                        0           0     0     0    0     0
# Hippomane mancinella                 0           0     0     0    1     0
# Libidibia coriaria                   0           0     1     0    0     0
# Pithecellobium unguis-cati           0           1     0     0    0     0
# Prosopis juliflora                   1           0     1     0    0     0
# Vachellia tortuosa                   0           0     1     0    0     0
# Vitex compressa                      0           0     0     0    0     0
# Vitex cymosa                         0           0     0     0    0     0
# Trichilia trifolia                   0           0     0     0    0     1
# Eugenia procera                      0           1     0     0    0     0
# Guapira pacurero                     0           1     0     0    0     0
# Coccoloba swartzii                   0           1     0     0    0     0
# Coccoloba uvifera                    0           1     0     0    0     0
# Krugiodendron ferreum                0           1     0     0    0     0
# Rhizophora mangle                    0           0     0     1    0     0
# Guettarda roupalifolia               0           0     1     0    0     0
# Randia aculeata                      0           0     1     0    0     0
# Amyris ignea                         0           0     0     0    0     0
# Zanthoxylum monophyllum              0           0     1     0    0     0
# Casearia tremula                     0           1     0     0    0     0
# Schoepfia schreberi                  0           0     0     0    0     0
# Jacquinia arborea                    0           0     1     0    0     0
# Guaiacum officinale                  0           0     1     0    0     0
# Guaiacum sanctum                     0           0     1     0    0     0
#
#
#                            whitish
# Species
# Avicennia germinans              0
# Metopium brownei                 0
# Handroanthus billbergii          1
# Bourreria succulenta             0
# Bursera karsteniana              0
# Bursera simaruba                 0
# Bursera tomentosa                0
# Cynophalla flexuosa              0
# Cynophalla hastata               0
# Quadrella indica                 0
# Quadrella odoratissima           0
# Crossopetalum rhacoma            0
# Maytenus tetragona               0
# Maytenus versluysii              0
# Clusia rosea                     0
# Conocarpus erectus               0
# Laguncularia racemosa            0
# Erythroxylum havanense           0
# Croton niveus                    0
# Hippomane mancinella             0
# Libidibia coriaria               0
# Pithecellobium unguis-cati       0
# Prosopis juliflora               0
# Vachellia tortuosa               0
# Vitex compressa                  0
# Vitex cymosa                     0
# Trichilia trifolia               0
# Eugenia procera                  0
# Guapira pacurero                 0
# Coccoloba swartzii               0
# Coccoloba uvifera                0
# Krugiodendron ferreum            0
# Rhizophora mangle                0
# Guettarda roupalifolia           0
# Randia aculeata                  0
# Amyris ignea                     0
# Zanthoxylum monophyllum          0
# Casearia tremula                 0
# Schoepfia schreberi              0
# Jacquinia arborea                0
# Guaiacum officinale              0
# Guaiacum sanctum                 0
#
# [42 rows x 202 columns]

# %% [markdown]
# #### Data Pierre

# %%
file_name = root + 'Dataset_Pierre.csv'
df_Pierre = pd.read_csv(file_name, header=[0, 1]) 
df_Pierre = df_Pierre.iloc[: , 1:]
df_Pierre = df_Pierre.set_index(df_Pierre['Species']['species'])
df_Pierre = df_Pierre.drop(columns=['Species', 'XXX'])
for i in df_Pierre:
    print(i)
# Out:
# ('plant type', 'Tree')
# ('plant type', 'Shrub')
# ('plant type', 'Bush')
# ('plant type', 'Ficus strangler')
# ('plant type', 'Liana')
# ('plant type', 'Parasitic')
# ('plant type', 'Palm tree')
# ('plant type', 'Herbaceous')
# ('phyllotaxis', 'Phyllotaxis alternate')
# ('phyllotaxis', 'Opposite phyllotaxis')
# ('phyllotaxis', 'Phyllotaxis whorled')
# ('trunk and root', 'Base of trunk straight')
# ('trunk and root', 'Base of trunk flared')
# ('trunk and root', 'Foothills')
# ('trunk and root', 'Stilt roots')
# ('trunk and root', 'Aerial roots')
# ('latex', 'No exudate')
# ('latex', 'Clear latex')
# ('latex', 'Clear gum or resin')
# ('latex', 'White latex')
# ('latex', 'Yellow latex')
# ('latex', 'Dark gum or resin')
# ('crown', 'Regular density of the crown')
# ('crown', 'Leaves grouped at the top of the axes')
# ('crown', 'Horizontally spreading crowns')
# ('crown', 'drooping axles')
# ('crown', 'Stepped crown')
# ('crown', 'Candelabra-shaped crown')
# ('stem shape', 'Circular stem section')
# ('stem shape', 'Square stem section')
# ('bark', 'Smooth bark')
# ('bark', 'Finely fissured bark')
# ('bark', 'Presence of spines or prickles on the trunk')
# ('bark', 'Papyrus bark')
# ('bark', 'Bark peeling in patches')
# ('bark', 'Cracked bark')
# ('bark color', 'Slice in light bark')
# ('bark color', 'Slice through pink bark')
# ('bark color', 'Slice through red bark')
# ('bark color', 'Slice through brown bark')
# ('bark color', 'Slice through orange bark with green rhytidome')
# ('bark color', 'Slice through yellow bark with green rhytidome')
# ('bark color', 'Slice through light bark with red mottling')
# ('bark color', 'Slice through yellow bark with brown mottling')
# ('leaf shape', 'Simple leaf')
# ('leaf shape', 'Bifoliate leaf')
# ('leaf shape', 'Trifoliate leaf')
# ('leaf shape', 'Digitized leaf')
# ('leaf shape', 'Leaves transformed into scales')
# ('leaf shape', 'Paripinnate leaf')
# ('leaf shape', 'Unipinnate leaf with opposite leaflets')
# ('leaf shape', 'Imperipinnate leaf with alternate leaflets')
# ('leaf shape', 'Bipinnate leaf')
# ('leaf shape', 'Three-pinnate leaf')
# ('petiole', 'Sessile leaf')
# ('petiole', 'Petiolated leaf')
# ('petiole', 'Petiole canaliculate')
# ('petiole', 'Petiole with glands')
# ('petiole', 'Winged petiole')
# ('petiole', 'Petiole with glandular hairs')
# ('leaf blade', 'Linear leaf blade')
# ('leaf blade', 'lanceolate blade')
# ('leaf blade', 'elliptical blade')
# ('leaf blade', 'obovate blade')
# ('leaf blade', 'obtriangular blade')
# ('leaf blade', 'asymmetrical blade')
# ('leaf blade', 'orbicular blade')
# ('leaf blade', 'bilobed blade')
# ('leaf blade', 'lobed blade')
# ('leaf blade', 'leaf with deep lobes')
# ('leaf margin', 'Smooth leaf margin')
# ('leaf margin', 'Margin of the wavy leaf')
# ('leaf margin', 'Margin of crenate leaf')
# ('leaf margin', 'Margin of toothed leaf')
# ('leaf base', 'Leaf base attenuated')
# ('leaf base', 'Rounded leaf base')
# ('leaf base', 'Leaf base cordate')
# ('leaf base', 'Leaf base with glands')
# ('leaf apex', 'Leaf apex sharp corner')
# ('leaf apex', 'Leaf apex with wide corners')
# ('leaf apex', 'Leaf apex acuminate')
# ('leaf apex', 'Leaf apex apiculate')
# ('leaf apex', 'Leaf apex mucronate')
# ('leaf apex', 'Rounded leaf apex')
# ('leaf apex', 'Leaf apex emarginated')
# ('vein', 'Only the main vein is visible')
# ('vein', 'Pinnate venation with secondary veins intersecting the edge of the leaf blade')
# ('vein', 'Pinnate venation with secondary veins connecting near the margin of the blade')
# ('vein', 'Blade trinervate at base')
# ('vein', 'Palmate venation with at least 5 main veins')
# ('tendril', 'Plant without tendrils')
# ('tendril', 'Plant with tendrils, or one that rolls up on a support')
# ('spine', 'Plant without spines')
# ('spine', '2 straight prickles at the base of the petiole')
# ('spine', '1 straight and 1 hooked spine at base of petiole')
# ('spine', '2 hooked spines at base of petiole')
# ('spine', 'Hooked spines randomly distributed on the axes')
# ('spine', 'Spines resulting from transformation of a shoot or petiole')
# ('spine', '3 prickles at base of petiole, 2 pointing upwards')
# ('spine', '3 spines at base of petiole, pointing downwards')
# ('blade color', 'Uniformly coloured blade')
# ('blade color', 'Leaf blade discoloured')
# ('fruit', 'Drupe, or drupe-like fruit')
# ('fruit', 'Berry, or berry-like fruit')
# ('fruit', 'Capsule')
# ('fruit', 'Pod')
# ('fruit', 'Follicle')
# ('fruit', 'Achene')
# ('fruit', 'Winged fruit')
# ('inflorescences', 'Flower isolated or in groups of 2 or 3')
# ('inflorescences', 'Spike of flowers or inflorescences')
# ('inflorescences', 'Rootlet or cluster of flowers or inflorescences')
# ('inflorescences', 'Corymb of flowers or inflorescences')
# ('inflorescences', 'Umbel of flowers or inflorescences')
# ('inflorescences', 'Fascicle of flowers or inflorescences')
# ('inflorescences', 'Glomerule of flowers or inflorescences')
# ('inflorescences', 'Cyme of flowers or inflorescences')
# ('inflorescences', 'Flower head')
# ('inflorescences', 'Panicle of flowers or inflorescences')
# ('sexuality', 'Axillary sexuality')
# ('sexuality', 'Terminal sexuality')
# ('flower color', 'White flower')
# ('flower color', 'Pink coloured flower')
# ('flower color', 'Red coloured flower')
# ('flower color', 'Yellow coloured flower')
# ('flower color', 'Green coloured flower')
# ('flower shape', 'Single-petalled flower')
# ('flower shape', 'Three-petalled flower')
# ('flower shape', 'Four-petalled flower')
# ('flower shape', 'Five-petalled flower')
# ('flower shape', 'Flower with 6 or more petals')
# ('flower shape', 'Tubular flower')
# ('flower shape', 'Butterfly-shaped flower')
# ('flower shape', 'Apetal flower')
# /var/folders/0p/7b4jnnp15d5gx16h36l4ycx00000gn/T/ipykernel_86495/3964626144.py:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_Pierre = df_Pierre.drop(columns=['Species', 'XXX'])

# %% [markdown]
# #### Data Palms

# %%
file_name = root + 'Dataset_Kissling.txt'
df_Daniel = pd.read_csv(file_name,
                 sep='\t', encoding='Latin-1')
palm_species = df_Daniel[~df_Daniel.isnull().any(axis=1)]['SpecName'].values
df_Daniel.set_index('SpecName', inplace=True)

### RESHAPE DATA FOR PALMS

# Exclude string types
df_Daniels_int = df_Daniel.select_dtypes(exclude=[object])
df_Daniels_str = df_Daniel.select_dtypes(include=[object])
# Drop numbers
df_Daniels_semi_ints = df_Daniels_int.loc[:, df_Daniels_int.max() <= 3]
# Merge again
df_Daniel_edit = pd.merge(df_Daniels_str, df_Daniels_semi_ints, left_index=True, right_index=True)


# Real numbers:
df_Daniels_real_ints = df_Daniels_int.loc[:, df_Daniels_int.max() >= 3]
columns = [
    ("Measurement", "Maximum Stem Height"),
    ("Measurement", "Maximum Stem Diameter"),
    ("Measurement", "Maximum Leaf Number"),
    ("Measurement", "Maximum Leaf Blade Length"),
    ("Measurement", "Maximum Rachis Length"),
    ("Measurement", "Maximum Petiole Length"),
    ("Measurement", "Average Fruit Length"),
    ("Measurement", "Minimum Fruit Length"),
    ("Measurement", "Maximum Fruit Length"),
    ("Measurement", "Average Fruit Width"),
    ("Measurement", "Minimum Fruit Width"),
    ("Measurement", "Maximum Fruit Width"),
]

df_Daniels_real_ints.columns = pd.MultiIndex.from_tuples(columns)
df_Daniels_real_ints

# Get colors as lst of lsts 
FruitColorDescription_colors_lst = []

for palm_colors in df_Daniels_str['FruitColorDescription'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        FruitColorDescription_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        FruitColorDescription_colors_lst.append([])

MainFruitColors_colors_lst = []

for palm_colors in df_Daniels_str['MainFruitColors'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        MainFruitColors_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        MainFruitColors_colors_lst.append([])

# Init SKlearn MLB
mlb = MultiLabelBinarizer()

# Create dummies for color columns
df_FruitColorDescription = pd.DataFrame(
    {
        'FruitColorDescription': FruitColorDescription_colors_lst
    }, columns=['FruitColorDescription'])

s = df_FruitColorDescription['FruitColorDescription']
df_FruitColorDescription = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour Description', column) for column in df_FruitColorDescription.columns]
df_FruitColorDescription.columns = pd.MultiIndex.from_tuples(columns)

# Create dummies for color columns
df_MainFruitColors = pd.DataFrame(
    {
        'MainFruitColors': MainFruitColors_colors_lst
    }, columns=['MainFruitColors'])

s = df_MainFruitColors['MainFruitColors']
df_MainFruitColors = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour', column) for column in df_MainFruitColors.columns]
df_MainFruitColors.columns = pd.MultiIndex.from_tuples(columns)

df_Daniels_str_non_color = df_Daniels_str[['UnderstoreyCanopy', 'FruitSizeCategorical', 'FruitShape', 'Conspicuousness']]

# df_Daniels_str_non_color.columns = pd.MultiIndex.from_tuples(
#     [
#         ('Crown', 'UnderstoreyCanopy'),
#         ('Fruit Size', 'FruitSizeCategorical'),
#         ('Fruit Shape', 'FruitShape'),
#         ('Conspicuousness', 'Conspicuousness'),
#     ]
# )

df_Daniels_str_non_color_dummies = pd.get_dummies(df_Daniels_str_non_color)
columns = []
for column in df_Daniels_str_non_color_dummies.columns:
    level0, level1 = column.split('_')
    if level0 == 'UnderstoreyCanopy':
        level0 = 'Crown'
    elif level0 == 'FruitSizeCategorical':
        level0 = 'Fruit Size'
    elif level0 == 'FruitShape':
        level0 = 'Fruit Shape'
    elif level0 == 'Conspicuousness':
        level0 = 'Conspicuousness'
    columns.append((level0, level1))
    
df_Daniels_str_non_color_dummies.columns = pd.MultiIndex.from_tuples(columns)

### JOIN ALL DATA
data_frames = [df_FruitColorDescription, df_MainFruitColors, df_Daniels_str_non_color_dummies, df_Daniels_real_ints]
df_Daniel_merged = pd.concat(data_frames, axis=1)
df_Daniel_merged
# Out:
#                          Fruit Colour Description                             \
#                                             black blue bluish brown brownish
# SpecName
# Acanthophoenix crinita                          1    0      0     0        0
# Acanthophoenix rousselii                        1    0      0     0        0
# Acanthophoenix rubra                            1    0      0     0        0
# Acoelorrhaphe wrightii                          1    0      0     1        0
# Acrocomia aculeata                              0    0      0     0        0
# ...                                           ...  ...    ...   ...      ...
# Wettinia quinaria                               0    0      0     1        0
# Wettinia radiata                                0    0      0     0        0
# Wettinia verruculosa                            0    0      0     1        0
# Wodyetia bifurcata                              0    0      0     0        0
# Zombia antillarum                               0    0      0     0        0
#
#                                                                   ...  \
#                          chocolate coral crimson darkgreen green  ...
# SpecName                                                          ...
# Acanthophoenix crinita           0     0       0         0     0  ...
# Acanthophoenix rousselii         0     0       0         0     0  ...
# Acanthophoenix rubra             0     0       0         0     0  ...
# Acoelorrhaphe wrightii           0     0       0         0     0  ...
# Acrocomia aculeata               0     0       0         0     1  ...
# ...                            ...   ...     ...       ...   ...  ...
# Wettinia quinaria                0     0       0         0     1  ...
# Wettinia radiata                 0     0       0         0     0  ...
# Wettinia verruculosa             0     0       0         0     1  ...
# Wodyetia bifurcata               0     0       0         0     0  ...
# Zombia antillarum                0     0       0         0     0  ...
#
#                                  Measurement                            \
#                          Maximum Leaf Number Maximum Leaf Blade Length
# SpecName
# Acanthophoenix crinita                  15.0                      2.30
# Acanthophoenix rousselii                 NaN                      3.00
# Acanthophoenix rubra                    20.0                      3.10
# Acoelorrhaphe wrightii                  25.0                      1.30
# Acrocomia aculeata                      30.0                      3.50
# ...                                      ...                       ...
# Wettinia quinaria                        6.0                      5.50
# Wettinia radiata                         6.0                      4.33
# Wettinia verruculosa                     6.0                      6.00
# Wodyetia bifurcata                      10.0                      3.20
# Zombia antillarum                       12.0                      1.20
#
#                                                                        \
#                          Maximum Rachis Length Maximum Petiole Length
# SpecName
# Acanthophoenix crinita                     NaN                    NaN
# Acanthophoenix rousselii                   NaN                    NaN
# Acanthophoenix rubra                       3.0                    NaN
# Acoelorrhaphe wrightii                     0.7                   0.65
# Acrocomia aculeata                         2.5                    NaN
# ...                                        ...                    ...
# Wettinia quinaria                          3.2                   1.35
# Wettinia radiata                           3.4                    NaN
# Wettinia verruculosa                       3.7                   2.40
# Wodyetia bifurcata                         2.3                   1.02
# Zombia antillarum                          1.0                    NaN
#
#                                                                     \
#                          Average Fruit Length Minimum Fruit Length
# SpecName
# Acanthophoenix crinita                   0.65                  0.6
# Acanthophoenix rousselii                 2.00                  NaN
# Acanthophoenix rubra                     1.00                  NaN
# Acoelorrhaphe wrightii                   0.70                  NaN
# Acrocomia aculeata                       4.25                  3.5
# ...                                       ...                  ...
# Wettinia quinaria                        2.75                  2.0
# Wettinia radiata                         4.00                  3.0
# Wettinia verruculosa                     2.50                  NaN
# Wodyetia bifurcata                       5.75                  5.0
# Zombia antillarum                        1.75                  NaN
#
#                                                                    \
#                          Maximum Fruit Length Average Fruit Width
# SpecName
# Acanthophoenix crinita                    0.7                0.50
# Acanthophoenix rousselii                  NaN                0.80
# Acanthophoenix rubra                      NaN                0.70
# Acoelorrhaphe wrightii                    NaN                0.70
# Acrocomia aculeata                        5.0                4.60
# ...                                       ...                 ...
# Wettinia quinaria                         3.5                2.00
# Wettinia radiata                          4.0                2.00
# Wettinia verruculosa                      NaN                1.50
# Wodyetia bifurcata                        6.5                4.35
# Zombia antillarum                         NaN                1.75
#
#
#                          Minimum Fruit Width Maximum Fruit Width
# SpecName
# Acanthophoenix crinita                   NaN                 NaN
# Acanthophoenix rousselii                 NaN                 NaN
# Acanthophoenix rubra                     NaN                 NaN
# Acoelorrhaphe wrightii                   0.5                 0.9
# Acrocomia aculeata                       3.8                 5.4
# ...                                      ...                 ...
# Wettinia quinaria                        1.5                 2.5
# Wettinia radiata                         NaN                 NaN
# Wettinia verruculosa                     NaN                 NaN
# Wodyetia bifurcata                       2.7                 6.0
# Zombia antillarum                        1.5                 2.0
#
# [2557 rows x 69 columns]

# %% [markdown]
# ## Prediction Data

# %% [markdown]
# ### Load Data

# %%
root = "../../data/processed/"
sentences_all = {}

f = open(F"{root}Sentences_Pierre.pkl", 'rb')
sentences_Pierre = pickle.load(f)
sentences_all |= sentences_Pierre 

f = open(F"{root}Sentences_Andrei.pkl", 'rb')
sentences_Andrei = pickle.load(f)
sentences_all |= sentences_Andrei 

f = open(F"{root}Sentences_Kissling.pkl", 'rb')
sentences_Kissling = pickle.load(f)
sentences_all |= sentences_Kissling 

# Drop duplicates
for species, sentences in sentences_all.items():
    sentences_all[species] = list(set(sentences))

# %% [markdown]
# ### Match Data

# %%
k= 5
google_form_lst = []

for idx, (species, sentences) in enumerate(tqdm(sentences_all.items())):

    # if idx < 400:
    #     continue
    # if species != 'Dypsis thiryana':
    #     continue
    
    df_select = [df_Andrei_dummies, df_Pierre, df_Daniel_merged]
    if species in df_Andrei_dummies.index:
        df_select = df_select[0]
    elif species in df_Pierre.index:
        df_select = df_select[1]
    elif species in df_Daniel_merged.index:
        df_select = df_select[2]
    else:
        raise ValueError

    for gt_main_trait in df_select.columns.get_level_values(0).unique():
        if gt_main_trait == 'Measurement':
            df_subset = df_select[df_select.index == species][gt_main_trait]
            # Not really efficient, use PD?
    
            subtraits = list(df_subset.columns)
            values = df_subset.values[0]
            for sub_trait, value in zip(subtraits, values):

                df_sent  = F"{sub_trait} {value}"

                top_list = []

                for sentence in sentences:
                    gt_sim = jaccard_similarity(sentence, df_sent)
                    top_list.append((gt_sim, sentence))

                top_list.sort(reverse=True)
                top_k_list = [sentence for (_, sentence) in top_list[0:k]]

                google_form_lst.append((species, gt_main_trait, sub_trait, df_sent, *top_k_list))
        else:
            df_subset = df_select[df_select.index == species][gt_main_trait]
            present_traits = df_subset.loc[:, df_subset.any()].columns.values
            df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)

            top_list = []

            for sentence in sentences:
                gt_sim = jaccard_similarity(sentence, df_sent)
                top_list.append((gt_sim, sentence))

            top_list.sort(reverse=True)
            top_k_list = [sentence for (_, sentence) in top_list[0:k]]

            google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list))
# Out:
# 100%|██████████| 647/647 [00:16<00:00, 38.85it/s]

# %% [markdown]
# ### Create Subset

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5'])
df_google
# Out:
#                       Species      Main Trait         GT Main Trait  \
# 0      Acacia amythethophylla      plant type            plant type
# 1      Acacia amythethophylla     phyllotaxis           phyllotaxis
# 2      Acacia amythethophylla  trunk and root        trunk and root
# 3      Acacia amythethophylla           latex                 latex
# 4      Acacia amythethophylla           crown                 crown
# ...                       ...             ...                   ...
# 13681      Wodyetia bifurcata     Measurement  Minimum Fruit Length
# 13682      Wodyetia bifurcata     Measurement  Maximum Fruit Length
# 13683      Wodyetia bifurcata     Measurement   Average Fruit Width
# 13684      Wodyetia bifurcata     Measurement   Minimum Fruit Width
# 13685      Wodyetia bifurcata     Measurement   Maximum Fruit Width
#
#                          GT Sub Traits  \
# 0                        [Tree, Shrub]
# 1              [Phyllotaxis alternate]
# 2             [Base of trunk straight]
# 3                         [No exudate]
# 4      [Horizontally spreading crowns]
# ...                                ...
# 13681         Minimum Fruit Length 5.0
# 13682         Maximum Fruit Length 6.5
# 13683         Average Fruit Width 4.35
# 13684          Minimum Fruit Width 2.7
# 13685          Maximum Fruit Width 6.0
#
#                                                        1  \
# 0      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 1             The branch bark is apparently 1.5% approx.
# 2      Fruits flat, reddish-brown, remaining on the t...
# 3                   Flower-heads abundant golden yellow.
# 4      Inflorescence large, terminal, much-branched, ...
# ...                                                  ...
# 13681                    Mature height averages 25 feet.
# 13682          Immature green fruit of the Foxtail Palm.
# 13683                    Mature height averages 25 feet.
# 13684                      Mature red fruit on Wodyetia.
# 13685                         Foxtail Palm Tree: Medium.
#
#                                                        2  \
# 0             The branch bark is apparently 1.5% approx.
# 1      Pinnae sometimes 20 or more pairs, with 50 or ...
# 2                                 Fruit flat, dehiscent.
# 3                                 Fruit flat, dehiscent.
# 4      Stipules spinescent, stout, brown, glossy, com...
# ...                                                  ...
# 13681          Immature green fruit of the Foxtail Palm.
# 13682               Foxtail Palm Tree: Large Multi Stem.
# 13683  Washingtonia robusta Agave americana Scroll to...
# 13684  Fruit is 2.inches long, deep orange to deep re...
# 13685                      Mature red fruit on Wodyetia.
#
#                                                        3  \
# 0                   Perennial, Not climbing, Shrub/Tree.
# 1      Inflorescence large, terminal, much-branched, ...
# 2                 Young plants 6-8 months old from seed.
# 3                 Young plants 6-8 months old from seed.
# 4      Flowers orange or yellow, strongly and sweetly...
# ...                                                  ...
# 13681                    Fruit showing remains of style.
# 13682        Orange fallen fruit below the Foxtail Palm.
# 13683  Leaf color is green to dull green with no silv...
# 13684                        Palm Fruits: Red when ripe.
# 13685          Immature green fruit of the Foxtail Palm.
#
#                                                        4  \
# 0                   Flower-heads abundant golden yellow.
# 1      Acacia confusa - Stem Smaller peaks suspected ...
# 2      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 3                   Perennial, Not climbing, Shrub/Tree.
# 4                   Flower-heads abundant golden yellow.
# ...                                                  ...
# 13681           More than 15 m.- Less than 15 m. Thorns.
# 13682                    Mature height averages 25 feet.
# 13683                     Fruit on ground below Foxtail.
# 13684                            Fruits : 2 inches long.
# 13685            Christmas Palm Tree: Medium Multi Stem.
#
#                                                        5
# 0      Inflorescence large, terminal, much-branched, ...
# 1                   Flower-heads abundant golden yellow.
# 2                   Flower-heads abundant golden yellow.
# 3      Fruits flat, reddish-brown, remaining on the t...
# 4      Acacia confusa - Stem Smaller peaks suspected ...
# ...                                                  ...
# 13681                            Fruits : 2 inches long.
# 13682                    Fruit showing remains of style.
# 13683  Leaves: Pinnate , reduplicate , arching, to 3 ...
# 13684  Fruits are 2 inches long, egg shaped, and oran...
# 13685  Fruit is 2.inches long, deep orange to deep re...
#
# [13686 rows x 9 columns]

# %%
df_google_subset = df_google\
                    .dropna()\
                    .sample(n=20, axis=0, random_state=123)\

df_google_subset
# Out:
#                        Species       Main Trait         GT Main Trait  \
# 8361   Handroanthus billbergii    Thorns/spines         Thorns/spines
# 12      Acacia amythethophylla        leaf base             leaf base
# 3837           Flueggea virosa   inflorescences        inflorescences
# 19      Acacia amythethophylla   inflorescences        inflorescences
# 5992      Pavetta cinereifolia        leaf base             leaf base
# 8038           Vitex madiensis       leaf blade            leaf blade
# 11738   Kentiopsis oliviformis      Measurement  Maximum Fruit Length
# 7096   Steganotaenia araliacea      leaf margin           leaf margin
# 1676             Cassia arereh        sexuality             sexuality
# 6285        Prosopis juliflora  Leaf lower side       Leaf lower side
# 5024          Lawsonia inermis       leaf blade            leaf blade
# 4063            Grewia bicolor          tendril               tendril
# 7964       Vitellaria paradoxa       stem shape            stem shape
# 10556      Desmoncus giganteus            Crown                 Crown
# 12125      Normanbya normanbyi  Conspicuousness       Conspicuousness
# 12740         Ravenea louvelii      Measurement   Maximum Leaf Number
# 12213     Oenocarpus distichus       Fruit Size            Fruit Size
# 5782       Opilia celtidifolia          petiole               petiole
# 2079      Combretum glutinosum          petiole               petiole
# 11577    Hydriastele hombronii      Measurement   Average Fruit Width
#
#                                            GT Sub Traits  \
# 8361                                            [absent]
# 12             [Leaf base attenuated, Rounded leaf base]
# 3837   [Fascicle of flowers or inflorescences, Glomer...
# 19     [Glomerule of flowers or inflorescences, Panic...
# 5992                              [Leaf base attenuated]
# 8038                   [elliptical blade, obovate blade]
# 11738                           Maximum Fruit Length 2.0
# 7096                            [Margin of toothed leaf]
# 1676                                [Terminal sexuality]
# 6285                                          [glabrous]
# 5024                   [elliptical blade, obovate blade]
# 4063                            [Plant without tendrils]
# 7964                             [Circular stem section]
# 10556                                           [canopy]
# 12125                                      [conspicuous]
# 12740                           Maximum Leaf Number 14.0
# 12213                                            [small]
# 5782                                   [Petiolated leaf]
# 2079                                   [Petiolated leaf]
# 11577                          Average Fruit Width 0.625
#
#                                                        1  \
# 8361                Definition: whole plant arborescent.
# 12     Fruits flat, reddish-brown, remaining on the t...
# 3837   Flowers in axillary.fascicles, bracts triangul...
# 19     Pinnae sometimes 20 or more pairs, with 50 or ...
# 5992   General Information Shrubs, small trees, or in...
# 8038   V. doniana , especially in leaflet shape, but ...
# 11738  Trunk to 30 m tall, 25 cm dbh, gray, base thic...
# 7096   Mericarps with 3 distinct dorsal ribs which ma...
# 1676                      Perennial, Not climbing, Tree.
# 6285               Leaflets sub-linear and sub-glabrous.
# 5024   The fruit is usually a capsule, the testa of a...
# 4063           Leaves almost white beneath Provided by:.
# 7964   Some of the fruits produced from open pollinat...
# 10556         Leaflets ovoid and have a wavy appearance.
# 12125                                      Open / Close.
# 12740         Leaves. pinnate with two or more leaflets.
# 12213  Moderate to massive, solitary or clustered, un...
# 5782   Triterpenoid saponins from Opilia celtidifolia...
# 2079   Petals and filaments cream or yellow Provided ...
# 11577  A tall, solitary palm, to 15-20 m in height, s...
#
#                                                        2  \
# 8361                Fruit an elongate dehiscent capsule.
# 12                  Flower-heads abundant golden yellow.
# 3837    Inflorescences fascicles or racemes to panicles.
# 19     Fruits flat, reddish-brown, remaining on the t...
# 5992   Leaves opposite or rarely whorled, usually wit...
# 8038                Definition: whole plant arborescent.
# 11738  Under the right light, the leaves have a bluis...
# 7096   Leaflet margins are conspicuously serrated, th...
# 1676                Definition: whole plant arborescent.
# 6285     The edge of the fruit without parallel margins.
# 5024   Description Small, arid tropical bush, usually...
# 4063       The fruit is edible, sweetish but astringent.
# 7964   Fruit: subglobose or elongate berries about 5 ...
# 10556  Clustering spiny climbing palms of Central and...
# 12125                                Plumose. , pinnate.
# 12740  The inflorescence is short, borne among the le...
# 12213  It forms a slender, solitary trunk to 10 m or ...
# 5782   Leaves lanceolate to elliptic with medifixed h...
# 2079                     Its growth is fast and profuse.
# 11577  Fruit 14-17 X 6-6.5 mm, ripening dull red, see...
#
#                                                        3  \
# 8361   Wings thin and sharply demarcated from seed body.
# 12     Acacia confusa - Root Smaller peaks suspected ...
# 3837   Flowers in.axillary fascicles, bracts triangul...
# 19     Acacia confusa - Stem Smaller peaks suspected ...
# 5992   Stamens 4, inserted in corolla throat, exserte...
# 8038                      Ovary globose with few glands.
# 11738                       Looks nothing like a kentia.
# 7096            Compound umbels of small, white flowers.
# 1676   Brown cylindrical pods 1â2 ft. long, splitti...
# 6285                  Leaflets oblong and sub-pubescent.
# 5024   The leaves gradually yellow and fall during pr...
# 4063   The many stamens spread in a cluster around th...
# 7964   Keywords Fruit set Inflorescence Insect pollin...
# 10556  Chelyocarpus is a genus of small to medium-siz...
# 12125  Moderate to tall, solitary, unarmed, pleonanth...
# 12740  Seeds, globose, hemispherical or representing ...
# 12213  Seed ovoid-ellipsoidal to globose, hilum basal...
# 5782                             Petals up to 2 Ã 1 mm.
# 2079   The fruit is a four-winged elliptic samara, an...
# 11577                              Palm Traits 1.0.0.625
#
#                                                        4  \
# 8361   The calyx is 5-dentate and campanulate to cupu...
# 12                                Fruit flat, dehiscent.
# 3837               Fruit white, c. 4 mm across, globose.
# 19     Inflorescence large, terminal, much-branched, ...
# 5992   Shrubs or small trees, occasionally suffrutice...
# 8038         Leaves digitately compound with 5 leaflets.
# 11738  Leaves of juvenile individuals spirally arrang...
# 7096   Steganotaenia araliacea variation araliacea fl...
# 1676                      Savannah tree, to 30 ft. high.
# 6285          Interfoliar glands frequent to occasional.
# 5024   Leaves of henna plant are entire, opposite, su...
# 4063   Androgynophore with a glabrous basal portion u...
# 7964   Inflorescences in dense umbels of 30-40 flower...
# 10556                Definition: whole plant herbaceous.
# 12125  Each palm can bear up to three inflorescences/...
# 12740  A short, litter collecting palm of the underst...
# 12213  Stem erect, densely covered in fibrous leaf sh...
# 5782   Shrub, scandent or occasionally erect, young b...
# 2079         Savannah tree, to 35 ft. high Provided by:.
# 11577          The leaves are pinnate and widely varied.
#
#                                                        5
# 8361   The corolla is yellow, except in those four sp...
# 12                Young plants 6-8 months old from seed.
# 3837   Specimens with spiny branch ends also.occur wi...
# 19                                Fruit flat, dehiscent.
# 5992   Leaves opposite, occasionally ternate, sessile...
# 8038           Growing tips covered in long tawny hairs.
# 11738  A large solitary palm over 30 m. in height, 25...
# 7096   The pale green leaves with sharply toothed mar...
# 1676                                       Groundcovers.
# 6285   The stigma has a central depression into which...
# 5024   Flowers are small, numerous, aromatic, white o...
# 4063   The fruits are round, fleshy drupes relished b...
# 7964   The fruits resemble large plums 4 to 8 centime...
# 10556  Definitie: An autotroph which is capable of tr...
# 12125                       Seeds, about an inch across.
# 12740  Dioecious pinnate-leaved palms of Madagascar a...
# 12213  Fruit ellipsoidal to globose, dark purple when...
# 5782                              Ripe fruit up to 3 cm.
# 2079   The thick leathery green leaves have a gummy f...
# 11577  Staminate flowers l1 mm long, 4 mm wide, deep ...

# %% [markdown]
# ### Add Images

# %%
random_sample_species = df_google_subset['Species'].values

images_links = {}
for species in tqdm(random_sample_species):
    species_ = species.replace(' ', '_')
    try:
        img_url = get_wiki_main_image(species_)
        if img_url[-3:] != 'jpg':
            img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        # if img_url[-3:].isupper():
        #     img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        images_links[species] = img_url
    except:
        images_links[species] = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'

# df_google_subset = df_google[df_google['Species'].isin(random_sample_species)]
df_google_subset = df_google_subset.set_index('Species')
df_google_subset["URL"] = pd.Series(images_links)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset.csv', sep='\t')#, quoting=csv.QUOTE_ALL)
# Out:
# 100%|██████████| 20/20 [00:03<00:00,  5.58it/s]

# %%
df_google_subset
# Out:
#                                   Main Trait              GT Main Trait  \
# Species
# Hymenocardia heudelotii           leaf shape                 leaf shape
# Entada abyssinica                    tendril                    tendril
# Parajubaea torallyi          Conspicuousness            Conspicuousness
# Maranthes polyandra           inflorescences             inflorescences
# Prosopis africana             inflorescences             inflorescences
# Syagrus macrocarpa               Measurement  Maximum Leaf Blade Length
# Adenium obesum                     sexuality                  sexuality
# Chamaedorea warscewiczii         Measurement      Maximum Rachis Length
# Aphania senegalensis                   latex                      latex
# Cordia africana                  leaf margin                leaf margin
# Terminalia albida                  leaf apex                  leaf apex
# Acacia dudgeoni                   plant type                 plant type
# Plectocomiopsis geminiflora      Measurement        Maximum Fruit Width
# Syagrus glaucescens              Measurement       Average Fruit Length
# Tamarix senegalensis              plant type                 plant type
# Terminalia brownii                plant type                 plant type
# Combretum collinum                     crown                      crown
# Pseudophoenix vinifera            Fruit Size                 Fruit Size
# Hydriastele wendlandiana         Measurement        Maximum Stem Height
# Areca catechu                    Measurement        Minimum Fruit Width
#
#                                                                  GT Sub Traits  \
# Species
# Hymenocardia heudelotii                                          [Simple leaf]
# Entada abyssinica                                     [Plant without tendrils]
# Parajubaea torallyi                                                  [cryptic]
# Maranthes polyandra          [Corymb of flowers or inflorescences, Panicle ...
# Prosopis africana                         [Spike of flowers or inflorescences]
# Syagrus macrocarpa                               Maximum Leaf Blade Length 4.0
# Adenium obesum                                            [Terminal sexuality]
# Chamaedorea warscewiczii                             Maximum Rachis Length 0.5
# Aphania senegalensis                                              [No exudate]
# Cordia africana              [Smooth leaf margin, Margin of crenate leaf, M...
# Terminalia albida            [Leaf apex sharp corner, Leaf apex with wide c...
# Acacia dudgeoni                                                  [Tree, Shrub]
# Plectocomiopsis geminiflora                            Maximum Fruit Width 3.5
# Syagrus glaucescens                                   Average Fruit Length 2.5
# Tamarix senegalensis                                                   [Shrub]
# Terminalia brownii                                               [Tree, Shrub]
# Combretum collinum                              [Regular density of the crown]
# Pseudophoenix vinifera                                                 [small]
# Hydriastele wendlandiana                              Maximum Stem Height 25.0
# Areca catechu                                          Minimum Fruit Width 3.5
#
#                                                                              1  \
# Species
# Hymenocardia heudelotii      Species in this genus are dioecious , with mal...
# Entada abyssinica                                  Small tree, without thorns.
# Parajubaea torallyi          Large, solitary, unarmed, pleonanthic, monoeci...
# Maranthes polyandra          In its form of a bush about 5 meters high, it ...
# Prosopis africana            Towards the end of the growth season thick and...
# Syagrus macrocarpa           It is the tallest of all the species in the ge...
# Adenium obesum               The apex is rounded and the base tapers into a...
# Chamaedorea warscewiczii     The fruit is an orange or red drupe 0.5â2 cm...
# Aphania senegalensis         Fruit purplish red, fertile schizocarp ellipso...
# Cordia africana              The leaf margin is notched smooth or only slig...
# Terminalia albida                         Definition: whole plant arborescent.
# Acacia dudgeoni                             They have compound , broad leaves.
# Plectocomiopsis geminiflora  Moderate to robust, clustered, high-climbing, ...
# Syagrus glaucescens          An unusual palm, with a slender, solitary trun...
# Tamarix senegalensis         Broadleaved Perennial Seed propagated Shrub Tr...
# Terminalia brownii                            Terminalia , aerial part, fresh.
# Combretum collinum           The bark is rough, greyish to black, furrowed ...
# Pseudophoenix vinifera       Seed not adherent to endocarp at maturity, hil...
# Hydriastele wendlandiana     The sparse crown has 5 to 10 paripinnate frond...
# Areca catechu                    Fruits are orange to red and about 5 cm long.
#
#                                                                              2  \
# Species
# Hymenocardia heudelotii                   Shrub or small tree, to 30 ft. high.
# Entada abyssinica            Normal structure of dense elongated nucleus wa...
# Parajubaea torallyi                                          Tous nos rosiers.
# Maranthes polyandra          Polyandra Get care plan What is the plant Mara...
# Prosopis africana            The inflorescence comprises a solitary spike, ...
# Syagrus macrocarpa           Graceful undergrowth palms from eastern Brazil...
# Adenium obesum               They are full of small oblong seeds with tufts...
# Chamaedorea warscewiczii     Pistillate in rather lax spirals, 2 x 1.5-1.7 ...
# Aphania senegalensis                                        Voir -> autre nom.
# Cordia africana              Unlike most legumes, the fruits are thick and ...
# Terminalia albida                           All parts shining-silky-pubescent.
# Acacia dudgeoni                           Definition: whole plant arborescent.
# Plectocomiopsis geminiflora  Ripe fruit oblate, to 2.5 x 3 cm, covered in u...
# Syagrus glaucescens          Those species that have upright trunks grow 2â...
# Tamarix senegalensis                             A twiggy shrub or small tree.
# Terminalia brownii               Terminalia , aerial part, fresh | Feedipedia.
# Combretum collinum           During germination two strands joined at their...
# Pseudophoenix vinifera       The fruit is lobed when more than one seed dev...
# Hydriastele wendlandiana     The sparse crown has 5 to 10 paripinnate frond...
# Areca catechu                Morphology Page fan palm feather palm palmate ...
#
#                                                                              3  \
# Species
# Hymenocardia heudelotii                       They have simple , broad leaves.
# Entada abyssinica                                  A seed sprouting up slowly.
# Parajubaea torallyi                             It is developing a nice trunk.
# Maranthes polyandra          It has a gnarled, twisted trunk, and is often ...
# Prosopis africana                        Structures of the main flavonoidsâ¦.
# Syagrus macrocarpa           Stem erect, short, rarely exceeding 3 m, at fi...
# Adenium obesum                  The caudex is evident only in young specimens.
# Chamaedorea warscewiczii     Staminate with 15-25 rachillae, these 20-30 cm...
# Aphania senegalensis         Petals 5 or.sometimes 4, purplish red, broadly...
# Cordia africana              Most alternate arranged leaves are stalked usu...
# Terminalia albida                    A savannah shrub or tree, to 40 ft. high.
# Acacia dudgeoni                                                       Valider.
# Plectocomiopsis geminiflora  Fruit 1 -seeded, perianth whorls persistent an...
# Syagrus glaucescens                         The fronds are flat, rigid so far.
# Tamarix senegalensis                      Definition: whole plant arborescent.
# Terminalia brownii                  Terminalia , aerial part with pods, fresh.
# Combretum collinum                   Flowers yellow, cream or white, fragrant.
# Pseudophoenix vinifera       Moderate, solitary, pleonanthic, polygamous or...
# Hydriastele wendlandiana     H. wendlandiana grows to a height of 25 m with...
# Areca catechu                The ovoid fruit is 4 - 5cm long and produced i...
#
#                                                                              4  \
# Species
# Hymenocardia heudelotii                   Definition: whole plant arborescent.
# Entada abyssinica                          The leaves are febrifuge and tonic.
# Parajubaea torallyi                            Easily double, possibly triple.
# Maranthes polyandra          A tree up to about 12 m. tall, sometimes low a...
# Prosopis africana            Diameter of tree with medium basal surface are...
# Syagrus macrocarpa           This slow-growing palm grows up to 10m, althou...
# Adenium obesum               The leafless grey-green to brown stems or bran...
# Chamaedorea warscewiczii     Stem: 1.5-3.5 cm diam., smooth, green, ringed,...
# Aphania senegalensis         Leaves with petiole to 60 cm, axis strong, sto...
# Cordia africana              .The flowers are borne in broad, schirmrispige...
# Terminalia albida            Vatican City San Marino Italy Slovenia Montene...
# Acacia dudgeoni                                                       Envoyer.
# Plectocomiopsis geminiflora  The inflorescence is produced at the top of th...
# Syagrus glaucescens          Leaves little arched, 2.5â3 m long, dark gre...
# Tamarix senegalensis         As the plants age, the bark becomes gray-brown...
# Terminalia brownii                                    Terminalia | Feedipedia.
# Combretum collinum                   A tree with often long drooping branches.
# Pseudophoenix vinifera       Stem erect, often swollen, prominently ringed ...
# Hydriastele wendlandiana     The sparse crown has 5 to 10 paripinnate frond...
# Areca catechu                      Flowers, fruits and buds in a single frame.
#
#                                                                              5  \
# Species
# Hymenocardia heudelotii                                                  Sans.
# Entada abyssinica            Its fruits are large, flat legumes which split...
# Parajubaea torallyi                                       Paiement sÃ©curisÃ©.
# Maranthes polyandra                                           Criar uma conta.
# Prosopis africana            The spike is pedunculate, 4-6 cm long and 1.5 ...
# Syagrus macrocarpa                 The fruit is about 8 cm long and 6 cm wide.
# Adenium obesum                                  Thick fleshy gray-green stems.
# Chamaedorea warscewiczii     Pistillate with rachillae 10-15, these to 25 c...
# Aphania senegalensis         Ovary obcordiform, usually 2-lobed,.2-loculed,...
# Cordia africana              The seed with its pleated cotyledon germinates...
# Terminalia albida                              Langhorne J, Quin SJ, Sanni LA.
# Acacia dudgeoni                                                          Sans.
# Plectocomiopsis geminiflora  Stems to 30 m or more, without sheaths to 3 cm...
# Syagrus glaucescens          It grows to 4-10m tall, with 8-20 leaves to 2m...
# Tamarix senegalensis                       Growing medium accompanying plants.
# Terminalia brownii           Tree 7â13 m. high, bark greyish, longitudina...
# Combretum collinum           It has grey bark when still young and this bec...
# Pseudophoenix vinifera                         Especially close to their base.
# Hydriastele wendlandiana     Stem 2 â 10 cm in diam., smooth, with grey, ...
# Areca catechu                Flowers are unisexual , inflorescences are cro...
#
#                                                                            URL
# Species
# Hymenocardia heudelotii      https://upload.wikimedia.org/wikipedia/commons...
# Entada abyssinica            https://upload.wikimedia.org/wikipedia/commons...
# Parajubaea torallyi          https://upload.wikimedia.org/wikipedia/commons...
# Maranthes polyandra          https://upload.wikimedia.org/wikipedia/commons...
# Prosopis africana            https://upload.wikimedia.org/wikipedia/commons...
# Syagrus macrocarpa           https://upload.wikimedia.org/wikipedia/commons...
# Adenium obesum               https://upload.wikimedia.org/wikipedia/commons...
# Chamaedorea warscewiczii     https://upload.wikimedia.org/wikipedia/commons...
# Aphania senegalensis         https://upload.wikimedia.org/wikipedia/commons...
# Cordia africana              https://upload.wikimedia.org/wikipedia/commons...
# Terminalia albida            https://upload.wikimedia.org/wikipedia/commons...
# Acacia dudgeoni              https://upload.wikimedia.org/wikipedia/commons...
# Plectocomiopsis geminiflora  https://upload.wikimedia.org/wikipedia/commons...
# Syagrus glaucescens          https://upload.wikimedia.org/wikipedia/commons...
# Tamarix senegalensis         https://upload.wikimedia.org/wikipedia/commons...
# Terminalia brownii           https://upload.wikimedia.org/wikipedia/commons...
# Combretum collinum           https://upload.wikimedia.org/wikipedia/commons...
# Pseudophoenix vinifera       https://upload.wikimedia.org/wikipedia/commons...
# Hydriastele wendlandiana     https://upload.wikimedia.org/wikipedia/commons...
# Areca catechu                https://upload.wikimedia.org/wikipedia/commons...
