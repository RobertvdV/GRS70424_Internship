# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn import metrics
import json
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.corpus import stopwords
import collections
from itertools import groupby
import pickle
import re
import matplotlib.colors as mcolors
import warnings
import requests
import csv
from sklearn.preprocessing import MultiLabelBinarizer
from functools import reduce

# %% [markdown]
# ### Global Variables & Functions

# %% [markdown]
# #### Variables

# %%
nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}

colors = [color[4:] for color in mcolors.TABLEAU_COLORS.keys()]
colors.extend([color for color in mcolors.CSS4_COLORS.keys()])
colors.extend(
    [
        'whitish', 'bluish', 'reddish', 'greenish', 'backish', 'greyish',
        'backish', 'purplish', 'yellowish', 'orangish', 'brownish', 'pinkish'
    ]
)



traits_dict = {
    'Life Form':
    [
        'Tree', 'Shrub', 'Bush', 'Ficus', 'Strangler', 'Liana', 'Parasitic', 'Palm', 'Herbaceous'
    ],
    'Trunk':
    [
        'Trunk', 'Straight', 'Flared', 'Foothills', 'Silt', 'Aerial'
    ],
    'Root':
    [
        'Root', 'Straight', 'Flared', 'Foothills', 'Silt', 'Aerial'
    ],
    'Latex':
    [
        'Latex'
    ],
    'Phyllotaxis': # Leaf Position
    [
        'Phyllotaxis', 'Alternate', 'Whorled', 'Whorls', 'Opposite'
    ],
    'Leaf Composition':
    [
        'Palmate', 'Pinnate', 'Entire', 'Bi-pinnate'
    ],
    'Crown':
    [
        'Crown'
    ],
    'Stem':
    [
        'Stem', 'Circular', 'Square'
    ],
    'Bark':
    [
        'Bark'
    ],
    'Bark Colour':
    [
        'Bark'
    ],
    'Leaf Shape':
    [
        'Simple', 'Bifoliate', 'Trifoliate', 'Digitized', 'Paripinnate', 'Unipinnate', 'Imperipinnate', 
        'Alternate', 'Bipinnate', 'Pinnate', 'Elliptic', 'Elongate', 'Ovate', 'Round', 'Obovate', 'Lanceolate',
        'Kidney-shaped', 'Heart-shaped', 'Spathulate'
    ],
    'Petiole':
    [
        'Petiole', 'Sessile', 'Petiolated', 'Canaliculate', 'Glands', 'Glandular', 
     'Winged' 'Wings', 'Hairs', 'Hair', 'Translucent'
     ],
    'Leaf Colour':
    [
        'Leaf Colour', 'Leaf Color'
    ],
    'Leaf Blade':
    [
        'Leaf Blade', 'Linear', 'Lanceolate', 'Elliptical', 'Obovate', 'Obtriangular', 
        'Obtriangular', 'Asymmetrical', 'Orbicular', 'Bilobed', 'Lobed', 'Lobes', 'Lobe'
    ],
    'Leaf Base':
    [
        'Leaf Base', 'Rounded', 'Cordate', 'Glands'
    ],
    'Leaf Margin':
    [
        'Margin', 'Smooth', 'Wavy', 'Crenate', 'Toothed', 'Teeth', 'Crenate', 'Serrate'
    ],
    'Leaf Apex':
    [
        'Apex', 'Acuminate', 'Apiculate', 'Mucronate', 'Rounded', 'Emarginated'
    ],
    'Leaf side':
    [
        'Glabrous', 'Pubescent', 'Salt Crystals', 'Scales', 'Woolly', 'Powdery'
    ],
    'Leaf glands':
    [
        'Glands', 'Gland', 'Translucent'
    ],
    'Rachis':
    [
        'Rachis', 'Winged'
    ],
    'Vein':
    [
        'Vein'
    ],
    'Tendril':
    [
        'Tendril'
    ],
    'Spine':
    [
        'Spine', 'Prickle', 'Spines', 'Prickles'
    ],
    'Thornes':
    [
        'Thorn', 'Thornes'
    ],
    'Blade Colour':
    [
        'Blade'
    ],
    'Fruit':
    [
        'Drupe', 'Berry', 'Capsule', 'Pod', 'Follicle', 'Achene', 'Winged', 'Follicle',
        'Pod', 'Nutlet', 'Fruit'
    ],
    'Fruit Shape':
    [
        'locular', 'Globose', 'Flattened', 'Elongate', 'Obovoid', 'Ovate', 'Twisted',
        'Curved', 'Pyriform', 'Ovoid'
    ],
    'Fruit Colour':
    [
        'Fruit'
    ],
    'Inflorescences':
    [
        'Inflorescences', 'Inflorescence', 'Sessile', 'Panicle', 'Flower head', 'Cyme', 'Glomerule', 
        'Fascicle', 'Umbel', 'Corymb', 'Rootlet', 'Spike', 'Dichasium', 'Fascicle',
        'Globose', 'Raceme', 'Fascicle', 'Umbel'
     ],
    'Sexuality':
    [
        'Sexuality', 'Axillary', 'Terminal'
    ],
    'Flower Colour':
    [
        'Flower colour', 'Flower color', 'Flower', 'Flowers'
    ],
    'Flower Shape':
    [
        'Flower shape', 'Petalled', 'Petal', 'Petals', 'Tubular', 'Apetal', 'Butterfly-shaped', 'Shaped', 'Flower', 'Flowers'
    ],
    'Sepal Shape':
    [
        'Sepal', 'Sepals', 'Connate'
    ],
    'Petal Shape':
    [
        'Petal', 'Petals', 'Tepals', 'Tepal', 'Tubular'
    ],
    'Aril Colour':
    [
        'Aril'
    ],
    'Seed Colour':
    [
        'Seed', 
    ],
    'Conspicuousness':
    [
        'Conspicuousness', 'Cryptic'
    ]
}

with open('../../data/supportive/traits_Pierre_and_Andrei.json', 'w') as f:
    json.dump(traits_dict, f)
with open('../../data/supportive/colour_list.json', 'w') as f:
    json.dump(colors, f)

traits_list = list(traits_dict.keys())
traits_list += [trait.lower() for lst in list(traits_dict.values()) for trait in lst]

# %% [markdown]
# #### Functions

# %%
def corresponding_keys(val, dictionary):
    """returns the corresponding key of a single value 
    assuming the values are lists.

    Args:
        val (string): string present in the dict
        dictionary (dict): dict with lists of stings as values

    Returns:
        list: list of matching keys
    """
    # Init list
    keys = []
    # Search the dict
    for k, v in dictionary.items():
        if val in v:
            keys.append(k)
    return keys
    
def jaccard_similarity(A, B):
    """Calculates the Jaccard similarity two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    A = set(A)
    B = set(B)
    
    # Get intersection of two sets
    nominator = A.intersection(B)

    # Find union of two sets
    denominator = A.union(B)

    # Take the ratio of sizes
    similarity = len(nominator)/len(denominator)

    return similarity


def similarity(groundtruth, pred):
    """Calculates the normal similarity between two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    groundtruth = set(groundtruth)
    pred = set(pred)

    # Find intersection of two sets
    nominator = groundtruth.intersection(pred)

    # Find union of two sets
    denominator = groundtruth

    # Take the ratio of sizes
    similarity = len(nominator)/(len(denominator))

    return similarity

def resentesize(lst):

    sentence = ''

    # Loop every 2 items 
    for item1, item2 in zip(lst[::2], lst[1::2]):
        
        # Set verb
        verb = 'has'
        chunk = item2.split(' ')[-1]
        if chunk not in nouns or chunk in colors:
            verb = 'is'

        sentence += f'{item1.capitalize()} {verb} {item2}. '
    
    return sentence


def get_wiki_main_image(title):
    url = 'https://en.wikipedia.org/w/api.php'
    data = {
        'action' :'query',
        'format' : 'json',
        'formatversion' : 2,
        'prop' : 'pageimages|pageterms',
        'piprop' : 'original',
        'titles' : title
    }
    response = requests.get(url, data)
    json_data = json.loads(response.text)
    return json_data['query']['pages'][0]['original']['source'] if len(json_data['query']['pages']) >0 else 'Not found'

# %% [markdown]
# ### Load GT Data

# %%
root = "../../data/external/"

# %% [markdown]
# #### Data Andrei

# %%
file_name = root + 'Dataset_Andrei.csv'
df_Andrei = pd.read_csv(file_name)

# Get Dummies to match DF Pierre
df_Andrei_dummies = pd.get_dummies(df_Andrei.iloc[:, 2:])
# Set species back
df_Andrei_dummies = df_Andrei_dummies.set_index(df_Andrei['Species'])

# Create tuple list for multi index
Andrei_multi_index = []
for top_index in df_Andrei.columns:
    for sub_index in df_Andrei_dummies.columns:
        if top_index in sub_index:

            sub_index = sub_index.split('_')[-1]
            Andrei_multi_index.append((top_index, sub_index))

# Set Mutli index
df_Andrei_dummies.columns = pd.MultiIndex.from_tuples(Andrei_multi_index)
df_Andrei_dummies
# Out:
#                            Life form      Leaf position                      \
#                                liana tree     alternate alternate, opposite
# Species
# Avicennia germinans                0    1             0                   0
# Metopium brownei                   0    1             1                   0
# Handroanthus billbergii            0    1             0                   0
# Bourreria succulenta               0    1             1                   0
# Bursera karsteniana                0    1             1                   0
# Bursera simaruba                   0    1             1                   0
# Bursera tomentosa                  0    1             1                   0
# Cynophalla flexuosa                1    0             1                   0
# Cynophalla hastata                 0    1             1                   0
# Quadrella indica                   0    1             1                   0
# Quadrella odoratissima             0    1             1                   0
# Crossopetalum rhacoma              0    1             0                   0
# Maytenus tetragona                 0    1             1                   0
# Maytenus versluysii                0    1             1                   0
# Clusia rosea                       0    1             0                   0
# Conocarpus erectus                 0    1             1                   0
# Laguncularia racemosa              0    1             0                   0
# Erythroxylum havanense             0    1             1                   0
# Croton niveus                      0    1             1                   0
# Hippomane mancinella               0    1             1                   0
# Libidibia coriaria                 0    1             1                   0
# Pithecellobium unguis-cati         0    1             1                   0
# Prosopis juliflora                 0    1             1                   0
# Vachellia tortuosa                 0    1             1                   0
# Vitex compressa                    0    1             0                   0
# Vitex cymosa                       0    1             0                   0
# Trichilia trifolia                 0    1             1                   0
# Eugenia procera                    0    1             0                   0
# Guapira pacurero                   0    1             0                   0
# Coccoloba swartzii                 0    1             1                   0
# Coccoloba uvifera                  0    1             1                   0
# Krugiodendron ferreum              0    1             0                   1
# Rhizophora mangle                  0    1             0                   0
# Guettarda roupalifolia             0    1             0                   0
# Randia aculeata                    0    1             0                   0
# Amyris ignea                       0    1             1                   0
# Zanthoxylum monophyllum            0    1             1                   0
# Casearia tremula                   0    1             1                   0
# Schoepfia schreberi                0    1             1                   0
# Jacquinia arborea                  0    1             1                   0
# Guaiacum officinale                0    1             0                   0
# Guaiacum sanctum                   0    1             0                   0
#
#                                                            \
#                            opposite opposite, whorls of 3
# Species
# Avicennia germinans               1                     0
# Metopium brownei                  0                     0
# Handroanthus billbergii           1                     0
# Bourreria succulenta              0                     0
# Bursera karsteniana               0                     0
# Bursera simaruba                  0                     0
# Bursera tomentosa                 0                     0
# Cynophalla flexuosa               0                     0
# Cynophalla hastata                0                     0
# Quadrella indica                  0                     0
# Quadrella odoratissima            0                     0
# Crossopetalum rhacoma             0                     0
# Maytenus tetragona                0                     0
# Maytenus versluysii               0                     0
# Clusia rosea                      1                     0
# Conocarpus erectus                0                     0
# Laguncularia racemosa             1                     0
# Erythroxylum havanense            0                     0
# Croton niveus                     0                     0
# Hippomane mancinella              0                     0
# Libidibia coriaria                0                     0
# Pithecellobium unguis-cati        0                     0
# Prosopis juliflora                0                     0
# Vachellia tortuosa                0                     0
# Vitex compressa                   1                     0
# Vitex cymosa                      1                     0
# Trichilia trifolia                0                     0
# Eugenia procera                   1                     0
# Guapira pacurero                  1                     0
# Coccoloba swartzii                0                     0
# Coccoloba uvifera                 0                     0
# Krugiodendron ferreum             0                     0
# Rhizophora mangle                 1                     0
# Guettarda roupalifolia            1                     0
# Randia aculeata                   0                     1
# Amyris ignea                      0                     0
# Zanthoxylum monophyllum           0                     0
# Casearia tremula                  0                     0
# Schoepfia schreberi               0                     0
# Jacquinia arborea                 0                     0
# Guaiacum officinale               1                     0
# Guaiacum sanctum                  1                     0
#
#                                                             Leaf composition  \
#                            opposite, whorls of 3, alternate        3 palmate
# Species
# Avicennia germinans                                       0                0
# Metopium brownei                                          0                0
# Handroanthus billbergii                                   0                0
# Bourreria succulenta                                      0                0
# Bursera karsteniana                                       0                0
# Bursera simaruba                                          0                0
# Bursera tomentosa                                         0                0
# Cynophalla flexuosa                                       0                0
# Cynophalla hastata                                        0                0
# Quadrella indica                                          0                0
# Quadrella odoratissima                                    0                0
# Crossopetalum rhacoma                                     1                0
# Maytenus tetragona                                        0                0
# Maytenus versluysii                                       0                0
# Clusia rosea                                              0                0
# Conocarpus erectus                                        0                0
# Laguncularia racemosa                                     0                0
# Erythroxylum havanense                                    0                0
# Croton niveus                                             0                0
# Hippomane mancinella                                      0                0
# Libidibia coriaria                                        0                0
# Pithecellobium unguis-cati                                0                0
# Prosopis juliflora                                        0                0
# Vachellia tortuosa                                        0                0
# Vitex compressa                                           0                0
# Vitex cymosa                                              0                0
# Trichilia trifolia                                        0                1
# Eugenia procera                                           0                0
# Guapira pacurero                                          0                0
# Coccoloba swartzii                                        0                0
# Coccoloba uvifera                                         0                0
# Krugiodendron ferreum                                     0                0
# Rhizophora mangle                                         0                0
# Guettarda roupalifolia                                    0                0
# Randia aculeata                                           0                0
# Amyris ignea                                              0                0
# Zanthoxylum monophyllum                                   0                0
# Casearia tremula                                          0                0
# Schoepfia schreberi                                       0                0
# Jacquinia arborea                                         0                0
# Guaiacum officinale                                       0                0
# Guaiacum sanctum                                          0                0
#
#                                                     ... Aril colour            \
#                            3-5 palmate 3-5 pinnate  ...      orange red white
# Species                                             ...
# Avicennia germinans                  0           0  ...           0   0     0
# Metopium brownei                     0           1  ...           0   0     0
# Handroanthus billbergii              0           1  ...           0   0     0
# Bourreria succulenta                 0           0  ...           0   0     0
# Bursera karsteniana                  0           0  ...           0   0     0
# Bursera simaruba                     0           0  ...           0   0     0
# Bursera tomentosa                    0           0  ...           0   0     0
# Cynophalla flexuosa                  0           0  ...           0   0     1
# Cynophalla hastata                   0           0  ...           0   0     1
# Quadrella indica                     0           0  ...           0   0     1
# Quadrella odoratissima               0           0  ...           0   0     1
# Crossopetalum rhacoma                0           0  ...           0   0     0
# Maytenus tetragona                   0           0  ...           0   0     1
# Maytenus versluysii                  0           0  ...           0   0     1
# Clusia rosea                         0           0  ...           1   0     0
# Conocarpus erectus                   0           0  ...           0   0     0
# Laguncularia racemosa                0           0  ...           0   0     0
# Erythroxylum havanense               0           0  ...           0   0     0
# Croton niveus                        0           0  ...           0   0     0
# Hippomane mancinella                 0           0  ...           0   0     0
# Libidibia coriaria                   0           0  ...           0   0     0
# Pithecellobium unguis-cati           0           0  ...           0   0     1
# Prosopis juliflora                   0           0  ...           0   0     0
# Vachellia tortuosa                   0           0  ...           0   0     0
# Vitex compressa                      1           0  ...           0   0     0
# Vitex cymosa                         1           0  ...           0   0     0
# Trichilia trifolia                   0           0  ...           1   0     0
# Eugenia procera                      0           0  ...           0   0     0
# Guapira pacurero                     0           0  ...           0   0     0
# Coccoloba swartzii                   0           0  ...           0   0     0
# Coccoloba uvifera                    0           0  ...           0   0     0
# Krugiodendron ferreum                0           0  ...           0   0     0
# Rhizophora mangle                    0           0  ...           0   0     0
# Guettarda roupalifolia               0           0  ...           0   0     0
# Randia aculeata                      0           0  ...           0   0     0
# Amyris ignea                         0           0  ...           0   0     0
# Zanthoxylum monophyllum              0           0  ...           0   0     0
# Casearia tremula                     0           0  ...           1   0     0
# Schoepfia schreberi                  0           0  ...           0   0     0
# Jacquinia arborea                    0           0  ...           0   0     0
# Guaiacum officinale                  0           0  ...           0   1     0
# Guaiacum sanctum                     0           0  ...           0   1     0
#
#                                        Seed colour                         \
#                            yellow-geen       black brown green grey white
# Species
# Avicennia germinans                  0           0     0     1    0     0
# Metopium brownei                     0           0     0     0    0     0
# Handroanthus billbergii              0           0     0     0    0     0
# Bourreria succulenta                 0           0     0     0    0     0
# Bursera karsteniana                  0           0     0     0    0     0
# Bursera simaruba                     0           0     0     0    0     0
# Bursera tomentosa                    0           0     0     0    0     0
# Cynophalla flexuosa                  0           1     0     0    0     0
# Cynophalla hastata                   0           1     0     0    0     0
# Quadrella indica                     0           1     0     0    0     0
# Quadrella odoratissima               0           1     0     0    0     0
# Crossopetalum rhacoma                0           0     0     0    0     0
# Maytenus tetragona                   0           1     0     0    0     0
# Maytenus versluysii                  0           1     0     0    0     0
# Clusia rosea                         0           0     0     0    0     0
# Conocarpus erectus                   0           0     0     0    0     0
# Laguncularia racemosa                0           0     0     1    0     0
# Erythroxylum havanense               0           0     0     0    0     0
# Croton niveus                        0           0     0     0    0     0
# Hippomane mancinella                 0           0     0     0    1     0
# Libidibia coriaria                   0           0     1     0    0     0
# Pithecellobium unguis-cati           0           1     0     0    0     0
# Prosopis juliflora                   1           0     1     0    0     0
# Vachellia tortuosa                   0           0     1     0    0     0
# Vitex compressa                      0           0     0     0    0     0
# Vitex cymosa                         0           0     0     0    0     0
# Trichilia trifolia                   0           0     0     0    0     1
# Eugenia procera                      0           1     0     0    0     0
# Guapira pacurero                     0           1     0     0    0     0
# Coccoloba swartzii                   0           1     0     0    0     0
# Coccoloba uvifera                    0           1     0     0    0     0
# Krugiodendron ferreum                0           1     0     0    0     0
# Rhizophora mangle                    0           0     0     1    0     0
# Guettarda roupalifolia               0           0     1     0    0     0
# Randia aculeata                      0           0     1     0    0     0
# Amyris ignea                         0           0     0     0    0     0
# Zanthoxylum monophyllum              0           0     1     0    0     0
# Casearia tremula                     0           1     0     0    0     0
# Schoepfia schreberi                  0           0     0     0    0     0
# Jacquinia arborea                    0           0     1     0    0     0
# Guaiacum officinale                  0           0     1     0    0     0
# Guaiacum sanctum                     0           0     1     0    0     0
#
#
#                            whitish
# Species
# Avicennia germinans              0
# Metopium brownei                 0
# Handroanthus billbergii          1
# Bourreria succulenta             0
# Bursera karsteniana              0
# Bursera simaruba                 0
# Bursera tomentosa                0
# Cynophalla flexuosa              0
# Cynophalla hastata               0
# Quadrella indica                 0
# Quadrella odoratissima           0
# Crossopetalum rhacoma            0
# Maytenus tetragona               0
# Maytenus versluysii              0
# Clusia rosea                     0
# Conocarpus erectus               0
# Laguncularia racemosa            0
# Erythroxylum havanense           0
# Croton niveus                    0
# Hippomane mancinella             0
# Libidibia coriaria               0
# Pithecellobium unguis-cati       0
# Prosopis juliflora               0
# Vachellia tortuosa               0
# Vitex compressa                  0
# Vitex cymosa                     0
# Trichilia trifolia               0
# Eugenia procera                  0
# Guapira pacurero                 0
# Coccoloba swartzii               0
# Coccoloba uvifera                0
# Krugiodendron ferreum            0
# Rhizophora mangle                0
# Guettarda roupalifolia           0
# Randia aculeata                  0
# Amyris ignea                     0
# Zanthoxylum monophyllum          0
# Casearia tremula                 0
# Schoepfia schreberi              0
# Jacquinia arborea                0
# Guaiacum officinale              0
# Guaiacum sanctum                 0
#
# [42 rows x 202 columns]

# %% [markdown]
# #### Data Pierre

# %%
file_name = root + 'Dataset_Pierre.csv'
df_Pierre = pd.read_csv(file_name, header=[0, 1]) 
df_Pierre = df_Pierre.iloc[: , 1:]
df_Pierre = df_Pierre.set_index(df_Pierre['Species']['species'])
df_Pierre
# Out:
#                                                  Species plant type        \
#                                                  species       Tree Shrub
# species
# Acacia amythethophylla            Acacia amythethophylla          1     1
# Acacia ataxacantha                    Acacia ataxacantha          1     1
# Acacia dudgeoni                          Acacia dudgeoni          1     1
# Acacia ehrenbergiana                Acacia ehrenbergiana          1     1
# Acacia erythrocalyx                  Acacia erythrocalyx          0     0
# ...                                                  ...        ...   ...
# Ziziphus abyssinica                  Ziziphus abyssinica          1     1
# Ziziphus lotus ssp. saharae  Ziziphus lotus ssp. saharae          0     1
# Ziziphus mauritiana                  Ziziphus mauritiana          1     1
# Ziziphus mucronata                    Ziziphus mucronata          1     1
# Ziziphus spina-christi            Ziziphus spina-christi          0     1
#
#                                                                             \
#                             Bush Ficus strangler Liana Parasitic Palm tree
# species
# Acacia amythethophylla         0               0     0         0         0
# Acacia ataxacantha             1               0     1         0         0
# Acacia dudgeoni                0               0     0         0         0
# Acacia ehrenbergiana           0               0     0         0         0
# Acacia erythrocalyx            1               0     1         0         0
# ...                          ...             ...   ...       ...       ...
# Ziziphus abyssinica            1               0     0         0         0
# Ziziphus lotus ssp. saharae    1               0     0         0         0
# Ziziphus mauritiana            1               0     0         0         0
# Ziziphus mucronata             1               0     0         0         0
# Ziziphus spina-christi         1               0     0         0         0
#
#                                                  phyllotaxis  ...  \
#                             Herbaceous Phyllotaxis alternate  ...
# species                                                       ...
# Acacia amythethophylla               0                     1  ...
# Acacia ataxacantha                   0                     1  ...
# Acacia dudgeoni                      0                     1  ...
# Acacia ehrenbergiana                 0                     1  ...
# Acacia erythrocalyx                  0                     1  ...
# ...                                ...                   ...  ...
# Ziziphus abyssinica                  0                     1  ...
# Ziziphus lotus ssp. saharae          0                     1  ...
# Ziziphus mauritiana                  0                     1  ...
# Ziziphus mucronata                   0                     1  ...
# Ziziphus spina-christi               0                     1  ...
#
#                                       flower color                        \
#                             Yellow coloured flower Green coloured flower
# species
# Acacia amythethophylla                           1                     0
# Acacia ataxacantha                               1                     0
# Acacia dudgeoni                                  1                     0
# Acacia ehrenbergiana                             1                     0
# Acacia erythrocalyx                              0                     0
# ...                                            ...                   ...
# Ziziphus abyssinica                              1                     0
# Ziziphus lotus ssp. saharae                      1                     0
# Ziziphus mauritiana                              1                     0
# Ziziphus mucronata                               1                     0
# Ziziphus spina-christi                           1                     1
#
#                                       flower shape                        \
#                             Single-petalled flower Three-petalled flower
# species
# Acacia amythethophylla                           0                     0
# Acacia ataxacantha                               0                     0
# Acacia dudgeoni                                  0                     0
# Acacia ehrenbergiana                             0                     0
# Acacia erythrocalyx                              0                     0
# ...                                            ...                   ...
# Ziziphus abyssinica                              0                     0
# Ziziphus lotus ssp. saharae                      0                     0
# Ziziphus mauritiana                              0                     0
# Ziziphus mucronata                               0                     0
# Ziziphus spina-christi                           0                     0
#
#                                                                        \
#                             Four-petalled flower Five-petalled flower
# species
# Acacia amythethophylla                         0                    1
# Acacia ataxacantha                             0                    1
# Acacia dudgeoni                                0                    1
# Acacia ehrenbergiana                           0                    1
# Acacia erythrocalyx                            0                    1
# ...                                          ...                  ...
# Ziziphus abyssinica                            0                    1
# Ziziphus lotus ssp. saharae                    0                    1
# Ziziphus mauritiana                            0                    1
# Ziziphus mucronata                             0                    1
# Ziziphus spina-christi                         0                    1
#
#                                                                          \
#                             Flower with 6 or more petals Tubular flower
# species
# Acacia amythethophylla                                 0              1
# Acacia ataxacantha                                     0              1
# Acacia dudgeoni                                        0              1
# Acacia ehrenbergiana                                   0              1
# Acacia erythrocalyx                                    0              1
# ...                                                  ...            ...
# Ziziphus abyssinica                                    0              0
# Ziziphus lotus ssp. saharae                            0              0
# Ziziphus mauritiana                                    0              0
# Ziziphus mucronata                                     0              0
# Ziziphus spina-christi                                 0              0
#
#
#                             Butterfly-shaped flower Apetal flower
# species
# Acacia amythethophylla                            0             0
# Acacia ataxacantha                                0             0
# Acacia dudgeoni                                   0             0
# Acacia ehrenbergiana                              0             0
# Acacia erythrocalyx                               0             0
# ...                                             ...           ...
# Ziziphus abyssinica                               0             0
# Ziziphus lotus ssp. saharae                       0             0
# Ziziphus mauritiana                               0             0
# Ziziphus mucronata                                0             0
# Ziziphus spina-christi                            0             0
#
# [361 rows x 136 columns]

# %% [markdown]
# #### Data Palms

# %%
file_name = root + 'Dataset_Kissling.txt'
df_Daniel = pd.read_csv(file_name,
                 sep='\t', encoding='Latin-1')
palm_species = df_Daniel[~df_Daniel.isnull().any(axis=1)]['SpecName'].values
df_Daniel.set_index('SpecName', inplace=True)

### RESHAPE DATA FOR PALMS

# Exclude string types
df_Daniels_int = df_Daniel.select_dtypes(exclude=[object])
df_Daniels_str = df_Daniel.select_dtypes(include=[object])
# Drop numbers
df_Daniels_semi_ints = df_Daniels_int.loc[:, df_Daniels_int.max() <= 3]
# Merge again
df_Daniel_edit = pd.merge(df_Daniels_str, df_Daniels_semi_ints, left_index=True, right_index=True)

# Get colors as lst of lsts 
FruitColorDescription_colors_lst = []

for palm_colors in df_Daniels_str['FruitColorDescription'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        FruitColorDescription_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        FruitColorDescription_colors_lst.append([])

MainFruitColors_colors_lst = []

for palm_colors in df_Daniels_str['MainFruitColors'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        MainFruitColors_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        MainFruitColors_colors_lst.append([])

# Init SKlearn MLB
mlb = MultiLabelBinarizer()

# Create dummies for color columns
df_FruitColorDescription = pd.DataFrame(
    {
        'FruitColorDescription': FruitColorDescription_colors_lst
    }, columns=['FruitColorDescription'])

s = df_FruitColorDescription['FruitColorDescription']
df_FruitColorDescription = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('FruitColorDescription', column) for column in df_FruitColorDescription.columns]
df_FruitColorDescription.columns = pd.MultiIndex.from_tuples(columns)

# Create dummies for color columns
df_MainFruitColors = pd.DataFrame(
    {
        'MainFruitColors': MainFruitColors_colors_lst
    }, columns=['MainFruitColors'])

s = df_MainFruitColors['MainFruitColors']
df_MainFruitColors = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour', column) for column in df_MainFruitColors.columns]
df_MainFruitColors.columns = pd.MultiIndex.from_tuples(columns)

df_Daniels_str_non_color = df_Daniels_str[['UnderstoreyCanopy', 'FruitSizeCategorical', 'FruitShape', 'Conspicuousness']]

# df_Daniels_str_non_color.columns = pd.MultiIndex.from_tuples(
#     [
#         ('Crown', 'UnderstoreyCanopy'),
#         ('Fruit Size', 'FruitSizeCategorical'),
#         ('Fruit Shape', 'FruitShape'),
#         ('Conspicuousness', 'Conspicuousness'),
#     ]
# )

df_Daniels_str_non_color_dummies = pd.get_dummies(df_Daniels_str_non_color)
columns = []
for column in df_Daniels_str_non_color_dummies.columns:
    level0, level1 = column.split('_')
    if level0 == 'UnderstoreyCanopy':
        level0 = 'Crown'
    elif level0 == 'FruitSizeCategorical':
        level0 = 'Fruit Size'
    elif level0 == 'FruitShape':
        level0 = 'Fruit Shape'
    elif level0 == 'Conspicuousness':
        level0 = 'Conspicuousness'
    columns.append((level0, level1))
    
df_Daniels_str_non_color_dummies.columns = pd.MultiIndex.from_tuples(columns)

### JOIN ALL DATA
data_frames = [df_FruitColorDescription, df_MainFruitColors, df_Daniels_str_non_color_dummies]
df_Daniel_merged = pd.concat(data_frames, axis=1)
df_Daniel_merged
# Out:
#                          FruitColorDescription                             \
#                                          black blue bluish brown brownish
# SpecName
# Acanthophoenix crinita                       1    0      0     0        0
# Acanthophoenix rousselii                     1    0      0     0        0
# Acanthophoenix rubra                         1    0      0     0        0
# Acoelorrhaphe wrightii                       1    0      0     1        0
# Acrocomia aculeata                           0    0      0     0        0
# ...                                        ...  ...    ...   ...      ...
# Wettinia quinaria                            0    0      0     1        0
# Wettinia radiata                             0    0      0     0        0
# Wettinia verruculosa                         0    0      0     1        0
# Wodyetia bifurcata                           0    0      0     0        0
# Zombia antillarum                            0    0      0     0        0
#
#                                                                   ...  \
#                          chocolate coral crimson darkgreen green  ...
# SpecName                                                          ...
# Acanthophoenix crinita           0     0       0         0     0  ...
# Acanthophoenix rousselii         0     0       0         0     0  ...
# Acanthophoenix rubra             0     0       0         0     0  ...
# Acoelorrhaphe wrightii           0     0       0         0     0  ...
# Acrocomia aculeata               0     0       0         0     1  ...
# ...                            ...   ...     ...       ...   ...  ...
# Wettinia quinaria                0     0       0         0     1  ...
# Wettinia radiata                 0     0       0         0     0  ...
# Wettinia verruculosa             0     0       0         0     1  ...
# Wodyetia bifurcata               0     0       0         0     0  ...
# Zombia antillarum                0     0       0         0     0  ...
#
#                          Fruit Size Fruit Shape                            \
#                               small   ellipsoid elongate fusiform globose
# SpecName
# Acanthophoenix crinita            1           0        0        0       0
# Acanthophoenix rousselii          1           0        0        0       0
# Acanthophoenix rubra              1           0        0        0       0
# Acoelorrhaphe wrightii            1           0        0        0       0
# Acrocomia aculeata                0           0        0        0       0
# ...                             ...         ...      ...      ...     ...
# Wettinia quinaria                 1           0        0        0       0
# Wettinia radiata                  0           0        0        0       1
# Wettinia verruculosa              1           0        0        0       0
# Wodyetia bifurcata                0           0        0        0       1
# Zombia antillarum                 1           0        0        0       0
#
#                                                  Conspicuousness
#                          ovoid pyramidal rounded     conspicuous cryptic
# SpecName
# Acanthophoenix crinita       0         0       0               0       1
# Acanthophoenix rousselii     1         0       0               0       1
# Acanthophoenix rubra         1         0       0               0       1
# Acoelorrhaphe wrightii       1         0       0               0       1
# Acrocomia aculeata           1         0       0               0       1
# ...                        ...       ...     ...             ...     ...
# Wettinia quinaria            1         0       0               0       1
# Wettinia radiata             0         0       0               1       0
# Wettinia verruculosa         1         0       0               0       1
# Wodyetia bifurcata           0         0       0               1       0
# Zombia antillarum            1         0       0               0       1
#
# [2557 rows x 57 columns]

# %% [markdown]
# ## Prediction Data

# %% [markdown]
# ### Load Data

# %%
root = "../../data/processed/"
sentences_all = {}

f = open(F"{root}Sentences_Pierre.pkl", 'rb')
sentences_Pierre = pickle.load(f)
sentences_all |= sentences_Pierre 

f = open(F"{root}Sentences_Andrei.pkl", 'rb')
sentences_Andrei = pickle.load(f)
sentences_all |= sentences_Andrei 

f = open(F"{root}Sentences_Kissling.pkl", 'rb')
sentences_Kissling = pickle.load(f)
sentences_all |= sentences_Kissling 

# Drop duplicates
for species, sentences in sentences_all.items():
    sentences_all[species] = list(set(sentences))

# %% [markdown]
# ### Match Data

# %%
k= 5
google_form_lst = []

for idx, (species, sentences) in enumerate(tqdm(sentences_all.items())):

    # if idx >= 1:
    #     continue
    
    df_select = [df_Andrei_dummies, df_Pierre, df_Daniel_merged]
    if species in df_Andrei_dummies.index:
        df_select = df_select[0]
    elif species in df_Pierre.index:
        df_select = df_select[1]
    elif species in df_Daniel_merged.index:
        df_select = df_select[2]
    else:
        raise ValueError

    for gt_main_trait in df_select.columns.get_level_values(0).unique():
        df_subset = df_select[df_select.index == species][gt_main_trait]
        present_traits = df_subset.loc[:, df_subset.any()].columns.values
        df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)

        top_list = []

        for sentence in sentences:
            gt_sim = jaccard_similarity(sentence, df_sent)
            top_list.append((gt_sim, sentence))

        top_list.sort(reverse=True)
        top_k_list = [sentence for (_, sentence) in top_list[0:k]]

        google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list))
# Out:
# 100%|██████████| 647/647 [00:27<00:00, 23.15it/s]

# %% [markdown]
# ### Create Subset

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5'])
df_google
# Out:
#                       Species       Main Trait    GT Main Trait  \
# 0      Acacia amythethophylla          Species          Species
# 1      Acacia amythethophylla       plant type       plant type
# 2      Acacia amythethophylla      phyllotaxis      phyllotaxis
# 3      Acacia amythethophylla   trunk and root   trunk and root
# 4      Acacia amythethophylla            latex            latex
# ...                       ...              ...              ...
# 11437      Wodyetia bifurcata     Fruit Colour     Fruit Colour
# 11438      Wodyetia bifurcata            Crown            Crown
# 11439      Wodyetia bifurcata       Fruit Size       Fruit Size
# 11440      Wodyetia bifurcata      Fruit Shape      Fruit Shape
# 11441      Wodyetia bifurcata  Conspicuousness  Conspicuousness
#
#                   GT Sub Traits  \
# 0                     [species]
# 1                 [Tree, Shrub]
# 2       [Phyllotaxis alternate]
# 3      [Base of trunk straight]
# 4                  [No exudate]
# ...                         ...
# 11437                     [red]
# 11438                  [canopy]
# 11439                   [large]
# 11440                 [globose]
# 11441             [conspicuous]
#
#                                                        1  \
# 0      Acacia confusa - Stem Smaller peaks suspected ...
# 1      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 2             The branch bark is apparently 1.5% approx.
# 3      Fruits flat, reddish-brown, remaining on the t...
# 4                   Flower-heads abundant golden yellow.
# ...                                                  ...
# 11437                                   Fruits close up.
# 11438                     Capi Nature Row Egg Antraciet.
# 11439                     Fruit on ground below Foxtail.
# 11440  Washingtonia robusta Agave americana Scroll to...
# 11441                                   Fruits close up.
#
#                                                        2  \
# 0      Stipules spinescent, stout, brown, glossy, com...
# 1             The branch bark is apparently 1.5% approx.
# 2      Pinnae sometimes 20 or more pairs, with 50 or ...
# 3                                 Fruit flat, dehiscent.
# 4                                 Fruit flat, dehiscent.
# ...                                                  ...
# 11437                     Fruit on ground below Foxtail.
# 11438         Leaf scars are regular and closely spaced.
# 11439               Foxtail Palm Tree: Large Multi Stem.
# 11440           Leaflets are thin and about a foot long.
# 11441                                    Nous contacter.
#
#                                                        3  \
# 0      Acacia confusa - Root Smaller peaks suspected ...
# 1                   Perennial, Not climbing, Shrub/Tree.
# 2      Inflorescence large, terminal, much-branched, ...
# 3                 Young plants 6-8 months old from seed.
# 4                 Young plants 6-8 months old from seed.
# ...                                                  ...
# 11437                         Foxtail Palm Tree: Medium.
# 11438  Leaves are very plumose with leaflets coming o...
# 11439          Immature green fruit of the Foxtail Palm.
# 11440                                   Fruits close up.
# 11441                     Capi Nature Row Egg Antraciet.
#
#                                                        4  \
# 0      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 1                   Flower-heads abundant golden yellow.
# 2      Acacia confusa - Stem Smaller peaks suspected ...
# 3      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 4                   Perennial, Not climbing, Shrub/Tree.
# ...                                                  ...
# 11437                            Fruits : 2 inches long.
# 11438  The crownshaft of the foxtail palm is light to...
# 11439                    Fruit showing remains of style.
# 11440  Fruits are 2 inches long, egg shaped, and oran...
# 11441  Monoecious, male and female flowers occur on s...
#
#                                                        5
# 0                                 Fruit flat, dehiscent.
# 1      Inflorescence large, terminal, much-branched, ...
# 2                   Flower-heads abundant golden yellow.
# 3                   Flower-heads abundant golden yellow.
# 4      Fruits flat, reddish-brown, remaining on the t...
# ...                                                  ...
# 11437  Fruits are 2 inches long, egg shaped, and oran...
# 11438                                    Nous contacter.
# 11439                          Foxtail Palm Tree: Small.
# 11440            The fruits grow plentiful on the stalk.
# 11441                     Popular, Tropical, Bi Pinnate.
#
# [11442 rows x 9 columns]

# %%
df_google_subset = df_google\
                    .dropna()\
                    .sample(n=20, axis=0, random_state=123)\

df_google_subset
# Out:
#                        Species        Main Trait     GT Main Trait  \
# 5891     Manilkara multinervis           tendril           tendril
# 10334      Chamaedorea simplex             Crown             Crown
# 10154         Bactris ptariana             Crown             Crown
# 5548   Leptadenia pyrotechnica      flower color      flower color
# 6065        Monotes kerstingii              vein              vein
# 2522    Commiphora pedunculata         sexuality         sexuality
# 3175         Entada abyssinica           Species           Species
# 2509    Commiphora pedunculata        leaf shape        leaf shape
# 1292       Boscia angustifolia             spine             spine
# 5465          Lawsonia inermis              vein              vein
# 4864   Hymenocardia heudelotii         leaf apex         leaf apex
# 1413        Breonadia salicina         leaf base         leaf base
# 7658             Smilax anceps        leaf shape        leaf shape
# 9578        Trichilia trifolia  Leaf composition  Leaf composition
# 7064        Pterocarpus lucens              vein              vein
# 6530         Pavetta corymbosa             crown             crown
# 6438          Parkia biglobosa         leaf base         leaf base
# 2090          Clausena anisata              vein              vein
# 7054        Pterocarpus lucens             crown             crown
# 8575       Vernonia amygdalina        plant type        plant type
#
#                                            GT Sub Traits  \
# 5891                            [Plant without tendrils]
# 10334                                      [understorey]
# 10154                                      [understorey]
# 5548                            [Yellow coloured flower]
# 6065   [Pinnate venation with secondary veins connect...
# 2522                                [Axillary sexuality]
# 3175                                           [species]
# 2509            [Unipinnate leaf with opposite leaflets]
# 1292                              [Plant without spines]
# 5465   [Pinnate venation with secondary veins connect...
# 4864   [Leaf apex sharp corner, Leaf apex with wide c...
# 1413                              [Leaf base attenuated]
# 7658                                       [Simple leaf]
# 9578                                         [3 palmate]
# 7064   [Pinnate venation with secondary veins connect...
# 6530   [Leaves grouped at the top of the axes, Steppe...
# 6438                                 [Leaf base cordate]
# 2090   [Only the main vein is visible, Pinnate venati...
# 7054      [Regular density of the crown, drooping axles]
# 8575                                             [Shrub]
#
#                                                        1  \
# 5891      Clustered white or brown flowers amongst them.
# 10334  The flowers are produced in inflorescences , t...
# 10154                                      Groundcovers.
# 5548       The roots reach up to 12 m below the surface.
# 6065   Inflorescence an axillary or terminal, short p...
# 2522    Flowers in axillary paniculate cymes up to 5 cm.
# 3175     The long spikes of flowers are cream to yellow.
# 2509   Leaves usually crowded at the ends of the yell...
# 1292   These leaves are narrow  lanceolate or linear ...
# 5465   Lawsonia inermis , commonly called henna, is a...
# 4864   Species in this genus are dioecious , with mal...
# 1413            Lateral branches are arranged in groups.
# 7658   Female flowers with perianth similar to that o...
# 9578                Definition: whole plant arborescent.
# 7064   Flowering time very brief, lasting only a few ...
# 6530   Seeds 2 , attached to the centre of the septum...
# 6438                     Leaflets held on a long rachis.
# 2090   The leaflet shape is ovate to narrowly ellipti...
# 7054   Bark light grey smooth flaking off in irregula...
# 8575   A many-stemmed shrub or small tree up to c. 8 ...
#
#                                                        2  \
# 5891      Leaves clustered towards apices of branchlets.
# 10334  General Information Plants small, usually low-...
# 10154  All species have spiny leaves, the spines are ...
# 5548   Leptadenia pyrotechnica flower Flower color ye...
# 6065                       Fruit an ovoid to globose nut
# 2522                         Stamen-filaments subterete.
# 3175   Sperm with apoptotic nucleus characterized by ...
# 2509   The lateral branchlets occasionally hardening ...
# 1292              Morphology Flowers greenish, fragrant.
# 5465   Terminal panicles of highly fragrant flowers b...
# 4864                Definition: whole plant arborescent.
# 1413                       Grey fissured and scaly bark.
# 7658                                Smilax anceps Willd.
# 9578   The immature pericarp usually contains a small...
# 7064   The ovate, flattened fruits are pale creamy-br...
# 6530   Leaves opposite or rarely whorled, usually wit...
# 6438         African locust bean is a multipurpose tree.
# 2090   The leaf surfaces are densely covered with emb...
# 7054   The heartwood is creamy white and indistinctly...
# 8575   Bitter leaf is a shrub or small tree which gro...
#
#                                                        3  \
# 5891   Clustered white or brown flowers amongst them ...
# 10334  Flowers sessile or partly enclosed in a cavity...
# 10154  Seed irregularly globular, basally attached, h...
# 5548   The flowers are fine-haired and have a minimal...
# 6065                  Seed ovoid, c. 5.5 mm long, brown.
# 2522   Petals densely appressed-pilose outside, up to...
# 3175                         Small tree, without thorns.
# 2509    Flowers in axillary paniculate cymes up to 5 cm.
# 1292   Flowers in dense branched terminal heads, smal...
# 5465   The fruits are small, brown globose capsule, o...
# 4864                Shrub or small tree, to 30 ft. high.
# 1413   The fruit is a capsule and they cluster in sma...
# 7658   Stamens equal to or shorter than perianth, 3 s...
# 9578             Trichilia trifolia subspecies trifolia.
# 7064   The heartwood is creamy white and indistinctly...
# 6530   Morphology Seeds 2 , attached to the centre of...
# 6438   Sterile flowers are shorter and are borne near...
# 2090   The leaf surfaces are densely covered with emb...
# 7054   The bark is dark grey-brown and fissured or fl...
# 8575   Stems slender with a pale-brown closely longit...
#
#                                                        4  \
# 5891                              Mature seed not known.
# 10334  A small understory palm with simple undivied l...
# 10154  Diminutive to large, solitary or clustered, un...
# 5548   Branches erect, slender, green when young, bro...
# 6065   Botany     Shrub or small to medium-sized tree...
# 2522   Leaves usually crowded at the ends of the yell...
# 3175                               Flowers creamy-white.
# 2509   An Commiphora pedunculata in nahilalakip ha ge...
# 1292   Twigs glabrous or initially densely pubescent,...
# 5465   The fruit is usually a capsule, the testa of a...
# 4864                    They have simple , broad leaves.
# 1413   The trees are monoecious with flowers that are...
# 7658   Stamens 6, placed on base of perianth, anthers...
# 9578   The fruit flesh is pulpy, with a flavor remini...
# 7064   The leaflets are fresh grassy green, glossy ab...
# 6530   Leaves opposite, occasionally ternate, sessile...
# 6438   Microsatellite primers for Parkia biglobosa re...
# 2090   The genus can be distinguished from related pl...
# 7054   The wind-dispersed, winged fruits remain on th...
# 8575   Vernonia amygdalina , a member of the daisy fa...
#
#                                                        5
# 5891   Young branchlets deep purplish-brown with pale...
# 10334  Flowers unisexual, sessile, staminate and pist...
# 10154  Stems subterranean and very short, to erect, v...
# 5548                   Flowers in small umbellate cymes.
# 6065   Flowers bisexual, regular, 5-merous, pedicel s...
# 2522   The lateral branchlets occasionally hardening ...
# 3175                         A seed sprouting up slowly.
# 2509   Flowers in dense, subglobose, hispid clusters ...
# 1292   Flowers are greenish to white, terminal or axi...
# 5465   The leaves gradually yellow and fall during pr...
# 4864                                               Sans.
# 1413                    Fruits a small ball of capsules.
# 7658                      Staminodia 3, filiform, short.
# 9578   The flowers are inconspicuous, whitish, with y...
# 7064   They flower at the end of the dry season, just...
# 6530   Stamens attached at the mouth of the tube, exs...
# 6438   The tree is a fire-resistant heliophyte charac...
# 2090   Inflorescence of elongate puberulous panicles,...
# 7054   The grain is straight or interlocked, texture ...
# 8575   Its flowers in heads, 6 mm in diameter and in ...

# %% [markdown]
# ### Add Images

# %%
random_sample_species = df_google_subset['Species'].values

images_links = {}
for species in tqdm(random_sample_species):
    species_ = species.replace(' ', '_')
    try:
        img_url = get_wiki_main_image(species_)
        if img_url[-3:] != 'jpg':
            img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        # if img_url[-3:].isupper():
        #     img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        images_links[species] = img_url
    except:
        images_links[species] = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'

# df_google_subset = df_google[df_google['Species'].isin(random_sample_species)]
df_google_subset = df_google_subset.set_index('Species')
df_google_subset["URL"] = pd.Series(images_links)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset.csv', sep='\t')#, quoting=csv.QUOTE_ALL)
# Out:
# 100%|██████████| 20/20 [00:03<00:00,  5.53it/s]

# %%
df_google_subset
# Out:
#                                Main Trait     GT Main Trait  \
# Species
# Manilkara multinervis             tendril           tendril
# Chamaedorea simplex                 Crown             Crown
# Bactris ptariana                    Crown             Crown
# Leptadenia pyrotechnica      flower color      flower color
# Monotes kerstingii                   vein              vein
# Commiphora pedunculata          sexuality         sexuality
# Entada abyssinica                 Species           Species
# Commiphora pedunculata         leaf shape        leaf shape
# Boscia angustifolia                 spine             spine
# Lawsonia inermis                     vein              vein
# Hymenocardia heudelotii         leaf apex         leaf apex
# Breonadia salicina              leaf base         leaf base
# Smilax anceps                  leaf shape        leaf shape
# Trichilia trifolia       Leaf composition  Leaf composition
# Pterocarpus lucens                   vein              vein
# Pavetta corymbosa                   crown             crown
# Parkia biglobosa                leaf base         leaf base
# Clausena anisata                     vein              vein
# Pterocarpus lucens                  crown             crown
# Vernonia amygdalina            plant type        plant type
#
#                                                              GT Sub Traits  \
# Species
# Manilkara multinervis                             [Plant without tendrils]
# Chamaedorea simplex                                          [understorey]
# Bactris ptariana                                             [understorey]
# Leptadenia pyrotechnica                           [Yellow coloured flower]
# Monotes kerstingii       [Pinnate venation with secondary veins connect...
# Commiphora pedunculata                                [Axillary sexuality]
# Entada abyssinica                                                [species]
# Commiphora pedunculata            [Unipinnate leaf with opposite leaflets]
# Boscia angustifolia                                 [Plant without spines]
# Lawsonia inermis         [Pinnate venation with secondary veins connect...
# Hymenocardia heudelotii  [Leaf apex sharp corner, Leaf apex with wide c...
# Breonadia salicina                                  [Leaf base attenuated]
# Smilax anceps                                                [Simple leaf]
# Trichilia trifolia                                             [3 palmate]
# Pterocarpus lucens       [Pinnate venation with secondary veins connect...
# Pavetta corymbosa        [Leaves grouped at the top of the axes, Steppe...
# Parkia biglobosa                                       [Leaf base cordate]
# Clausena anisata         [Only the main vein is visible, Pinnate venati...
# Pterocarpus lucens          [Regular density of the crown, drooping axles]
# Vernonia amygdalina                                                [Shrub]
#
#                                                                          1  \
# Species
# Manilkara multinervis       Clustered white or brown flowers amongst them.
# Chamaedorea simplex      The flowers are produced in inflorescences , t...
# Bactris ptariana                                             Groundcovers.
# Leptadenia pyrotechnica      The roots reach up to 12 m below the surface.
# Monotes kerstingii       Inflorescence an axillary or terminal, short p...
# Commiphora pedunculata    Flowers in axillary paniculate cymes up to 5 cm.
# Entada abyssinica          The long spikes of flowers are cream to yellow.
# Commiphora pedunculata   Leaves usually crowded at the ends of the yell...
# Boscia angustifolia      These leaves are narrow  lanceolate or linear ...
# Lawsonia inermis         Lawsonia inermis , commonly called henna, is a...
# Hymenocardia heudelotii  Species in this genus are dioecious , with mal...
# Breonadia salicina                Lateral branches are arranged in groups.
# Smilax anceps            Female flowers with perianth similar to that o...
# Trichilia trifolia                    Definition: whole plant arborescent.
# Pterocarpus lucens       Flowering time very brief, lasting only a few ...
# Pavetta corymbosa        Seeds 2 , attached to the centre of the septum...
# Parkia biglobosa                           Leaflets held on a long rachis.
# Clausena anisata         The leaflet shape is ovate to narrowly ellipti...
# Pterocarpus lucens       Bark light grey smooth flaking off in irregula...
# Vernonia amygdalina      A many-stemmed shrub or small tree up to c. 8 ...
#
#                                                                          2  \
# Species
# Manilkara multinervis       Leaves clustered towards apices of branchlets.
# Chamaedorea simplex      General Information Plants small, usually low-...
# Bactris ptariana         All species have spiny leaves, the spines are ...
# Leptadenia pyrotechnica  Leptadenia pyrotechnica flower Flower color ye...
# Monotes kerstingii                           Fruit an ovoid to globose nut
# Commiphora pedunculata                         Stamen-filaments subterete.
# Entada abyssinica        Sperm with apoptotic nucleus characterized by ...
# Commiphora pedunculata   The lateral branchlets occasionally hardening ...
# Boscia angustifolia                 Morphology Flowers greenish, fragrant.
# Lawsonia inermis         Terminal panicles of highly fragrant flowers b...
# Hymenocardia heudelotii               Definition: whole plant arborescent.
# Breonadia salicina                           Grey fissured and scaly bark.
# Smilax anceps                                         Smilax anceps Willd.
# Trichilia trifolia       The immature pericarp usually contains a small...
# Pterocarpus lucens       The ovate, flattened fruits are pale creamy-br...
# Pavetta corymbosa        Leaves opposite or rarely whorled, usually wit...
# Parkia biglobosa               African locust bean is a multipurpose tree.
# Clausena anisata         The leaf surfaces are densely covered with emb...
# Pterocarpus lucens       The heartwood is creamy white and indistinctly...
# Vernonia amygdalina      Bitter leaf is a shrub or small tree which gro...
#
#                                                                          3  \
# Species
# Manilkara multinervis    Clustered white or brown flowers amongst them ...
# Chamaedorea simplex      Flowers sessile or partly enclosed in a cavity...
# Bactris ptariana         Seed irregularly globular, basally attached, h...
# Leptadenia pyrotechnica  The flowers are fine-haired and have a minimal...
# Monotes kerstingii                      Seed ovoid, c. 5.5 mm long, brown.
# Commiphora pedunculata   Petals densely appressed-pilose outside, up to...
# Entada abyssinica                              Small tree, without thorns.
# Commiphora pedunculata    Flowers in axillary paniculate cymes up to 5 cm.
# Boscia angustifolia      Flowers in dense branched terminal heads, smal...
# Lawsonia inermis         The fruits are small, brown globose capsule, o...
# Hymenocardia heudelotii               Shrub or small tree, to 30 ft. high.
# Breonadia salicina       The fruit is a capsule and they cluster in sma...
# Smilax anceps            Stamens equal to or shorter than perianth, 3 s...
# Trichilia trifolia                 Trichilia trifolia subspecies trifolia.
# Pterocarpus lucens       The heartwood is creamy white and indistinctly...
# Pavetta corymbosa        Morphology Seeds 2 , attached to the centre of...
# Parkia biglobosa         Sterile flowers are shorter and are borne near...
# Clausena anisata         The leaf surfaces are densely covered with emb...
# Pterocarpus lucens       The bark is dark grey-brown and fissured or fl...
# Vernonia amygdalina      Stems slender with a pale-brown closely longit...
#
#                                                                          4  \
# Species
# Manilkara multinervis                               Mature seed not known.
# Chamaedorea simplex      A small understory palm with simple undivied l...
# Bactris ptariana         Diminutive to large, solitary or clustered, un...
# Leptadenia pyrotechnica  Branches erect, slender, green when young, bro...
# Monotes kerstingii       Botany     Shrub or small to medium-sized tree...
# Commiphora pedunculata   Leaves usually crowded at the ends of the yell...
# Entada abyssinica                                    Flowers creamy-white.
# Commiphora pedunculata   An Commiphora pedunculata in nahilalakip ha ge...
# Boscia angustifolia      Twigs glabrous or initially densely pubescent,...
# Lawsonia inermis         The fruit is usually a capsule, the testa of a...
# Hymenocardia heudelotii                   They have simple , broad leaves.
# Breonadia salicina       The trees are monoecious with flowers that are...
# Smilax anceps            Stamens 6, placed on base of perianth, anthers...
# Trichilia trifolia       The fruit flesh is pulpy, with a flavor remini...
# Pterocarpus lucens       The leaflets are fresh grassy green, glossy ab...
# Pavetta corymbosa        Leaves opposite, occasionally ternate, sessile...
# Parkia biglobosa         Microsatellite primers for Parkia biglobosa re...
# Clausena anisata         The genus can be distinguished from related pl...
# Pterocarpus lucens       The wind-dispersed, winged fruits remain on th...
# Vernonia amygdalina      Vernonia amygdalina , a member of the daisy fa...
#
#                                                                          5  \
# Species
# Manilkara multinervis    Young branchlets deep purplish-brown with pale...
# Chamaedorea simplex      Flowers unisexual, sessile, staminate and pist...
# Bactris ptariana         Stems subterranean and very short, to erect, v...
# Leptadenia pyrotechnica                  Flowers in small umbellate cymes.
# Monotes kerstingii       Flowers bisexual, regular, 5-merous, pedicel s...
# Commiphora pedunculata   The lateral branchlets occasionally hardening ...
# Entada abyssinica                              A seed sprouting up slowly.
# Commiphora pedunculata   Flowers in dense, subglobose, hispid clusters ...
# Boscia angustifolia      Flowers are greenish to white, terminal or axi...
# Lawsonia inermis         The leaves gradually yellow and fall during pr...
# Hymenocardia heudelotii                                              Sans.
# Breonadia salicina                        Fruits a small ball of capsules.
# Smilax anceps                               Staminodia 3, filiform, short.
# Trichilia trifolia       The flowers are inconspicuous, whitish, with y...
# Pterocarpus lucens       They flower at the end of the dry season, just...
# Pavetta corymbosa        Stamens attached at the mouth of the tube, exs...
# Parkia biglobosa         The tree is a fire-resistant heliophyte charac...
# Clausena anisata         Inflorescence of elongate puberulous panicles,...
# Pterocarpus lucens       The grain is straight or interlocked, texture ...
# Vernonia amygdalina      Its flowers in heads, 6 mm in diameter and in ...
#
#                                                                        URL
# Species
# Manilkara multinervis    https://upload.wikimedia.org/wikipedia/commons...
# Chamaedorea simplex      https://upload.wikimedia.org/wikipedia/commons...
# Bactris ptariana         https://upload.wikimedia.org/wikipedia/commons...
# Leptadenia pyrotechnica  https://upload.wikimedia.org/wikipedia/commons...
# Monotes kerstingii       https://upload.wikimedia.org/wikipedia/commons...
# Commiphora pedunculata   https://upload.wikimedia.org/wikipedia/commons...
# Entada abyssinica        https://upload.wikimedia.org/wikipedia/commons...
# Commiphora pedunculata   https://upload.wikimedia.org/wikipedia/commons...
# Boscia angustifolia      https://upload.wikimedia.org/wikipedia/commons...
# Lawsonia inermis         https://upload.wikimedia.org/wikipedia/commons...
# Hymenocardia heudelotii  https://upload.wikimedia.org/wikipedia/commons...
# Breonadia salicina       https://upload.wikimedia.org/wikipedia/commons...
# Smilax anceps            https://upload.wikimedia.org/wikipedia/commons...
# Trichilia trifolia       https://upload.wikimedia.org/wikipedia/commons...
# Pterocarpus lucens       https://upload.wikimedia.org/wikipedia/commons...
# Pavetta corymbosa        https://upload.wikimedia.org/wikipedia/commons...
# Parkia biglobosa         https://upload.wikimedia.org/wikipedia/commons...
# Clausena anisata         https://upload.wikimedia.org/wikipedia/commons...
# Pterocarpus lucens       https://upload.wikimedia.org/wikipedia/commons...
# Vernonia amygdalina      https://upload.wikimedia.org/wikipedia/commons...
