# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn import metrics
import json
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.corpus import stopwords
import collections
from itertools import groupby
import pickle
import re
import matplotlib.colors as mcolors
import warnings
import requests
import csv
from sklearn.preprocessing import MultiLabelBinarizer
from functools import reduce
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Global Variables & Functions

# %% [markdown]
# #### Variables

# %%
nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}

with open('../../data/supportive/colour_list.json', 'r') as f:
  colors = json.load(f)

with open('../../data/supportive/trait_dictionary.json', 'r') as f:
  traits_dict = json.load(f)
traits_list = list(traits_dict.keys())
traits_list += [trait.lower() for lst in list(traits_dict.values()) for trait in lst]

# %% [markdown]
# #### Functions

# %%
def corresponding_keys(val, dictionary):
    """returns the corresponding key of a single value 
    assuming the values are lists.

    Args:
        val (string): string present in the dict
        dictionary (dict): dict with lists of stings as values

    Returns:
        list: list of matching keys
    """
    # Init list
    keys = []
    # Search the dict
    for k, v in dictionary.items():
        if val in v:
            keys.append(k)
    return keys
    
def jaccard_similarity(A, B):
    """Calculates the Jaccard similarity two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    A = set(A.lower().split())
    B = set(B.lower().split())
    
    # Get intersection of two sets
    nominator = A.intersection(B)

    # Find union of two sets
    denominator = A.union(B)

    # Take the ratio of sizes
    similarity = len(nominator)/len(denominator)

    return similarity


def similarity(groundtruth, pred):
    """Calculates the normal similarity between two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    groundtruth = set(groundtruth)
    pred = set(pred)

    # Find intersection of two sets
    nominator = groundtruth.intersection(pred)

    # Find union of two sets
    denominator = groundtruth

    # Take the ratio of sizes
    similarity = len(nominator)/(len(denominator))

    return similarity

def resentesize(lst):

    sentence = ''

    # Loop every 2 items 
    for item1, item2 in zip(lst[::2], lst[1::2]):
        
        # Set verb
        verb = 'has'
        chunk = item2.split(' ')[-1]
        if chunk not in nouns or chunk in colors:
            verb = 'is'

        sentence += f'{item1.capitalize()} {verb} {item2}. '
    
    return sentence


def get_wiki_main_image(title):
    url = 'https://en.wikipedia.org/w/api.php'
    data = {
        'action' :'query',
        'format' : 'json',
        'formatversion' : 2,
        'prop' : 'pageimages|pageterms',
        'piprop' : 'original',
        'titles' : title
    }
    response = requests.get(url, data)
    json_data = json.loads(response.text)
    return json_data['query']['pages'][0]['original']['source'] if len(json_data['query']['pages']) >0 else 'Not found'

# %% [markdown]
# ### Load GT Data

# %%
root = "../../data/external/"

# %% [markdown]
# #### Data Andrei

# %%
file_name = root + 'Dataset_Andrei.csv'
df_Andrei = pd.read_csv(file_name)

# Get Dummies to match DF Pierre
df_Andrei_dummies = pd.get_dummies(df_Andrei.iloc[:, 2:])
# Set species back
df_Andrei_dummies = df_Andrei_dummies.set_index(df_Andrei['Species'])

# Create tuple list for multi index
Andrei_multi_index = []
for top_index in df_Andrei.columns:
    for sub_index in df_Andrei_dummies.columns:
        if top_index in sub_index:

            sub_index = sub_index.split('_')[-1]
            Andrei_multi_index.append((top_index, sub_index))

# Set Mutli index
df_Andrei_dummies.columns = pd.MultiIndex.from_tuples(Andrei_multi_index)
df_Andrei_dummies
# Out:
#                            Life form      Leaf position                      \
#                                liana tree     alternate alternate, opposite
# Species
# Avicennia germinans                0    1             0                   0
# Metopium brownei                   0    1             1                   0
# Handroanthus billbergii            0    1             0                   0
# Bourreria succulenta               0    1             1                   0
# Bursera karsteniana                0    1             1                   0
# Bursera simaruba                   0    1             1                   0
# Bursera tomentosa                  0    1             1                   0
# Cynophalla flexuosa                1    0             1                   0
# Cynophalla hastata                 0    1             1                   0
# Quadrella indica                   0    1             1                   0
# Quadrella odoratissima             0    1             1                   0
# Crossopetalum rhacoma              0    1             0                   0
# Maytenus tetragona                 0    1             1                   0
# Maytenus versluysii                0    1             1                   0
# Clusia rosea                       0    1             0                   0
# Conocarpus erectus                 0    1             1                   0
# Laguncularia racemosa              0    1             0                   0
# Erythroxylum havanense             0    1             1                   0
# Croton niveus                      0    1             1                   0
# Hippomane mancinella               0    1             1                   0
# Libidibia coriaria                 0    1             1                   0
# Pithecellobium unguis-cati         0    1             1                   0
# Prosopis juliflora                 0    1             1                   0
# Vachellia tortuosa                 0    1             1                   0
# Vitex compressa                    0    1             0                   0
# Vitex cymosa                       0    1             0                   0
# Trichilia trifolia                 0    1             1                   0
# Eugenia procera                    0    1             0                   0
# Guapira pacurero                   0    1             0                   0
# Coccoloba swartzii                 0    1             1                   0
# Coccoloba uvifera                  0    1             1                   0
# Krugiodendron ferreum              0    1             0                   1
# Rhizophora mangle                  0    1             0                   0
# Guettarda roupalifolia             0    1             0                   0
# Randia aculeata                    0    1             0                   0
# Amyris ignea                       0    1             1                   0
# Zanthoxylum monophyllum            0    1             1                   0
# Casearia tremula                   0    1             1                   0
# Schoepfia schreberi                0    1             1                   0
# Jacquinia arborea                  0    1             1                   0
# Guaiacum officinale                0    1             0                   0
# Guaiacum sanctum                   0    1             0                   0
#
#                                                            \
#                            opposite opposite, whorls of 3
# Species
# Avicennia germinans               1                     0
# Metopium brownei                  0                     0
# Handroanthus billbergii           1                     0
# Bourreria succulenta              0                     0
# Bursera karsteniana               0                     0
# Bursera simaruba                  0                     0
# Bursera tomentosa                 0                     0
# Cynophalla flexuosa               0                     0
# Cynophalla hastata                0                     0
# Quadrella indica                  0                     0
# Quadrella odoratissima            0                     0
# Crossopetalum rhacoma             0                     0
# Maytenus tetragona                0                     0
# Maytenus versluysii               0                     0
# Clusia rosea                      1                     0
# Conocarpus erectus                0                     0
# Laguncularia racemosa             1                     0
# Erythroxylum havanense            0                     0
# Croton niveus                     0                     0
# Hippomane mancinella              0                     0
# Libidibia coriaria                0                     0
# Pithecellobium unguis-cati        0                     0
# Prosopis juliflora                0                     0
# Vachellia tortuosa                0                     0
# Vitex compressa                   1                     0
# Vitex cymosa                      1                     0
# Trichilia trifolia                0                     0
# Eugenia procera                   1                     0
# Guapira pacurero                  1                     0
# Coccoloba swartzii                0                     0
# Coccoloba uvifera                 0                     0
# Krugiodendron ferreum             0                     0
# Rhizophora mangle                 1                     0
# Guettarda roupalifolia            1                     0
# Randia aculeata                   0                     1
# Amyris ignea                      0                     0
# Zanthoxylum monophyllum           0                     0
# Casearia tremula                  0                     0
# Schoepfia schreberi               0                     0
# Jacquinia arborea                 0                     0
# Guaiacum officinale               1                     0
# Guaiacum sanctum                  1                     0
#
#                                                             Leaf composition  \
#                            opposite, whorls of 3, alternate        3 palmate
# Species
# Avicennia germinans                                       0                0
# Metopium brownei                                          0                0
# Handroanthus billbergii                                   0                0
# Bourreria succulenta                                      0                0
# Bursera karsteniana                                       0                0
# Bursera simaruba                                          0                0
# Bursera tomentosa                                         0                0
# Cynophalla flexuosa                                       0                0
# Cynophalla hastata                                        0                0
# Quadrella indica                                          0                0
# Quadrella odoratissima                                    0                0
# Crossopetalum rhacoma                                     1                0
# Maytenus tetragona                                        0                0
# Maytenus versluysii                                       0                0
# Clusia rosea                                              0                0
# Conocarpus erectus                                        0                0
# Laguncularia racemosa                                     0                0
# Erythroxylum havanense                                    0                0
# Croton niveus                                             0                0
# Hippomane mancinella                                      0                0
# Libidibia coriaria                                        0                0
# Pithecellobium unguis-cati                                0                0
# Prosopis juliflora                                        0                0
# Vachellia tortuosa                                        0                0
# Vitex compressa                                           0                0
# Vitex cymosa                                              0                0
# Trichilia trifolia                                        0                1
# Eugenia procera                                           0                0
# Guapira pacurero                                          0                0
# Coccoloba swartzii                                        0                0
# Coccoloba uvifera                                         0                0
# Krugiodendron ferreum                                     0                0
# Rhizophora mangle                                         0                0
# Guettarda roupalifolia                                    0                0
# Randia aculeata                                           0                0
# Amyris ignea                                              0                0
# Zanthoxylum monophyllum                                   0                0
# Casearia tremula                                          0                0
# Schoepfia schreberi                                       0                0
# Jacquinia arborea                                         0                0
# Guaiacum officinale                                       0                0
# Guaiacum sanctum                                          0                0
#
#                                                     ... Aril colour            \
#                            3-5 palmate 3-5 pinnate  ...      orange red white
# Species                                             ...
# Avicennia germinans                  0           0  ...           0   0     0
# Metopium brownei                     0           1  ...           0   0     0
# Handroanthus billbergii              0           1  ...           0   0     0
# Bourreria succulenta                 0           0  ...           0   0     0
# Bursera karsteniana                  0           0  ...           0   0     0
# Bursera simaruba                     0           0  ...           0   0     0
# Bursera tomentosa                    0           0  ...           0   0     0
# Cynophalla flexuosa                  0           0  ...           0   0     1
# Cynophalla hastata                   0           0  ...           0   0     1
# Quadrella indica                     0           0  ...           0   0     1
# Quadrella odoratissima               0           0  ...           0   0     1
# Crossopetalum rhacoma                0           0  ...           0   0     0
# Maytenus tetragona                   0           0  ...           0   0     1
# Maytenus versluysii                  0           0  ...           0   0     1
# Clusia rosea                         0           0  ...           1   0     0
# Conocarpus erectus                   0           0  ...           0   0     0
# Laguncularia racemosa                0           0  ...           0   0     0
# Erythroxylum havanense               0           0  ...           0   0     0
# Croton niveus                        0           0  ...           0   0     0
# Hippomane mancinella                 0           0  ...           0   0     0
# Libidibia coriaria                   0           0  ...           0   0     0
# Pithecellobium unguis-cati           0           0  ...           0   0     1
# Prosopis juliflora                   0           0  ...           0   0     0
# Vachellia tortuosa                   0           0  ...           0   0     0
# Vitex compressa                      1           0  ...           0   0     0
# Vitex cymosa                         1           0  ...           0   0     0
# Trichilia trifolia                   0           0  ...           1   0     0
# Eugenia procera                      0           0  ...           0   0     0
# Guapira pacurero                     0           0  ...           0   0     0
# Coccoloba swartzii                   0           0  ...           0   0     0
# Coccoloba uvifera                    0           0  ...           0   0     0
# Krugiodendron ferreum                0           0  ...           0   0     0
# Rhizophora mangle                    0           0  ...           0   0     0
# Guettarda roupalifolia               0           0  ...           0   0     0
# Randia aculeata                      0           0  ...           0   0     0
# Amyris ignea                         0           0  ...           0   0     0
# Zanthoxylum monophyllum              0           0  ...           0   0     0
# Casearia tremula                     0           0  ...           1   0     0
# Schoepfia schreberi                  0           0  ...           0   0     0
# Jacquinia arborea                    0           0  ...           0   0     0
# Guaiacum officinale                  0           0  ...           0   1     0
# Guaiacum sanctum                     0           0  ...           0   1     0
#
#                                        Seed colour                         \
#                            yellow-geen       black brown green grey white
# Species
# Avicennia germinans                  0           0     0     1    0     0
# Metopium brownei                     0           0     0     0    0     0
# Handroanthus billbergii              0           0     0     0    0     0
# Bourreria succulenta                 0           0     0     0    0     0
# Bursera karsteniana                  0           0     0     0    0     0
# Bursera simaruba                     0           0     0     0    0     0
# Bursera tomentosa                    0           0     0     0    0     0
# Cynophalla flexuosa                  0           1     0     0    0     0
# Cynophalla hastata                   0           1     0     0    0     0
# Quadrella indica                     0           1     0     0    0     0
# Quadrella odoratissima               0           1     0     0    0     0
# Crossopetalum rhacoma                0           0     0     0    0     0
# Maytenus tetragona                   0           1     0     0    0     0
# Maytenus versluysii                  0           1     0     0    0     0
# Clusia rosea                         0           0     0     0    0     0
# Conocarpus erectus                   0           0     0     0    0     0
# Laguncularia racemosa                0           0     0     1    0     0
# Erythroxylum havanense               0           0     0     0    0     0
# Croton niveus                        0           0     0     0    0     0
# Hippomane mancinella                 0           0     0     0    1     0
# Libidibia coriaria                   0           0     1     0    0     0
# Pithecellobium unguis-cati           0           1     0     0    0     0
# Prosopis juliflora                   1           0     1     0    0     0
# Vachellia tortuosa                   0           0     1     0    0     0
# Vitex compressa                      0           0     0     0    0     0
# Vitex cymosa                         0           0     0     0    0     0
# Trichilia trifolia                   0           0     0     0    0     1
# Eugenia procera                      0           1     0     0    0     0
# Guapira pacurero                     0           1     0     0    0     0
# Coccoloba swartzii                   0           1     0     0    0     0
# Coccoloba uvifera                    0           1     0     0    0     0
# Krugiodendron ferreum                0           1     0     0    0     0
# Rhizophora mangle                    0           0     0     1    0     0
# Guettarda roupalifolia               0           0     1     0    0     0
# Randia aculeata                      0           0     1     0    0     0
# Amyris ignea                         0           0     0     0    0     0
# Zanthoxylum monophyllum              0           0     1     0    0     0
# Casearia tremula                     0           1     0     0    0     0
# Schoepfia schreberi                  0           0     0     0    0     0
# Jacquinia arborea                    0           0     1     0    0     0
# Guaiacum officinale                  0           0     1     0    0     0
# Guaiacum sanctum                     0           0     1     0    0     0
#
#
#                            whitish
# Species
# Avicennia germinans              0
# Metopium brownei                 0
# Handroanthus billbergii          1
# Bourreria succulenta             0
# Bursera karsteniana              0
# Bursera simaruba                 0
# Bursera tomentosa                0
# Cynophalla flexuosa              0
# Cynophalla hastata               0
# Quadrella indica                 0
# Quadrella odoratissima           0
# Crossopetalum rhacoma            0
# Maytenus tetragona               0
# Maytenus versluysii              0
# Clusia rosea                     0
# Conocarpus erectus               0
# Laguncularia racemosa            0
# Erythroxylum havanense           0
# Croton niveus                    0
# Hippomane mancinella             0
# Libidibia coriaria               0
# Pithecellobium unguis-cati       0
# Prosopis juliflora               0
# Vachellia tortuosa               0
# Vitex compressa                  0
# Vitex cymosa                     0
# Trichilia trifolia               0
# Eugenia procera                  0
# Guapira pacurero                 0
# Coccoloba swartzii               0
# Coccoloba uvifera                0
# Krugiodendron ferreum            0
# Rhizophora mangle                0
# Guettarda roupalifolia           0
# Randia aculeata                  0
# Amyris ignea                     0
# Zanthoxylum monophyllum          0
# Casearia tremula                 0
# Schoepfia schreberi              0
# Jacquinia arborea                0
# Guaiacum officinale              0
# Guaiacum sanctum                 0
#
# [42 rows x 202 columns]

# %% [markdown]
# #### Data Pierre

# %%
file_name = root + 'Dataset_Pierre.csv'
df_Pierre = pd.read_csv(file_name, header=[0, 1]) 
df_Pierre = df_Pierre.iloc[: , 1:]
df_Pierre = df_Pierre.set_index(df_Pierre['Species']['species'])
df_Pierre = df_Pierre.drop(columns=['Species', 'XXX'])
# Out:
# /var/folders/0p/7b4jnnp15d5gx16h36l4ycx00000gn/T/ipykernel_34592/4153551112.py:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_Pierre = df_Pierre.drop(columns=['Species', 'XXX'])

# %% [markdown]
# #### Data Palms

# %%
file_name = root + 'Dataset_Kissling.txt'
df_Daniel = pd.read_csv(file_name,
                 sep='\t', encoding='Latin-1')
palm_species = df_Daniel[~df_Daniel.isnull().any(axis=1)]['SpecName'].values
df_Daniel.set_index('SpecName', inplace=True)

### RESHAPE DATA FOR PALMS

# Exclude string types
df_Daniels_int = df_Daniel.select_dtypes(exclude=[object])
df_Daniels_str = df_Daniel.select_dtypes(include=[object])
# Drop numbers
df_Daniels_semi_ints = df_Daniels_int.loc[:, df_Daniels_int.max() <= 3]
# Merge again
df_Daniel_edit = pd.merge(df_Daniels_str, df_Daniels_semi_ints, left_index=True, right_index=True)


# Real numbers:
df_Daniels_real_ints = df_Daniels_int.loc[:, df_Daniels_int.max() >= 3]
columns = [
    ("Measurement", "Maximum Stem Height in Meters"),
    ("Measurement", "Maximum Stem Diameter in Centimeters"),
    ("Measurement", "Maximum Leaf Number"),
    ("Measurement", "Maximum Leaf Blade Length in Meters"),
    ("Measurement", "Maximum Rachis Length in Meters"),
    ("Measurement", "Maximum Petiole Length in Meters"),
    ("Measurement", "Average Fruit Length in Centimeters"),
    ("Measurement", "Minimum Fruit Length in Centimeters"),
    ("Measurement", "Maximum Fruit Length in Centimeters"),
    ("Measurement", "Average Fruit Width in Centimeters"),
    ("Measurement", "Minimum Fruit Width in Centimeters"),
    ("Measurement", "Maximum Fruit Width in Centimeters"),
]

df_Daniels_real_ints.columns = pd.MultiIndex.from_tuples(columns)
df_Daniels_real_ints

# Get colors as lst of lsts 
FruitColorDescription_colors_lst = []

for palm_colors in df_Daniels_str['FruitColorDescription'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        FruitColorDescription_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        FruitColorDescription_colors_lst.append([])

MainFruitColors_colors_lst = []

for palm_colors in df_Daniels_str['MainFruitColors'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        MainFruitColors_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        MainFruitColors_colors_lst.append([])

# Init SKlearn MLB
mlb = MultiLabelBinarizer()

# Create dummies for color columns
df_FruitColorDescription = pd.DataFrame(
    {
        'FruitColorDescription': FruitColorDescription_colors_lst
    }, columns=['FruitColorDescription'])

s = df_FruitColorDescription['FruitColorDescription']
df_FruitColorDescription = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour Description', column) for column in df_FruitColorDescription.columns]
df_FruitColorDescription.columns = pd.MultiIndex.from_tuples(columns)

# Create dummies for color columns
df_MainFruitColors = pd.DataFrame(
    {
        'MainFruitColors': MainFruitColors_colors_lst
    }, columns=['MainFruitColors'])

s = df_MainFruitColors['MainFruitColors']
df_MainFruitColors = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour', column) for column in df_MainFruitColors.columns]
df_MainFruitColors.columns = pd.MultiIndex.from_tuples(columns)

df_Daniels_str_non_color = df_Daniels_str[['UnderstoreyCanopy', 'FruitSizeCategorical', 'FruitShape', 'Conspicuousness']]

# df_Daniels_str_non_color.columns = pd.MultiIndex.from_tuples(
#     [
#         ('Crown', 'UnderstoreyCanopy'),
#         ('Fruit Size', 'FruitSizeCategorical'),
#         ('Fruit Shape', 'FruitShape'),
#         ('Conspicuousness', 'Conspicuousness'),
#     ]
# )

df_Daniels_str_non_color_dummies = pd.get_dummies(df_Daniels_str_non_color)
columns = []
for column in df_Daniels_str_non_color_dummies.columns:
    level0, level1 = column.split('_')
    if level0 == 'UnderstoreyCanopy':
        level0 = 'Crown'
    elif level0 == 'FruitSizeCategorical':
        level0 = 'Fruit Size'
    elif level0 == 'FruitShape':
        level0 = 'Fruit Shape'
    elif level0 == 'Conspicuousness':
        level0 = 'Conspicuousness'
    columns.append((level0, level1))
    
df_Daniels_str_non_color_dummies.columns = pd.MultiIndex.from_tuples(columns)

### JOIN ALL DATA
data_frames = [df_FruitColorDescription, df_MainFruitColors, df_Daniels_str_non_color_dummies, df_Daniels_real_ints]
df_Daniel_merged = pd.concat(data_frames, axis=1)
df_Daniel_merged
# Out:
#                          Fruit Colour Description                             \
#                                             black blue bluish brown brownish
# SpecName
# Acanthophoenix crinita                          1    0      0     0        0
# Acanthophoenix rousselii                        1    0      0     0        0
# Acanthophoenix rubra                            1    0      0     0        0
# Acoelorrhaphe wrightii                          1    0      0     1        0
# Acrocomia aculeata                              0    0      0     0        0
# ...                                           ...  ...    ...   ...      ...
# Wettinia quinaria                               0    0      0     1        0
# Wettinia radiata                                0    0      0     0        0
# Wettinia verruculosa                            0    0      0     1        0
# Wodyetia bifurcata                              0    0      0     0        0
# Zombia antillarum                               0    0      0     0        0
#
#                                                                   ...  \
#                          chocolate coral crimson darkgreen green  ...
# SpecName                                                          ...
# Acanthophoenix crinita           0     0       0         0     0  ...
# Acanthophoenix rousselii         0     0       0         0     0  ...
# Acanthophoenix rubra             0     0       0         0     0  ...
# Acoelorrhaphe wrightii           0     0       0         0     0  ...
# Acrocomia aculeata               0     0       0         0     1  ...
# ...                            ...   ...     ...       ...   ...  ...
# Wettinia quinaria                0     0       0         0     1  ...
# Wettinia radiata                 0     0       0         0     0  ...
# Wettinia verruculosa             0     0       0         0     1  ...
# Wodyetia bifurcata               0     0       0         0     0  ...
# Zombia antillarum                0     0       0         0     0  ...
#
#                                  Measurement  \
#                          Maximum Leaf Number
# SpecName
# Acanthophoenix crinita                  15.0
# Acanthophoenix rousselii                 NaN
# Acanthophoenix rubra                    20.0
# Acoelorrhaphe wrightii                  25.0
# Acrocomia aculeata                      30.0
# ...                                      ...
# Wettinia quinaria                        6.0
# Wettinia radiata                         6.0
# Wettinia verruculosa                     6.0
# Wodyetia bifurcata                      10.0
# Zombia antillarum                       12.0
#
#                                                               \
#                          Maximum Leaf Blade Length in Meters
# SpecName
# Acanthophoenix crinita                                  2.30
# Acanthophoenix rousselii                                3.00
# Acanthophoenix rubra                                    3.10
# Acoelorrhaphe wrightii                                  1.30
# Acrocomia aculeata                                      3.50
# ...                                                      ...
# Wettinia quinaria                                       5.50
# Wettinia radiata                                        4.33
# Wettinia verruculosa                                    6.00
# Wodyetia bifurcata                                      3.20
# Zombia antillarum                                       1.20
#
#                                                           \
#                          Maximum Rachis Length in Meters
# SpecName
# Acanthophoenix crinita                               NaN
# Acanthophoenix rousselii                             NaN
# Acanthophoenix rubra                                 3.0
# Acoelorrhaphe wrightii                               0.7
# Acrocomia aculeata                                   2.5
# ...                                                  ...
# Wettinia quinaria                                    3.2
# Wettinia radiata                                     3.4
# Wettinia verruculosa                                 3.7
# Wodyetia bifurcata                                   2.3
# Zombia antillarum                                    1.0
#
#                                                            \
#                          Maximum Petiole Length in Meters
# SpecName
# Acanthophoenix crinita                                NaN
# Acanthophoenix rousselii                              NaN
# Acanthophoenix rubra                                  NaN
# Acoelorrhaphe wrightii                               0.65
# Acrocomia aculeata                                    NaN
# ...                                                   ...
# Wettinia quinaria                                    1.35
# Wettinia radiata                                      NaN
# Wettinia verruculosa                                 2.40
# Wodyetia bifurcata                                   1.02
# Zombia antillarum                                     NaN
#
#                                                               \
#                          Average Fruit Length in Centimeters
# SpecName
# Acanthophoenix crinita                                  0.65
# Acanthophoenix rousselii                                2.00
# Acanthophoenix rubra                                    1.00
# Acoelorrhaphe wrightii                                  0.70
# Acrocomia aculeata                                      4.25
# ...                                                      ...
# Wettinia quinaria                                       2.75
# Wettinia radiata                                        4.00
# Wettinia verruculosa                                    2.50
# Wodyetia bifurcata                                      5.75
# Zombia antillarum                                       1.75
#
#                                                               \
#                          Minimum Fruit Length in Centimeters
# SpecName
# Acanthophoenix crinita                                   0.6
# Acanthophoenix rousselii                                 NaN
# Acanthophoenix rubra                                     NaN
# Acoelorrhaphe wrightii                                   NaN
# Acrocomia aculeata                                       3.5
# ...                                                      ...
# Wettinia quinaria                                        2.0
# Wettinia radiata                                         3.0
# Wettinia verruculosa                                     NaN
# Wodyetia bifurcata                                       5.0
# Zombia antillarum                                        NaN
#
#                                                               \
#                          Maximum Fruit Length in Centimeters
# SpecName
# Acanthophoenix crinita                                   0.7
# Acanthophoenix rousselii                                 NaN
# Acanthophoenix rubra                                     NaN
# Acoelorrhaphe wrightii                                   NaN
# Acrocomia aculeata                                       5.0
# ...                                                      ...
# Wettinia quinaria                                        3.5
# Wettinia radiata                                         4.0
# Wettinia verruculosa                                     NaN
# Wodyetia bifurcata                                       6.5
# Zombia antillarum                                        NaN
#
#                                                              \
#                          Average Fruit Width in Centimeters
# SpecName
# Acanthophoenix crinita                                 0.50
# Acanthophoenix rousselii                               0.80
# Acanthophoenix rubra                                   0.70
# Acoelorrhaphe wrightii                                 0.70
# Acrocomia aculeata                                     4.60
# ...                                                     ...
# Wettinia quinaria                                      2.00
# Wettinia radiata                                       2.00
# Wettinia verruculosa                                   1.50
# Wodyetia bifurcata                                     4.35
# Zombia antillarum                                      1.75
#
#                                                              \
#                          Minimum Fruit Width in Centimeters
# SpecName
# Acanthophoenix crinita                                  NaN
# Acanthophoenix rousselii                                NaN
# Acanthophoenix rubra                                    NaN
# Acoelorrhaphe wrightii                                  0.5
# Acrocomia aculeata                                      3.8
# ...                                                     ...
# Wettinia quinaria                                       1.5
# Wettinia radiata                                        NaN
# Wettinia verruculosa                                    NaN
# Wodyetia bifurcata                                      2.7
# Zombia antillarum                                       1.5
#
#
#                          Maximum Fruit Width in Centimeters
# SpecName
# Acanthophoenix crinita                                  NaN
# Acanthophoenix rousselii                                NaN
# Acanthophoenix rubra                                    NaN
# Acoelorrhaphe wrightii                                  0.9
# Acrocomia aculeata                                      5.4
# ...                                                     ...
# Wettinia quinaria                                       2.5
# Wettinia radiata                                        NaN
# Wettinia verruculosa                                    NaN
# Wodyetia bifurcata                                      6.0
# Zombia antillarum                                       2.0
#
# [2557 rows x 69 columns]

# %% [markdown]
# ## Prediction Data

# %% [markdown]
# ### Load Data

# %%
root = "../../data/processed/"
sentences_all = {}

f = open(F"{root}Sentences_Pierre.pkl", 'rb')
sentences_Pierre = pickle.load(f)
sentences_all |= sentences_Pierre 

f = open(F"{root}Sentences_Andrei.pkl", 'rb')
sentences_Andrei = pickle.load(f)
sentences_all |= sentences_Andrei 

f = open(F"{root}Sentences_Kissling.pkl", 'rb')
sentences_Kissling = pickle.load(f)
sentences_all |= sentences_Kissling 

# Drop duplicates
for species, sentences in sentences_all.items():
    sentences_all[species] = list(set(sentences))

# %% [markdown]
# ### Match Data

# %%
k= 5
google_form_lst = []

for idx, (species, sentences) in enumerate(tqdm(sentences_all.items())):

    # if idx > 1:
    #     continue
    # if species != 'Dypsis thiryana':
    #     continue
    
    df_select = [df_Andrei_dummies, df_Pierre, df_Daniel_merged]
    if species in df_Andrei_dummies.index:
        df_select = df_select[0]
    elif species in df_Pierre.index:
        df_select = df_select[1]
    elif species in df_Daniel_merged.index:
        df_select = df_select[2]
    else:
        raise ValueError

    for gt_main_trait in df_select.columns.get_level_values(0).unique():
        if gt_main_trait == 'Measurement':
            df_subset = df_select[df_select.index == species][gt_main_trait]
            # Not really efficient, use PD?
    
            subtraits = list(df_subset.columns)
            values = df_subset.values[0]
            for sub_trait, value in zip(subtraits, values):

                df_sent  = F"{sub_trait}: {value}"

                top_list = []

                for sentence in sentences:
                    gt_sim = jaccard_similarity(sentence, df_sent)
                    if not gt_sim:
                        sentence = np.NaN
                    top_list.append((gt_sim, sentence))

                top_list.sort(reverse=True)
                # top_k_list = [sentence for (_, sentence) in top_list[0:k]]
                gt_sim_sum = 0
                top_k_list = []
                for (gt_sim, sentence) in top_list[0:k]:
                    gt_sim_sum += gt_sim
                    top_k_list.append(sentence)                

                google_form_lst.append((species, gt_main_trait, sub_trait, [df_sent], *top_k_list, df_sent.capitalize(), gt_sim_sum))
        else:
            df_subset = df_select[df_select.index == species][gt_main_trait]
            present_traits = df_subset.loc[:, df_subset.any()].columns.values
            
            # df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)
            
            # NEW VERSION SINGLE TRAIT
            size = present_traits.shape
            if not size[0]:
                continue
            df_sent = F"{gt_main_trait} {present_traits[0]}"
            # print(df_sent)

            top_list = []

            for sentence in sentences:
                gt_sim = jaccard_similarity(sentence, df_sent)

                if not gt_sim:
                    sentence = np.NaN

                # print(gt_sim, sentence, df_sent)
                top_list.append((gt_sim, sentence))

            top_list.sort(reverse=True)

            # print(top_list)

            # top_k_list = [sentence for (_, sentence) in top_list[0:k]]
            gt_sim_sum = 0
            top_k_list = []
            for (gt_sim, sentence) in top_list[0:k]:
                gt_sim_sum += gt_sim
                top_k_list.append(sentence)

            # GoogleSent = gt_main_trait + ': ' + ', '.join(list(present_traits))
            GoogleSent = F"{gt_main_trait}: {present_traits[0]}"
            google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list, GoogleSent.capitalize(), gt_sim_sum))
# Out:
# 100%|██████████| 647/647 [00:17<00:00, 37.71it/s]

# %% [markdown]
# ### Create Subset

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5', 'GoogleSentence', 'Jaccard Sum'])
df_google
# Out:
#                       Species      Main Trait  \
# 0      Acacia amythethophylla      plant type
# 1      Acacia amythethophylla     phyllotaxis
# 2      Acacia amythethophylla  trunk and root
# 3      Acacia amythethophylla           latex
# 4      Acacia amythethophylla           crown
# ...                       ...             ...
# 13141      Wodyetia bifurcata     Measurement
# 13142      Wodyetia bifurcata     Measurement
# 13143      Wodyetia bifurcata     Measurement
# 13144      Wodyetia bifurcata     Measurement
# 13145      Wodyetia bifurcata     Measurement
#
#                              GT Main Trait  \
# 0                               plant type
# 1                              phyllotaxis
# 2                           trunk and root
# 3                                    latex
# 4                                    crown
# ...                                    ...
# 13141  Minimum Fruit Length in Centimeters
# 13142  Maximum Fruit Length in Centimeters
# 13143   Average Fruit Width in Centimeters
# 13144   Minimum Fruit Width in Centimeters
# 13145   Maximum Fruit Width in Centimeters
#
#                                     GT Sub Traits  \
# 0                                   [Tree, Shrub]
# 1                         [Phyllotaxis alternate]
# 2                        [Base of trunk straight]
# 3                                    [No exudate]
# 4                 [Horizontally spreading crowns]
# ...                                           ...
# 13141  [Minimum Fruit Length in Centimeters: 5.0]
# 13142  [Maximum Fruit Length in Centimeters: 6.5]
# 13143  [Average Fruit Width in Centimeters: 4.35]
# 13144   [Minimum Fruit Width in Centimeters: 2.7]
# 13145   [Maximum Fruit Width in Centimeters: 6.0]
#
#                                                        1  \
# 0      A tree 20â40 ft. high, sometimes scarcely ar...
# 1                                                    NaN
# 2      Inflorescence large, terminal, much-branched, ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13141                      White, Pale-yellow in Summer.
# 13142                      White, Pale-yellow in Summer.
# 13143  The average width of the crown of leaves on a ...
# 13144                      White, Pale-yellow in Summer.
# 13145                      White, Pale-yellow in Summer.
#
#                                                        2  \
# 0      Small or medium tree 2â12 m. high, bark roug...
# 1                                                    NaN
# 2      Acacia confusa - Root Smaller peaks suspected ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13141                         Dark-green in All seasons.
# 13142                         Dark-green in All seasons.
# 13143                      White, Pale-yellow in Summer.
# 13144                         Dark-green in All seasons.
# 13145                         Dark-green in All seasons.
#
#                                                        3  \
# 0      Small or medium tree 2-15 m. high, bark rough,...
# 1                                                    NaN
# 2      Pinnae sometimes 20 or more pairs, with 50 or ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13141  Fruit is 2.inches long, deep orange to deep re...
# 13142  Fruit is 2.inches long, deep orange to deep re...
# 13143                         Dark-green in All seasons.
# 13144  Fruit is 2.inches long, deep orange to deep re...
# 13145  Fruit is 2.inches long, deep orange to deep re...
#
#                                                        4  \
# 0      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 1                                                    NaN
# 2      Flowers orange or yellow, strongly and sweetly...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13141                      Mature red fruit on Wodyetia.
# 13142                      Mature red fruit on Wodyetia.
# 13143  Fruit is 2.inches long, deep orange to deep re...
# 13144                      Mature red fruit on Wodyetia.
# 13145                      Mature red fruit on Wodyetia.
#
#                                                        5  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Flowers orange or yellow, strongly and sweetly...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13141                    Fruit showing remains of style.
# 13142                    Fruit showing remains of style.
# 13143                      Mature red fruit on Wodyetia.
# 13144                    Fruit showing remains of style.
# 13145                    Fruit showing remains of style.
#
#                                  GoogleSentence  Jaccard Sum
# 0                              Plant type: tree     0.309402
# 1            Phyllotaxis: phyllotaxis alternate     0.000000
# 2        Trunk and root: base of trunk straight     0.323004
# 3                             Latex: no exudate     0.000000
# 4          Crown: horizontally spreading crowns     0.000000
# ...                                         ...          ...
# 13141  Minimum fruit length in centimeters: 5.0     0.527485
# 13142  Maximum fruit length in centimeters: 6.5     0.527485
# 13143  Average fruit width in centimeters: 4.35     0.581332
# 13144   Minimum fruit width in centimeters: 2.7     0.527485
# 13145   Maximum fruit width in centimeters: 6.0     0.527485
#
# [13146 rows x 11 columns]

# %%
df_google = df_google.dropna()

for i in range(10):
    df_google_subset = df_google\
                            .sample(n=20, axis=0, random_state=333+i)

    df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset_{i+1}.csv', sep='\t')

# %%
df_google_subset = df_google[df_google["Jaccard Sum"] > 0.5].sample(n=20, axis=0, random_state=123)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset_demo.csv', sep='\t')
df_google_subset
# Out:
#                       Species      Main Trait  \
# 423        Adansonia digitata           crown
# 1703      Citrus aurantifolia    flower color
# 12083    Pritchardia glabrata     Measurement
# 1815         Clausena anisata  inflorescences
# 513     Albizia adianthifolia           crown
# 11332  Linospadix palmerianus      Fruit Size
# 6252         Ricinus communis      plant type
# 1427         Capparis decidua           fruit
# 8545          Randia aculeata    Fruit colour
# 11616          Nypa fruticans     Measurement
# 1663    Cissus quadrangularis           crown
# 7632        Voacanga africana  inflorescences
# 12129       Raphia farinifera     Measurement
# 11612          Nypa fruticans     Measurement
# 3104      Euphorbia tirucalli           fruit
# 6632          Senna singueana  inflorescences
# 2380       Croton gratissimus            vein
# 2574            Delonix regia      bark color
# 5141         Mangifera indica           crown
# 4772           Lantana camara    flower color
#
#                              GT Main Trait  \
# 423                                  crown
# 1703                          flower color
# 12083   Minimum Fruit Width in Centimeters
# 1815                        inflorescences
# 513                                  crown
# 11332                           Fruit Size
# 6252                            plant type
# 1427                                 fruit
# 8545                          Fruit colour
# 11616   Maximum Fruit Width in Centimeters
# 1663                                 crown
# 7632                        inflorescences
# 12129                  Maximum Leaf Number
# 11612  Minimum Fruit Length in Centimeters
# 3104                                 fruit
# 6632                        inflorescences
# 2380                                  vein
# 2574                            bark color
# 5141                                 crown
# 4772                          flower color
#
#                                            GT Sub Traits  \
# 423    [Regular density of the crown, Leaves grouped ...
# 1703                                      [White flower]
# 12083          [Minimum Fruit Width in Centimeters: 2.0]
# 1815              [Panicle of flowers or inflorescences]
# 513    [Regular density of the crown, Horizontally sp...
# 11332                                            [small]
# 6252                                       [Shrub, Bush]
# 1427                        [Berry, or berry-like fruit]
# 8545                             [green, black, whitish]
# 11616         [Maximum Fruit Width in Centimeters: 10.0]
# 1663      [Regular density of the crown, drooping axles]
# 7632               [Corymb of flowers or inflorescences]
# 12129                        [Maximum Leaf Number: 12.0]
# 11612         [Minimum Fruit Length in Centimeters: 8.0]
# 3104                                           [Capsule]
# 6632   [Rootlet or cluster of flowers or inflorescences]
# 2380   [Pinnate venation with secondary veins connect...
# 2574   [Slice in light bark, Slice through orange bar...
# 5141                      [Regular density of the crown]
# 4772   [White flower, Pink coloured flower, Red colou...
#
#                                                        1  \
# 423    Leaves: Palmately compound and clustered at th...
# 1703                                Flower Color: White.
# 12083  They produce round black fruit less than 1 inc...
# 1815   Flowers in axillary, cymose panicles, yellow o...
# 513    The crown is flattened, with large, spreading ...
# 11332                 Fruit elongate/cylindricall, 0 -15
# 6252   Ricinus communis is an herbaceous plant or sem...
# 1427             Fruit is a berry, globose or ellipsoid.
# 8545                                  Fruit shape: oval.
# 11616  Fruit is globose, nodding, up to 30 centimeter...
# 1663   Cissus quadrangularis is a perennial plant of ...
# 7632                    Its flowers are white or yellow.
# 12129                                     Leaf Close-up.
# 11612  Fruit is globose, nodding, up to 30 centimeter...
# 3104                                Capsule 3-lobed, ca.
# 6632   The inflorescences are racemes at the ends of ...
# 2380   The leaves of the lavender croton are simple a...
# 2574                                           In Bloom.
# 5141   The flesh of ripe mangos is pale yellow to ora...
# 4772                                      White flowers.
#
#                                                        2  \
# 423    Pollen grains are spherical with spikes over t...
# 1703   The small white flowers are usually borne in c...
# 12083  The mature fruit are 1/2 inch by 3/4 inch elli...
# 1815   The bisexual flowers of Clausena anisata grow ...
# 513    The leaves are alternate, bipinnately compound...
# 11332              Fruit elongate/cylindricall, 0 -15 cm
# 6252                        Plant Spread: 1.5 to 4 feet.
# 1427            Fruit is ellipsoidal, obovate or oblong.
# 8545                                Fruit cover: fleshy.
# 11616                                    Fruit - PubMed.
# 1663   Each has a tendril emerging from the opposite ...
# 7632   The white or yellow flowers are in small bunch...
# 12129                                  Leaf Base Detail.
# 11612                                    Fruit - PubMed.
# 3104   The glabrous fruit is a ridged capsule at matu...
# 6632   The flowers have two sets of stamen: feeding s...
# 2380                   The fruit is yellow with 3 lobes.
# 2574         Bark and Trunk : Light brown to gray trunk.
# 5141   There is a characteristic beak that develops l...
# 4772                      Little Lucky Red' Flower Form.
#
#                                                        3  \
# 423    Leaves are 2 foliate at the start of the seaso...
# 1703   Seeds small, plump, ovoid, pale, smooth with w...
# 12083  Â  The fruit are medium to small ellipsoid to ...
# 1815   The inflorescence varies in form, but is gener...
# 513    The first 2 leaves are opposite, bipinnately c...
# 11332               Clustering small palm, 1-2.5 m tall.
# 6252   Broadleaved Perennial Seed propagated Shrub Tr...
# 1427                    Leaf veins are prominent or not.
# 8545                                 Fruit color: white.
# 11616                   The fruits mature in 5-9 months.
# 1663   Cissus quadrangularis is a type of plant that ...
# 7632                       Inflorescence of V. africana.
# 12129                          On leaf margin and veins.
# 11612                   The fruits mature in 5-9 months.
# 3104   Capsule glabrescent, exserted on a tomentose p...
# 6632                      Shrub or small tree 1â15 in.
# 2380   The crushed, slender-petioled leaves are pleas...
# 2574             Inflorescences in axillary racemes, ca.
# 5141   The panicles consist of male and perfect herma...
# 4772                 Bandana Trailing Gold' Flower Form.
#
#                                                        4  \
# 423    Leaves are alternate at the ends of branches o...
# 1703   The stigma is receptive as the flower opens an...
# 12083          Leaf , roots , floral , fruit , endocarp.
# 1815   The pale yellow, cream or white flowers are ab...
# 513    Leaves are very characteristic, the 4-8 pairs ...
# 11332         Fruit cylindrical , about 10-18 x 5-10 mm.
# 6252   Main The castor bean plant is a tropical peren...
# 1427          It is a small much-branched tree or shrub.
# 8545                          Fruit length:.5 to 1 inch.
# 11616         A globular fruit cluster of the nipa palm.
# 1663               The tendrils are opposite the leaves.
# 7632   Voacanga Africana could grow up to heights of ...
# 12129  Their fronds â botanically a single leaf â...
# 11612         A globular fruit cluster of the nipa palm.
# 3104   Capsule 3-lobed, 8 × 8 mm, smooth, sparsely pi...
# 6632   Leaves:petiole eglandular , rhachis with a con...
# 2380   With the first rains of the next season, they ...
# 2574                 Bright medium green to light green.
# 5141   Flowers.The inflorescence can reach full bloom...
# 4772   These seeds are light brown in color and egg-s...
#
#                                                        5  \
# 423    Baobab is an indigenous fruit tree associated ...
# 1703   The Orangedog Caterpillar is a large, brown, g...
# 12083         Starting to show droopiness in the leaves.
# 1815                  Rootstocks of accession: own root.
# 513    Each leaf is separated into 4-8, and each of t...
# 11332    The small leaves have just a few wide leaflets.
# 6252   Plant name Family Context References Allium ce...
# 1427   Four white or white-pinkish petals, oblong, ob...
# 8545   Back in Stock Seeds A-Z Vines & Climbers Fruit...
# 11616      Â  A globular fruit cluster of the nipa palm.
# 1663                            The calyx is cup shaped.
# 7632          Paired, follicular fruits of V. thouarsii.
# 12129  Trunk: Multiple , usually sucker-producing, 2-...
# 11612      Â  A globular fruit cluster of the nipa palm.
# 3104   Capsule glabrescent, c. 8 Ã 8.5 mm, subglobos...
# 6632   Leaflets 6â10 pairs, elliptic, oblong-ellipt...
# 2380   The new twigs are angled and slender, yellow-b...
# 2574             Chromosome number in D. regia is 2n=28.
# 5141   The floral disc is also four- or five-lobed, f...
# 4772   The flower has a tutti frutti smell with a pep...
#
#                                           GoogleSentence  Jaccard Sum
# 423                  Crown: regular density of the crown     0.618627
# 1703                          Flower color: white flower     0.506818
# 12083            Minimum fruit width in centimeters: 2.0     0.536334
# 1815   Inflorescences: panicle of flowers or inflores...     0.697150
# 513                  Crown: regular density of the crown     0.692322
# 11332                                  Fruit size: small     0.625433
# 6252                                   Plant type: shrub     0.544719
# 1427                   Fruit: berry, or berry-like fruit     0.917929
# 8545                 Fruit colour: green, black, whitish     0.606349
# 11616           Maximum fruit width in centimeters: 10.0     0.507118
# 1663                 Crown: regular density of the crown     0.652259
# 7632   Inflorescences: corymb of flowers or infloresc...     0.708565
# 12129                          Maximum leaf number: 12.0     0.553176
# 11612           Minimum fruit length in centimeters: 8.0     0.507118
# 3104                                      Fruit: capsule     0.605021
# 6632   Inflorescences: rootlet or cluster of flowers ...     0.528409
# 2380   Vein: pinnate venation with secondary veins co...     0.580254
# 2574                     Bark color: slice in light bark     0.635354
# 5141                 Crown: regular density of the crown     0.605515
# 4772                          Flower color: white flower     0.709957
