# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn import metrics
import json
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import wordnet as wn
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk.corpus import stopwords
import collections
from itertools import groupby
import pickle
import re
import matplotlib.colors as mcolors
import warnings
import requests
import csv
from sklearn.preprocessing import MultiLabelBinarizer
from functools import reduce
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Global Variables & Functions

# %% [markdown]
# #### Variables

# %%
nouns = {x.name().split('.', 1)[0] for x in wn.all_synsets('n')}

colors = [color[4:] for color in mcolors.TABLEAU_COLORS.keys()]
colors.extend([color for color in mcolors.CSS4_COLORS.keys()])
colors.extend(
    [
        'whitish', 'bluish', 'reddish', 'greenish', 'backish', 'greyish',
        'backish', 'purplish', 'yellowish', 'orangish', 'brownish', 'pinkish'
    ]
)



traits_dict = {
    'Life Form':
    [
        'Tree', 'Shrub', 'Bush', 'Ficus', 'Strangler', 'Liana', 'Parasitic', 'Palm', 'Herbaceous'
    ],
    'Trunk':
    [
        'Trunk', 'Straight', 'Flared', 'Foothills', 'Silt', 'Aerial'
    ],
    'Root':
    [
        'Root', 'Straight', 'Flared', 'Foothills', 'Silt', 'Aerial'
    ],
    'Latex':
    [
        'Latex'
    ],
    'Phyllotaxis': # Leaf Position
    [
        'Phyllotaxis', 'Alternate', 'Whorled', 'Whorls', 'Opposite'
    ],
    'Leaf Composition':
    [
        'Palmate', 'Pinnate', 'Entire', 'Bi-pinnate'
    ],
    'Crown':
    [
        'Crown'
    ],
    'Stem':
    [
        'Stem', 'Circular', 'Square'
    ],
    'Bark':
    [
        'Bark'
    ],
    'Bark Colour':
    [
        'Bark'
    ],
    'Leaf Shape':
    [
        'Simple', 'Bifoliate', 'Trifoliate', 'Digitized', 'Paripinnate', 'Unipinnate', 'Imperipinnate', 
        'Alternate', 'Bipinnate', 'Pinnate', 'Elliptic', 'Elongate', 'Ovate', 'Round', 'Obovate', 'Lanceolate',
        'Kidney-shaped', 'Heart-shaped', 'Spathulate'
    ],
    'Petiole':
    [
        'Petiole', 'Sessile', 'Petiolated', 'Canaliculate', 'Glands', 'Glandular', 
     'Winged' 'Wings', 'Hairs', 'Hair', 'Translucent'
     ],
    'Leaf Colour':
    [
        'Leaf Colour', 'Leaf Color'
    ],
    'Leaf Blade':
    [
        'Leaf Blade', 'Linear', 'Lanceolate', 'Elliptical', 'Obovate', 'Obtriangular', 
        'Obtriangular', 'Asymmetrical', 'Orbicular', 'Bilobed', 'Lobed', 'Lobes', 'Lobe'
    ],
    'Leaf Base':
    [
        'Leaf Base', 'Rounded', 'Cordate', 'Glands'
    ],
    'Leaf Margin':
    [
        'Margin', 'Smooth', 'Wavy', 'Crenate', 'Toothed', 'Teeth', 'Crenate', 'Serrate'
    ],
    'Leaf Apex':
    [
        'Apex', 'Acuminate', 'Apiculate', 'Mucronate', 'Rounded', 'Emarginated'
    ],
    'Leaf side':
    [
        'Glabrous', 'Pubescent', 'Salt Crystals', 'Scales', 'Woolly', 'Powdery'
    ],
    'Leaf glands':
    [
        'Glands', 'Gland', 'Translucent'
    ],
    'Rachis':
    [
        'Rachis', 'Winged'
    ],
    'Vein':
    [
        'Vein'
    ],
    'Tendril':
    [
        'Tendril'
    ],
    'Spine':
    [
        'Spine', 'Prickle', 'Spines', 'Prickles'
    ],
    'Thornes':
    [
        'Thorn', 'Thornes'
    ],
    'Blade Colour':
    [
        'Blade'
    ],
    'Fruit':
    [
        'Drupe', 'Berry', 'Capsule', 'Pod', 'Follicle', 'Achene', 'Winged', 'Follicle',
        'Pod', 'Nutlet', 'Fruit'
    ],
    'Fruit Shape':
    [
        'locular', 'Globose', 'Flattened', 'Elongate', 'Obovoid', 'Ovate', 'Twisted',
        'Curved', 'Pyriform', 'Ovoid'
    ],
    'Fruit Colour':
    [
        'Fruit'
    ],
    'Inflorescences':
    [
        'Inflorescences', 'Inflorescence', 'Sessile', 'Panicle', 'Flower head', 'Cyme', 'Glomerule', 
        'Fascicle', 'Umbel', 'Corymb', 'Rootlet', 'Spike', 'Dichasium', 'Fascicle',
        'Globose', 'Raceme', 'Fascicle', 'Umbel'
     ],
    'Sexuality':
    [
        'Sexuality', 'Axillary', 'Terminal'
    ],
    'Flower Colour':
    [
        'Flower colour', 'Flower color', 'Flower', 'Flowers'
    ],
    'Flower Shape':
    [
        'Flower shape', 'Petalled', 'Petal', 'Petals', 'Tubular', 'Apetal', 'Butterfly-shaped', 'Shaped', 'Flower', 'Flowers'
    ],
    'Sepal Shape':
    [
        'Sepal', 'Sepals', 'Connate'
    ],
    'Petal Shape':
    [
        'Petal', 'Petals', 'Tepals', 'Tepal', 'Tubular'
    ],
    'Aril Colour':
    [
        'Aril'
    ],
    'Seed Colour':
    [
        'Seed', 
    ],
    'Conspicuousness':
    [
        'Conspicuousness', 'Cryptic'
    ]
}

with open('../../data/supportive/traits_Pierre_and_Andrei.json', 'w') as f:
    json.dump(traits_dict, f)
with open('../../data/supportive/colour_list.json', 'w') as f:
    json.dump(colors, f)

traits_list = list(traits_dict.keys())
traits_list += [trait.lower() for lst in list(traits_dict.values()) for trait in lst]

# %% [markdown]
# #### Functions

# %%
def corresponding_keys(val, dictionary):
    """returns the corresponding key of a single value 
    assuming the values are lists.

    Args:
        val (string): string present in the dict
        dictionary (dict): dict with lists of stings as values

    Returns:
        list: list of matching keys
    """
    # Init list
    keys = []
    # Search the dict
    for k, v in dictionary.items():
        if val in v:
            keys.append(k)
    return keys
    
def jaccard_similarity(A, B):
    """Calculates the Jaccard similarity two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    A = set(A)
    B = set(B)
    
    # Get intersection of two sets
    nominator = A.intersection(B)

    # Find union of two sets
    denominator = A.union(B)

    # Take the ratio of sizes
    similarity = len(nominator)/len(denominator)

    return similarity


def similarity(groundtruth, pred):
    """Calculates the normal similarity between two sets.

    Args:
        A (Set): Set A
        B (Set): Set B

    Returns:
        Integer: 0.00 - 1.00
    """

    # Create sets just in case
    groundtruth = set(groundtruth)
    pred = set(pred)

    # Find intersection of two sets
    nominator = groundtruth.intersection(pred)

    # Find union of two sets
    denominator = groundtruth

    # Take the ratio of sizes
    similarity = len(nominator)/(len(denominator))

    return similarity

def resentesize(lst):

    sentence = ''

    # Loop every 2 items 
    for item1, item2 in zip(lst[::2], lst[1::2]):
        
        # Set verb
        verb = 'has'
        chunk = item2.split(' ')[-1]
        if chunk not in nouns or chunk in colors:
            verb = 'is'

        sentence += f'{item1.capitalize()} {verb} {item2}. '
    
    return sentence


def get_wiki_main_image(title):
    url = 'https://en.wikipedia.org/w/api.php'
    data = {
        'action' :'query',
        'format' : 'json',
        'formatversion' : 2,
        'prop' : 'pageimages|pageterms',
        'piprop' : 'original',
        'titles' : title
    }
    response = requests.get(url, data)
    json_data = json.loads(response.text)
    return json_data['query']['pages'][0]['original']['source'] if len(json_data['query']['pages']) >0 else 'Not found'

# %% [markdown]
# ### Load GT Data

# %%
root = "../../data/external/"

# %% [markdown]
# #### Data Andrei

# %%
file_name = root + 'Dataset_Andrei.csv'
df_Andrei = pd.read_csv(file_name)

# Get Dummies to match DF Pierre
df_Andrei_dummies = pd.get_dummies(df_Andrei.iloc[:, 2:])
# Set species back
df_Andrei_dummies = df_Andrei_dummies.set_index(df_Andrei['Species'])

# Create tuple list for multi index
Andrei_multi_index = []
for top_index in df_Andrei.columns:
    for sub_index in df_Andrei_dummies.columns:
        if top_index in sub_index:

            sub_index = sub_index.split('_')[-1]
            Andrei_multi_index.append((top_index, sub_index))

# Set Mutli index
df_Andrei_dummies.columns = pd.MultiIndex.from_tuples(Andrei_multi_index)
df_Andrei_dummies
# Out:
#                            Life form      Leaf position                      \
#                                liana tree     alternate alternate, opposite
# Species
# Avicennia germinans                0    1             0                   0
# Metopium brownei                   0    1             1                   0
# Handroanthus billbergii            0    1             0                   0
# Bourreria succulenta               0    1             1                   0
# Bursera karsteniana                0    1             1                   0
# Bursera simaruba                   0    1             1                   0
# Bursera tomentosa                  0    1             1                   0
# Cynophalla flexuosa                1    0             1                   0
# Cynophalla hastata                 0    1             1                   0
# Quadrella indica                   0    1             1                   0
# Quadrella odoratissima             0    1             1                   0
# Crossopetalum rhacoma              0    1             0                   0
# Maytenus tetragona                 0    1             1                   0
# Maytenus versluysii                0    1             1                   0
# Clusia rosea                       0    1             0                   0
# Conocarpus erectus                 0    1             1                   0
# Laguncularia racemosa              0    1             0                   0
# Erythroxylum havanense             0    1             1                   0
# Croton niveus                      0    1             1                   0
# Hippomane mancinella               0    1             1                   0
# Libidibia coriaria                 0    1             1                   0
# Pithecellobium unguis-cati         0    1             1                   0
# Prosopis juliflora                 0    1             1                   0
# Vachellia tortuosa                 0    1             1                   0
# Vitex compressa                    0    1             0                   0
# Vitex cymosa                       0    1             0                   0
# Trichilia trifolia                 0    1             1                   0
# Eugenia procera                    0    1             0                   0
# Guapira pacurero                   0    1             0                   0
# Coccoloba swartzii                 0    1             1                   0
# Coccoloba uvifera                  0    1             1                   0
# Krugiodendron ferreum              0    1             0                   1
# Rhizophora mangle                  0    1             0                   0
# Guettarda roupalifolia             0    1             0                   0
# Randia aculeata                    0    1             0                   0
# Amyris ignea                       0    1             1                   0
# Zanthoxylum monophyllum            0    1             1                   0
# Casearia tremula                   0    1             1                   0
# Schoepfia schreberi                0    1             1                   0
# Jacquinia arborea                  0    1             1                   0
# Guaiacum officinale                0    1             0                   0
# Guaiacum sanctum                   0    1             0                   0
#
#                                                            \
#                            opposite opposite, whorls of 3
# Species
# Avicennia germinans               1                     0
# Metopium brownei                  0                     0
# Handroanthus billbergii           1                     0
# Bourreria succulenta              0                     0
# Bursera karsteniana               0                     0
# Bursera simaruba                  0                     0
# Bursera tomentosa                 0                     0
# Cynophalla flexuosa               0                     0
# Cynophalla hastata                0                     0
# Quadrella indica                  0                     0
# Quadrella odoratissima            0                     0
# Crossopetalum rhacoma             0                     0
# Maytenus tetragona                0                     0
# Maytenus versluysii               0                     0
# Clusia rosea                      1                     0
# Conocarpus erectus                0                     0
# Laguncularia racemosa             1                     0
# Erythroxylum havanense            0                     0
# Croton niveus                     0                     0
# Hippomane mancinella              0                     0
# Libidibia coriaria                0                     0
# Pithecellobium unguis-cati        0                     0
# Prosopis juliflora                0                     0
# Vachellia tortuosa                0                     0
# Vitex compressa                   1                     0
# Vitex cymosa                      1                     0
# Trichilia trifolia                0                     0
# Eugenia procera                   1                     0
# Guapira pacurero                  1                     0
# Coccoloba swartzii                0                     0
# Coccoloba uvifera                 0                     0
# Krugiodendron ferreum             0                     0
# Rhizophora mangle                 1                     0
# Guettarda roupalifolia            1                     0
# Randia aculeata                   0                     1
# Amyris ignea                      0                     0
# Zanthoxylum monophyllum           0                     0
# Casearia tremula                  0                     0
# Schoepfia schreberi               0                     0
# Jacquinia arborea                 0                     0
# Guaiacum officinale               1                     0
# Guaiacum sanctum                  1                     0
#
#                                                             Leaf composition  \
#                            opposite, whorls of 3, alternate        3 palmate
# Species
# Avicennia germinans                                       0                0
# Metopium brownei                                          0                0
# Handroanthus billbergii                                   0                0
# Bourreria succulenta                                      0                0
# Bursera karsteniana                                       0                0
# Bursera simaruba                                          0                0
# Bursera tomentosa                                         0                0
# Cynophalla flexuosa                                       0                0
# Cynophalla hastata                                        0                0
# Quadrella indica                                          0                0
# Quadrella odoratissima                                    0                0
# Crossopetalum rhacoma                                     1                0
# Maytenus tetragona                                        0                0
# Maytenus versluysii                                       0                0
# Clusia rosea                                              0                0
# Conocarpus erectus                                        0                0
# Laguncularia racemosa                                     0                0
# Erythroxylum havanense                                    0                0
# Croton niveus                                             0                0
# Hippomane mancinella                                      0                0
# Libidibia coriaria                                        0                0
# Pithecellobium unguis-cati                                0                0
# Prosopis juliflora                                        0                0
# Vachellia tortuosa                                        0                0
# Vitex compressa                                           0                0
# Vitex cymosa                                              0                0
# Trichilia trifolia                                        0                1
# Eugenia procera                                           0                0
# Guapira pacurero                                          0                0
# Coccoloba swartzii                                        0                0
# Coccoloba uvifera                                         0                0
# Krugiodendron ferreum                                     0                0
# Rhizophora mangle                                         0                0
# Guettarda roupalifolia                                    0                0
# Randia aculeata                                           0                0
# Amyris ignea                                              0                0
# Zanthoxylum monophyllum                                   0                0
# Casearia tremula                                          0                0
# Schoepfia schreberi                                       0                0
# Jacquinia arborea                                         0                0
# Guaiacum officinale                                       0                0
# Guaiacum sanctum                                          0                0
#
#                                                     ... Aril colour            \
#                            3-5 palmate 3-5 pinnate  ...      orange red white
# Species                                             ...
# Avicennia germinans                  0           0  ...           0   0     0
# Metopium brownei                     0           1  ...           0   0     0
# Handroanthus billbergii              0           1  ...           0   0     0
# Bourreria succulenta                 0           0  ...           0   0     0
# Bursera karsteniana                  0           0  ...           0   0     0
# Bursera simaruba                     0           0  ...           0   0     0
# Bursera tomentosa                    0           0  ...           0   0     0
# Cynophalla flexuosa                  0           0  ...           0   0     1
# Cynophalla hastata                   0           0  ...           0   0     1
# Quadrella indica                     0           0  ...           0   0     1
# Quadrella odoratissima               0           0  ...           0   0     1
# Crossopetalum rhacoma                0           0  ...           0   0     0
# Maytenus tetragona                   0           0  ...           0   0     1
# Maytenus versluysii                  0           0  ...           0   0     1
# Clusia rosea                         0           0  ...           1   0     0
# Conocarpus erectus                   0           0  ...           0   0     0
# Laguncularia racemosa                0           0  ...           0   0     0
# Erythroxylum havanense               0           0  ...           0   0     0
# Croton niveus                        0           0  ...           0   0     0
# Hippomane mancinella                 0           0  ...           0   0     0
# Libidibia coriaria                   0           0  ...           0   0     0
# Pithecellobium unguis-cati           0           0  ...           0   0     1
# Prosopis juliflora                   0           0  ...           0   0     0
# Vachellia tortuosa                   0           0  ...           0   0     0
# Vitex compressa                      1           0  ...           0   0     0
# Vitex cymosa                         1           0  ...           0   0     0
# Trichilia trifolia                   0           0  ...           1   0     0
# Eugenia procera                      0           0  ...           0   0     0
# Guapira pacurero                     0           0  ...           0   0     0
# Coccoloba swartzii                   0           0  ...           0   0     0
# Coccoloba uvifera                    0           0  ...           0   0     0
# Krugiodendron ferreum                0           0  ...           0   0     0
# Rhizophora mangle                    0           0  ...           0   0     0
# Guettarda roupalifolia               0           0  ...           0   0     0
# Randia aculeata                      0           0  ...           0   0     0
# Amyris ignea                         0           0  ...           0   0     0
# Zanthoxylum monophyllum              0           0  ...           0   0     0
# Casearia tremula                     0           0  ...           1   0     0
# Schoepfia schreberi                  0           0  ...           0   0     0
# Jacquinia arborea                    0           0  ...           0   0     0
# Guaiacum officinale                  0           0  ...           0   1     0
# Guaiacum sanctum                     0           0  ...           0   1     0
#
#                                        Seed colour                         \
#                            yellow-geen       black brown green grey white
# Species
# Avicennia germinans                  0           0     0     1    0     0
# Metopium brownei                     0           0     0     0    0     0
# Handroanthus billbergii              0           0     0     0    0     0
# Bourreria succulenta                 0           0     0     0    0     0
# Bursera karsteniana                  0           0     0     0    0     0
# Bursera simaruba                     0           0     0     0    0     0
# Bursera tomentosa                    0           0     0     0    0     0
# Cynophalla flexuosa                  0           1     0     0    0     0
# Cynophalla hastata                   0           1     0     0    0     0
# Quadrella indica                     0           1     0     0    0     0
# Quadrella odoratissima               0           1     0     0    0     0
# Crossopetalum rhacoma                0           0     0     0    0     0
# Maytenus tetragona                   0           1     0     0    0     0
# Maytenus versluysii                  0           1     0     0    0     0
# Clusia rosea                         0           0     0     0    0     0
# Conocarpus erectus                   0           0     0     0    0     0
# Laguncularia racemosa                0           0     0     1    0     0
# Erythroxylum havanense               0           0     0     0    0     0
# Croton niveus                        0           0     0     0    0     0
# Hippomane mancinella                 0           0     0     0    1     0
# Libidibia coriaria                   0           0     1     0    0     0
# Pithecellobium unguis-cati           0           1     0     0    0     0
# Prosopis juliflora                   1           0     1     0    0     0
# Vachellia tortuosa                   0           0     1     0    0     0
# Vitex compressa                      0           0     0     0    0     0
# Vitex cymosa                         0           0     0     0    0     0
# Trichilia trifolia                   0           0     0     0    0     1
# Eugenia procera                      0           1     0     0    0     0
# Guapira pacurero                     0           1     0     0    0     0
# Coccoloba swartzii                   0           1     0     0    0     0
# Coccoloba uvifera                    0           1     0     0    0     0
# Krugiodendron ferreum                0           1     0     0    0     0
# Rhizophora mangle                    0           0     0     1    0     0
# Guettarda roupalifolia               0           0     1     0    0     0
# Randia aculeata                      0           0     1     0    0     0
# Amyris ignea                         0           0     0     0    0     0
# Zanthoxylum monophyllum              0           0     1     0    0     0
# Casearia tremula                     0           1     0     0    0     0
# Schoepfia schreberi                  0           0     0     0    0     0
# Jacquinia arborea                    0           0     1     0    0     0
# Guaiacum officinale                  0           0     1     0    0     0
# Guaiacum sanctum                     0           0     1     0    0     0
#
#
#                            whitish
# Species
# Avicennia germinans              0
# Metopium brownei                 0
# Handroanthus billbergii          1
# Bourreria succulenta             0
# Bursera karsteniana              0
# Bursera simaruba                 0
# Bursera tomentosa                0
# Cynophalla flexuosa              0
# Cynophalla hastata               0
# Quadrella indica                 0
# Quadrella odoratissima           0
# Crossopetalum rhacoma            0
# Maytenus tetragona               0
# Maytenus versluysii              0
# Clusia rosea                     0
# Conocarpus erectus               0
# Laguncularia racemosa            0
# Erythroxylum havanense           0
# Croton niveus                    0
# Hippomane mancinella             0
# Libidibia coriaria               0
# Pithecellobium unguis-cati       0
# Prosopis juliflora               0
# Vachellia tortuosa               0
# Vitex compressa                  0
# Vitex cymosa                     0
# Trichilia trifolia               0
# Eugenia procera                  0
# Guapira pacurero                 0
# Coccoloba swartzii               0
# Coccoloba uvifera                0
# Krugiodendron ferreum            0
# Rhizophora mangle                0
# Guettarda roupalifolia           0
# Randia aculeata                  0
# Amyris ignea                     0
# Zanthoxylum monophyllum          0
# Casearia tremula                 0
# Schoepfia schreberi              0
# Jacquinia arborea                0
# Guaiacum officinale              0
# Guaiacum sanctum                 0
#
# [42 rows x 202 columns]

# %% [markdown]
# #### Data Pierre

# %%
file_name = root + 'Dataset_Pierre.csv'
df_Pierre = pd.read_csv(file_name, header=[0, 1]) 
df_Pierre = df_Pierre.iloc[: , 1:]
df_Pierre = df_Pierre.set_index(df_Pierre['Species']['species'])
df_Pierre = df_Pierre.drop(columns=['Species'])
df_Pierre
# Out:
# /var/folders/0p/7b4jnnp15d5gx16h36l4ycx00000gn/T/ipykernel_31715/3001850027.py:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df_Pierre = df_Pierre.drop(columns=['Species'])
#                             plant type                                   \
#                                   Tree Shrub Bush Ficus strangler Liana
# species
# Acacia amythethophylla               1     1    0               0     0
# Acacia ataxacantha                   1     1    1               0     1
# Acacia dudgeoni                      1     1    0               0     0
# Acacia ehrenbergiana                 1     1    0               0     0
# Acacia erythrocalyx                  0     0    1               0     1
# ...                                ...   ...  ...             ...   ...
# Ziziphus abyssinica                  1     1    1               0     0
# Ziziphus lotus ssp. saharae          0     1    1               0     0
# Ziziphus mauritiana                  1     1    1               0     0
# Ziziphus mucronata                   1     1    1               0     0
# Ziziphus spina-christi               0     1    1               0     0
#
#                                                             \
#                             Parasitic Palm tree Herbaceous
# species
# Acacia amythethophylla              0         0          0
# Acacia ataxacantha                  0         0          0
# Acacia dudgeoni                     0         0          0
# Acacia ehrenbergiana                0         0          0
# Acacia erythrocalyx                 0         0          0
# ...                               ...       ...        ...
# Ziziphus abyssinica                 0         0          0
# Ziziphus lotus ssp. saharae         0         0          0
# Ziziphus mauritiana                 0         0          0
# Ziziphus mucronata                  0         0          0
# Ziziphus spina-christi              0         0          0
#
#                                       phyllotaxis                       ...  \
#                             Phyllotaxis alternate Opposite phyllotaxis  ...
# species                                                                 ...
# Acacia amythethophylla                          1                    0  ...
# Acacia ataxacantha                              1                    0  ...
# Acacia dudgeoni                                 1                    0  ...
# Acacia ehrenbergiana                            1                    0  ...
# Acacia erythrocalyx                             1                    0  ...
# ...                                           ...                  ...  ...
# Ziziphus abyssinica                             1                    0  ...
# Ziziphus lotus ssp. saharae                     1                    0  ...
# Ziziphus mauritiana                             1                    0  ...
# Ziziphus mucronata                              1                    0  ...
# Ziziphus spina-christi                          1                    0  ...
#
#                                       flower color                        \
#                             Yellow coloured flower Green coloured flower
# species
# Acacia amythethophylla                           1                     0
# Acacia ataxacantha                               1                     0
# Acacia dudgeoni                                  1                     0
# Acacia ehrenbergiana                             1                     0
# Acacia erythrocalyx                              0                     0
# ...                                            ...                   ...
# Ziziphus abyssinica                              1                     0
# Ziziphus lotus ssp. saharae                      1                     0
# Ziziphus mauritiana                              1                     0
# Ziziphus mucronata                               1                     0
# Ziziphus spina-christi                           1                     1
#
#                                       flower shape                        \
#                             Single-petalled flower Three-petalled flower
# species
# Acacia amythethophylla                           0                     0
# Acacia ataxacantha                               0                     0
# Acacia dudgeoni                                  0                     0
# Acacia ehrenbergiana                             0                     0
# Acacia erythrocalyx                              0                     0
# ...                                            ...                   ...
# Ziziphus abyssinica                              0                     0
# Ziziphus lotus ssp. saharae                      0                     0
# Ziziphus mauritiana                              0                     0
# Ziziphus mucronata                               0                     0
# Ziziphus spina-christi                           0                     0
#
#                                                                        \
#                             Four-petalled flower Five-petalled flower
# species
# Acacia amythethophylla                         0                    1
# Acacia ataxacantha                             0                    1
# Acacia dudgeoni                                0                    1
# Acacia ehrenbergiana                           0                    1
# Acacia erythrocalyx                            0                    1
# ...                                          ...                  ...
# Ziziphus abyssinica                            0                    1
# Ziziphus lotus ssp. saharae                    0                    1
# Ziziphus mauritiana                            0                    1
# Ziziphus mucronata                             0                    1
# Ziziphus spina-christi                         0                    1
#
#                                                                          \
#                             Flower with 6 or more petals Tubular flower
# species
# Acacia amythethophylla                                 0              1
# Acacia ataxacantha                                     0              1
# Acacia dudgeoni                                        0              1
# Acacia ehrenbergiana                                   0              1
# Acacia erythrocalyx                                    0              1
# ...                                                  ...            ...
# Ziziphus abyssinica                                    0              0
# Ziziphus lotus ssp. saharae                            0              0
# Ziziphus mauritiana                                    0              0
# Ziziphus mucronata                                     0              0
# Ziziphus spina-christi                                 0              0
#
#
#                             Butterfly-shaped flower Apetal flower
# species
# Acacia amythethophylla                            0             0
# Acacia ataxacantha                                0             0
# Acacia dudgeoni                                   0             0
# Acacia ehrenbergiana                              0             0
# Acacia erythrocalyx                               0             0
# ...                                             ...           ...
# Ziziphus abyssinica                               0             0
# Ziziphus lotus ssp. saharae                       0             0
# Ziziphus mauritiana                               0             0
# Ziziphus mucronata                                0             0
# Ziziphus spina-christi                            0             0
#
# [361 rows x 135 columns]

# %% [markdown]
# #### Data Palms

# %%
file_name = root + 'Dataset_Kissling.txt'
df_Daniel = pd.read_csv(file_name,
                 sep='\t', encoding='Latin-1')
palm_species = df_Daniel[~df_Daniel.isnull().any(axis=1)]['SpecName'].values
df_Daniel.set_index('SpecName', inplace=True)

### RESHAPE DATA FOR PALMS

# Exclude string types
df_Daniels_int = df_Daniel.select_dtypes(exclude=[object])
df_Daniels_str = df_Daniel.select_dtypes(include=[object])
# Drop numbers
df_Daniels_semi_ints = df_Daniels_int.loc[:, df_Daniels_int.max() <= 3]
# Merge again
df_Daniel_edit = pd.merge(df_Daniels_str, df_Daniels_semi_ints, left_index=True, right_index=True)

# Get colors as lst of lsts 
FruitColorDescription_colors_lst = []

for palm_colors in df_Daniels_str['FruitColorDescription'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        FruitColorDescription_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        FruitColorDescription_colors_lst.append([])

MainFruitColors_colors_lst = []

for palm_colors in df_Daniels_str['MainFruitColors'].values:
    if type(palm_colors) == str:
        #print(type(colors))
        palm_colors = re.split(r'; |to | |-', palm_colors)

        #print(palm_colors)
        MainFruitColors_colors_lst.append([color for color in palm_colors if color in colors])
    else:
        MainFruitColors_colors_lst.append([])

# Init SKlearn MLB
mlb = MultiLabelBinarizer()

# Create dummies for color columns
df_FruitColorDescription = pd.DataFrame(
    {
        'FruitColorDescription': FruitColorDescription_colors_lst
    }, columns=['FruitColorDescription'])

s = df_FruitColorDescription['FruitColorDescription']
df_FruitColorDescription = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour Description', column) for column in df_FruitColorDescription.columns]
df_FruitColorDescription.columns = pd.MultiIndex.from_tuples(columns)

# Create dummies for color columns
df_MainFruitColors = pd.DataFrame(
    {
        'MainFruitColors': MainFruitColors_colors_lst
    }, columns=['MainFruitColors'])

s = df_MainFruitColors['MainFruitColors']
df_MainFruitColors = pd.DataFrame(mlb.fit_transform(s),columns=mlb.classes_, index=df_Daniel.index)

# Multiindex columns
columns = [('Fruit Colour', column) for column in df_MainFruitColors.columns]
df_MainFruitColors.columns = pd.MultiIndex.from_tuples(columns)

df_Daniels_str_non_color = df_Daniels_str[['UnderstoreyCanopy', 'FruitSizeCategorical', 'FruitShape', 'Conspicuousness']]

# df_Daniels_str_non_color.columns = pd.MultiIndex.from_tuples(
#     [
#         ('Crown', 'UnderstoreyCanopy'),
#         ('Fruit Size', 'FruitSizeCategorical'),
#         ('Fruit Shape', 'FruitShape'),
#         ('Conspicuousness', 'Conspicuousness'),
#     ]
# )

df_Daniels_str_non_color_dummies = pd.get_dummies(df_Daniels_str_non_color)
columns = []
for column in df_Daniels_str_non_color_dummies.columns:
    level0, level1 = column.split('_')
    if level0 == 'UnderstoreyCanopy':
        level0 = 'Crown'
    elif level0 == 'FruitSizeCategorical':
        level0 = 'Fruit Size'
    elif level0 == 'FruitShape':
        level0 = 'Fruit Shape'
    elif level0 == 'Conspicuousness':
        level0 = 'Conspicuousness'
    columns.append((level0, level1))
    
df_Daniels_str_non_color_dummies.columns = pd.MultiIndex.from_tuples(columns)

### JOIN ALL DATA
data_frames = [df_FruitColorDescription, df_MainFruitColors, df_Daniels_str_non_color_dummies]
df_Daniel_merged = pd.concat(data_frames, axis=1)
df_Daniel_merged
# Out:
#                          Fruit Colour Description                             \
#                                             black blue bluish brown brownish
# SpecName
# Acanthophoenix crinita                          1    0      0     0        0
# Acanthophoenix rousselii                        1    0      0     0        0
# Acanthophoenix rubra                            1    0      0     0        0
# Acoelorrhaphe wrightii                          1    0      0     1        0
# Acrocomia aculeata                              0    0      0     0        0
# ...                                           ...  ...    ...   ...      ...
# Wettinia quinaria                               0    0      0     1        0
# Wettinia radiata                                0    0      0     0        0
# Wettinia verruculosa                            0    0      0     1        0
# Wodyetia bifurcata                              0    0      0     0        0
# Zombia antillarum                               0    0      0     0        0
#
#                                                                   ...  \
#                          chocolate coral crimson darkgreen green  ...
# SpecName                                                          ...
# Acanthophoenix crinita           0     0       0         0     0  ...
# Acanthophoenix rousselii         0     0       0         0     0  ...
# Acanthophoenix rubra             0     0       0         0     0  ...
# Acoelorrhaphe wrightii           0     0       0         0     0  ...
# Acrocomia aculeata               0     0       0         0     1  ...
# ...                            ...   ...     ...       ...   ...  ...
# Wettinia quinaria                0     0       0         0     1  ...
# Wettinia radiata                 0     0       0         0     0  ...
# Wettinia verruculosa             0     0       0         0     1  ...
# Wodyetia bifurcata               0     0       0         0     0  ...
# Zombia antillarum                0     0       0         0     0  ...
#
#                          Fruit Size Fruit Shape                            \
#                               small   ellipsoid elongate fusiform globose
# SpecName
# Acanthophoenix crinita            1           0        0        0       0
# Acanthophoenix rousselii          1           0        0        0       0
# Acanthophoenix rubra              1           0        0        0       0
# Acoelorrhaphe wrightii            1           0        0        0       0
# Acrocomia aculeata                0           0        0        0       0
# ...                             ...         ...      ...      ...     ...
# Wettinia quinaria                 1           0        0        0       0
# Wettinia radiata                  0           0        0        0       1
# Wettinia verruculosa              1           0        0        0       0
# Wodyetia bifurcata                0           0        0        0       1
# Zombia antillarum                 1           0        0        0       0
#
#                                                  Conspicuousness
#                          ovoid pyramidal rounded     conspicuous cryptic
# SpecName
# Acanthophoenix crinita       0         0       0               0       1
# Acanthophoenix rousselii     1         0       0               0       1
# Acanthophoenix rubra         1         0       0               0       1
# Acoelorrhaphe wrightii       1         0       0               0       1
# Acrocomia aculeata           1         0       0               0       1
# ...                        ...       ...     ...             ...     ...
# Wettinia quinaria            1         0       0               0       1
# Wettinia radiata             0         0       0               1       0
# Wettinia verruculosa         1         0       0               0       1
# Wodyetia bifurcata           0         0       0               1       0
# Zombia antillarum            1         0       0               0       1
#
# [2557 rows x 57 columns]

# %%
df_Daniels_int.loc[:, df_Daniels_int.max() >= 3]
# Out:
#                           MaxStemHeight_m  MaxStemDia_cm  MaxLeafNumber  \
# SpecName
# Acanthophoenix crinita               10.0           20.0           15.0
# Acanthophoenix rousselii             25.0           30.0            NaN
# Acanthophoenix rubra                 15.0           18.0           20.0
# Acoelorrhaphe wrightii                9.1           15.0           25.0
# Acrocomia aculeata                   12.0           50.0           30.0
# ...                                   ...            ...            ...
# Wettinia quinaria                    15.0           20.0            6.0
# Wettinia radiata                      9.0           10.0            6.0
# Wettinia verruculosa                 10.0           20.0            6.0
# Wodyetia bifurcata                   15.0           25.0           10.0
# Zombia antillarum                     3.0           10.0           12.0
#
#                           Max_Blade_Length_m  Max_Rachis_Length_m  \
# SpecName
# Acanthophoenix crinita                  2.30                  NaN
# Acanthophoenix rousselii                3.00                  NaN
# Acanthophoenix rubra                    3.10                  3.0
# Acoelorrhaphe wrightii                  1.30                  0.7
# Acrocomia aculeata                      3.50                  2.5
# ...                                      ...                  ...
# Wettinia quinaria                       5.50                  3.2
# Wettinia radiata                        4.33                  3.4
# Wettinia verruculosa                    6.00                  3.7
# Wodyetia bifurcata                      3.20                  2.3
# Zombia antillarum                       1.20                  1.0
#
#                           Max_Petiole_length_m  AverageFruitLength_cm  \
# SpecName
# Acanthophoenix crinita                     NaN                   0.65
# Acanthophoenix rousselii                   NaN                   2.00
# Acanthophoenix rubra                       NaN                   1.00
# Acoelorrhaphe wrightii                    0.65                   0.70
# Acrocomia aculeata                         NaN                   4.25
# ...                                        ...                    ...
# Wettinia quinaria                         1.35                   2.75
# Wettinia radiata                           NaN                   4.00
# Wettinia verruculosa                      2.40                   2.50
# Wodyetia bifurcata                        1.02                   5.75
# Zombia antillarum                          NaN                   1.75
#
#                           MinFruitLength_cm  MaxFruitLength_cm  \
# SpecName
# Acanthophoenix crinita                  0.6                0.7
# Acanthophoenix rousselii                NaN                NaN
# Acanthophoenix rubra                    NaN                NaN
# Acoelorrhaphe wrightii                  NaN                NaN
# Acrocomia aculeata                      3.5                5.0
# ...                                     ...                ...
# Wettinia quinaria                       2.0                3.5
# Wettinia radiata                        3.0                4.0
# Wettinia verruculosa                    NaN                NaN
# Wodyetia bifurcata                      5.0                6.5
# Zombia antillarum                       NaN                NaN
#
#                           AverageFruitWidth_cm  MinFruitWidth_cm  \
# SpecName
# Acanthophoenix crinita                    0.50               NaN
# Acanthophoenix rousselii                  0.80               NaN
# Acanthophoenix rubra                      0.70               NaN
# Acoelorrhaphe wrightii                    0.70               0.5
# Acrocomia aculeata                        4.60               3.8
# ...                                        ...               ...
# Wettinia quinaria                         2.00               1.5
# Wettinia radiata                          2.00               NaN
# Wettinia verruculosa                      1.50               NaN
# Wodyetia bifurcata                        4.35               2.7
# Zombia antillarum                         1.75               1.5
#
#                           MaxFruitWidth_cm
# SpecName
# Acanthophoenix crinita                 NaN
# Acanthophoenix rousselii               NaN
# Acanthophoenix rubra                   NaN
# Acoelorrhaphe wrightii                 0.9
# Acrocomia aculeata                     5.4
# ...                                    ...
# Wettinia quinaria                      2.5
# Wettinia radiata                       NaN
# Wettinia verruculosa                   NaN
# Wodyetia bifurcata                     6.0
# Zombia antillarum                      2.0
#
# [2557 rows x 12 columns]

# %% [markdown]
# ## Prediction Data

# %% [markdown]
# ### Load Data

# %%
root = "../../data/processed/"
sentences_all = {}

f = open(F"{root}Sentences_Pierre.pkl", 'rb')
sentences_Pierre = pickle.load(f)
sentences_all |= sentences_Pierre 

f = open(F"{root}Sentences_Andrei.pkl", 'rb')
sentences_Andrei = pickle.load(f)
sentences_all |= sentences_Andrei 

f = open(F"{root}Sentences_Kissling.pkl", 'rb')
sentences_Kissling = pickle.load(f)
sentences_all |= sentences_Kissling 

# Drop duplicates
for species, sentences in sentences_all.items():
    sentences_all[species] = list(set(sentences))

# %% [markdown]
# ### Match Data

# %%
k= 5
google_form_lst = []

for idx, (species, sentences) in enumerate(tqdm(sentences_all.items())):

    # if idx < 400:
    #     continue
    
    df_select = [df_Andrei_dummies, df_Pierre, df_Daniel_merged]
    if species in df_Andrei_dummies.index:
        df_select = df_select[0]
    elif species in df_Pierre.index:
        df_select = df_select[1]
    elif species in df_Daniel_merged.index:
        df_select = df_select[2]
    else:
        raise ValueError

    for gt_main_trait in df_select.columns.get_level_values(0).unique():
        df_subset = df_select[df_select.index == species][gt_main_trait]
        present_traits = df_subset.loc[:, df_subset.any()].columns.values
        df_sent  = ' '.join(gt_main_trait + ' ' + present_traits)

        top_list = []

        for sentence in sentences:
            gt_sim = jaccard_similarity(sentence, df_sent)
            top_list.append((gt_sim, sentence))

        top_list.sort(reverse=True)
        top_k_list = [sentence for (_, sentence) in top_list[0:k]]

        google_form_lst.append((species, gt_main_trait, gt_main_trait, list(present_traits), *top_k_list))
# Out:
# 100%|██████████| 647/647 [00:15<00:00, 42.16it/s]

# %% [markdown]
# ### Create Subset

# %%
# Google forms
df_google = pd.DataFrame(google_form_lst, columns=['Species', 'Main Trait', 'GT Main Trait', 'GT Sub Traits', '1', '2', '3', '4', '5'])
df_google
# Out:
#                       Species       Main Trait    GT Main Trait  \
# 0      Acacia amythethophylla       plant type       plant type
# 1      Acacia amythethophylla      phyllotaxis      phyllotaxis
# 2      Acacia amythethophylla   trunk and root   trunk and root
# 3      Acacia amythethophylla            latex            latex
# 4      Acacia amythethophylla            crown            crown
# ...                       ...              ...              ...
# 11077      Wodyetia bifurcata     Fruit Colour     Fruit Colour
# 11078      Wodyetia bifurcata            Crown            Crown
# 11079      Wodyetia bifurcata       Fruit Size       Fruit Size
# 11080      Wodyetia bifurcata      Fruit Shape      Fruit Shape
# 11081      Wodyetia bifurcata  Conspicuousness  Conspicuousness
#
#                          GT Sub Traits  \
# 0                        [Tree, Shrub]
# 1              [Phyllotaxis alternate]
# 2             [Base of trunk straight]
# 3                         [No exudate]
# 4      [Horizontally spreading crowns]
# ...                                ...
# 11077                            [red]
# 11078                         [canopy]
# 11079                          [large]
# 11080                        [globose]
# 11081                    [conspicuous]
#
#                                                        1  \
# 0      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 1             The branch bark is apparently 1.5% approx.
# 2      Fruits flat, reddish-brown, remaining on the t...
# 3                   Flower-heads abundant golden yellow.
# 4      Inflorescence large, terminal, much-branched, ...
# ...                                                  ...
# 11077                                   Fruits close up.
# 11078                     Capi Nature Row Egg Antraciet.
# 11079                     Fruit on ground below Foxtail.
# 11080  Washingtonia robusta Agave americana Scroll to...
# 11081                                   Fruits close up.
#
#                                                        2  \
# 0             The branch bark is apparently 1.5% approx.
# 1      Pinnae sometimes 20 or more pairs, with 50 or ...
# 2                                 Fruit flat, dehiscent.
# 3                                 Fruit flat, dehiscent.
# 4      Stipules spinescent, stout, brown, glossy, com...
# ...                                                  ...
# 11077                     Fruit on ground below Foxtail.
# 11078         Leaf scars are regular and closely spaced.
# 11079               Foxtail Palm Tree: Large Multi Stem.
# 11080           Leaflets are thin and about a foot long.
# 11081                                    Nous contacter.
#
#                                                        3  \
# 0                   Perennial, Not climbing, Shrub/Tree.
# 1      Inflorescence large, terminal, much-branched, ...
# 2                 Young plants 6-8 months old from seed.
# 3                 Young plants 6-8 months old from seed.
# 4      Flowers orange or yellow, strongly and sweetly...
# ...                                                  ...
# 11077                         Foxtail Palm Tree: Medium.
# 11078  Leaves are very plumose with leaflets coming o...
# 11079          Immature green fruit of the Foxtail Palm.
# 11080                                   Fruits close up.
# 11081                     Capi Nature Row Egg Antraciet.
#
#                                                        4  \
# 0                   Flower-heads abundant golden yellow.
# 1      Acacia confusa - Stem Smaller peaks suspected ...
# 2      Shrub or tree to 7 m. Thorns in pairs at nodes...
# 3                   Perennial, Not climbing, Shrub/Tree.
# 4                   Flower-heads abundant golden yellow.
# ...                                                  ...
# 11077                            Fruits : 2 inches long.
# 11078  The crownshaft of the foxtail palm is light to...
# 11079                    Fruit showing remains of style.
# 11080  Fruits are 2 inches long, egg shaped, and oran...
# 11081  Monoecious, male and female flowers occur on s...
#
#                                                        5
# 0      Inflorescence large, terminal, much-branched, ...
# 1                   Flower-heads abundant golden yellow.
# 2                   Flower-heads abundant golden yellow.
# 3      Fruits flat, reddish-brown, remaining on the t...
# 4      Acacia confusa - Stem Smaller peaks suspected ...
# ...                                                  ...
# 11077  Fruits are 2 inches long, egg shaped, and oran...
# 11078                                    Nous contacter.
# 11079                          Foxtail Palm Tree: Small.
# 11080            The fruits grow plentiful on the stalk.
# 11081                     Popular, Tropical, Bi Pinnate.
#
# [11082 rows x 9 columns]

# %%
df_google_subset = df_google\
                    .dropna()\
                    .sample(n=20, axis=0, random_state=333)\

df_google_subset
# Out:
#                           Species                Main Trait  \
# 273           Chamaedorea allenii                Fruit Size
# 101           Astrocaryum vulgare           Conspicuousness
# 647             Dypsis tenuissima           Conspicuousness
# 430            Cyrtostachys renda               Fruit Shape
# 1437           Voanioala gerardii                Fruit Size
# 517              Dypsis catatiana              Fruit Colour
# 224           Basselinia pancheri                     Crown
# 946            Mauritiella armata               Fruit Shape
# 708               Geonoma deversa  Fruit Colour Description
# 346        Chamaedorea pauciflora               Fruit Shape
# 1117  Plectocomiopsis geminiflora              Fruit Colour
# 1358             Syagrus oleracea                     Crown
# 688            Geonoma baculifera               Fruit Shape
# 148              Bactris dianeura               Fruit Shape
# 577          Dypsis mananjarensis              Fruit Colour
# 565              Dypsis lutescens              Fruit Colour
# 1130      Pseudophoenix lediniana                     Crown
# 648               Dypsis thiryana  Fruit Colour Description
# 303   Chamaedorea ernesti-augusti                Fruit Size
# 1181            Ravenea musicalis           Conspicuousness
#
#                  GT Main Trait      GT Sub Traits  \
# 273                 Fruit Size            [small]
# 101            Conspicuousness      [conspicuous]
# 647            Conspicuousness          [cryptic]
# 430                Fruit Shape            [ovoid]
# 1437                Fruit Size            [large]
# 517               Fruit Colour              [red]
# 224                      Crown           [canopy]
# 946                Fruit Shape          [globose]
# 708   Fruit Colour Description  [black, purplish]
# 346                Fruit Shape            [ovoid]
# 1117              Fruit Colour            [brown]
# 1358                     Crown           [canopy]
# 688                Fruit Shape          [globose]
# 148                Fruit Shape          [globose]
# 577               Fruit Colour           [yellow]
# 565               Fruit Colour           [yellow]
# 1130                     Crown           [canopy]
# 648   Fruit Colour Description              [red]
# 303                 Fruit Size            [small]
# 1181           Conspicuousness      [conspicuous]
#
#                                                       1  \
# 273                            Subshrub, Solitary palm.
# 101   The trunk is heavily spined and even the inflo...
# 647   Infloresence interfoliar, unbranched, pistilla...
# 430   Some specimens were spectacular, while some we...
# 1437      Voanioala can reach up to 5 meters in height.
# 517           Entire bifid or pinnately divided leaves.
# 224                       Crownshaft and flower spathe.
# 946   Mauritiella is a dioecious genus of flowering ...
# 708                             Shrub, Caespitose palm.
# 346   Flowers sessile or partly enclosed in a cavity...
# 1117  Clustering, moderate to robust rattan with ste...
# 1358  When the vigorous seeds stain slowly, they pre...
# 688                               Shrub, Solitary palm.
# 148   Stems generally bear spines on the internodes,...
# 577            Plants are mostly upright in appearance.
# 565   Flowers are both male and female and after the...
# 1130  Small tree, four to six metres tall, with pinn...
# 648   It is about 40cms tall and is more glossy gree...
# 303                  Rare Red Hibiscus Flower 20 Seeds.
# 1181                                      Groundcovers.
#
#                                                       2  \
# 273   Small, sometimes moderate, erect or procumbent...
# 101   The seed is covered externally with an orange ...
# 647                   Clustering palm in groups of 2-6.
# 430   Solitary or clustered, moderate to tall, unarm...
# 1437   Solitary, unarmed, pleonanthic monoecious palms.
# 517                       Solitary small or dwarf palm.
# 224              Crownshaft detail, with inflorescence.
# 946      This is round to ellipsoidal, located basally.
# 708   Definitie: An autotroph which is capable of tr...
# 346   Stem usually slender, covered wholly or partia...
# 1117  The stems are small, densely clustering, spiny...
# 1358  The plumule of the embryonic axis is different...
# 688   Seed Â± globose, hilum short, basal, raphe enc...
# 148   Most species are small trees about 2 m tall, b...
# 577   Tall, to 25m, solitary, tristichous palm, with...
# 565   Dypsis lutescens leaflets with yellow leaf rac...
# 1130                                    Painfully slow.
# 648         It has bifurcated , hard to tell from pics.
# 303    The stem is slender and looks a bit like bamboo.
# 1181  Staminate inflorescences occur in multiples of...
#
#                                                       3  \
# 273   Seed erect, globose, or ellipsoidal, hilum sma...
# 101   The trunk and stem parts have large black spin...
# 647   Definitie: An autotroph which is capable of tr...
# 430   The seed is brownish in color with an oval non...
# 1437            It is a rediculously slow growing palm.
# 517                   Solitary dwarf palm, to 1 m tall.
# 224   Almost entire, stffly erect leaves, with very ...
# 946   Female plant with two inflorescences and one f...
# 708   Small to moderate, solitary or clustered, unar...
# 346                      Herb, Subshrub, Solitary palm.
# 1117  Female flowers are usually borne in clusters o...
# 1358  The fruit are drupes, which vary in colour fro...
# 688   Small to moderate, solitary or clustered, unar...
# 148   Flowers grow in triplets along the inflorescen...
# 577   Definitie: An autotroph which is capable of tr...
# 565                              Pale-yellow in Summer.
# 1130  Â  Like the waxy whiteÂ trunk the way it shows...
# 648                    Clustering palm in tufts of 2-4.
# 303                          Flower of Hawaii 15 Seeds.
# 1181  Fourteen to 16 pinnate fronds emerge from the ...
#
#                                                       4  \
# 273   Fruit small, globose or oblong, stigmatic rema...
# 101   The spadices are held erect, and the inner spa...
# 647                Definition: whole plant arborescent.
# 430   Si riproduce per divisione e per seme, che man...
# 1437  V. gerondii is polypoid and has a chromosome c...
# 517   A small, solitary palm, to about 1.5m tall, wi...
# 224   Small to stout, solitary or clustered, unarmed...
# 946                 Definition: whole plant herbaceous.
# 708   Fruit Â±globose, sometimes somewhat pointed, g...
# 346   A small, understory palm, with entire, deeply ...
# 1117  The seed is basally attached, spherical, usual...
# 1358  They are monoecious , with both male and femal...
# 688   Geonoma baculifera differs from its two relati...
# 148   Spines deep blackish-brown,.those on basal par...
# 577       Today the tips of the leaves reach about 6ft.
# 565   Most frequent element in an array, return lowe...
# 1130  Trees in this genus are medium to large palms ...
# 648   The from is extremely thin, almost less than a...
# 303   Small, solitary palm, leaves simple, two-lobed...
# 1181  They are small to large, dioecious palms, with...
#
#                                                       5
# 273   Flowers sessile or partly enclosed in a cavity...
# 101   The trunk and stem parts, have large black spi...
# 647                                       Groundcovers.
# 430   Stems erect, bare, conspicuously ringed with l...
# 1437  The flower bearing branches are numerous and b...
# 517                                              Clear.
# 224   Characteristic small to moderate pinnate-leave...
# 946   The leaves are fairly stiff and deeply split, ...
# 708   Seed Â± globose, hilum short, basal, raphe enc...
# 346   Some features of floral anatomy, including vas...
# 1117  The calyx is also thick and leathery, thrice l...
# 1358  The stems are normally spineless, but some spe...
# 688   Definitie: An autotroph which is capable of tr...
# 148   Sparingly colonial palm, rare in dense primary...
# 577                 Definitie: whole plant growth form.
# 565      It bears panicles of yellow flowers in summer.
# 1130                       P. lediniana trunk close-up.
# 648                   Clustering palm, in tufts of 2-4.
# 303                                   Valider mon avis.
# 1181  The trunk is relatively short and is swollen, ...

# %% [markdown]
# ### Add Images

# %%
random_sample_species = df_google_subset['Species'].values

images_links = {}
for species in tqdm(random_sample_species):
    species_ = species.replace(' ', '_')
    try:
        img_url = get_wiki_main_image(species_)
        if img_url[-3:] != 'jpg':
            img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        # if img_url[-3:].isupper():
        #     img_url = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'
        images_links[species] = img_url
    except:
        images_links[species] = 'https://upload.wikimedia.org/wikipedia/commons/1/14/No_Image_Available.jpg'

# df_google_subset = df_google[df_google['Species'].isin(random_sample_species)]
df_google_subset = df_google_subset.set_index('Species')
df_google_subset["URL"] = pd.Series(images_links)
df_google_subset.to_csv(f'{root}top_sents_all_AllSentencesAgainstTrait_Random20Subset.csv', sep='\t')#, quoting=csv.QUOTE_ALL)
# Out:
# 100%|██████████| 20/20 [00:03<00:00,  5.69it/s]

# %%
df_google_subset
# Out:
#                                            Main Trait  \
# Species
# Chamaedorea allenii                        Fruit Size
# Astrocaryum vulgare                   Conspicuousness
# Dypsis tenuissima                     Conspicuousness
# Cyrtostachys renda                        Fruit Shape
# Voanioala gerardii                         Fruit Size
# Dypsis catatiana                         Fruit Colour
# Basselinia pancheri                             Crown
# Mauritiella armata                        Fruit Shape
# Geonoma deversa              Fruit Colour Description
# Chamaedorea pauciflora                    Fruit Shape
# Plectocomiopsis geminiflora              Fruit Colour
# Syagrus oleracea                                Crown
# Geonoma baculifera                        Fruit Shape
# Bactris dianeura                          Fruit Shape
# Dypsis mananjarensis                     Fruit Colour
# Dypsis lutescens                         Fruit Colour
# Pseudophoenix lediniana                         Crown
# Dypsis thiryana              Fruit Colour Description
# Chamaedorea ernesti-augusti                Fruit Size
# Ravenea musicalis                     Conspicuousness
#
#                                         GT Main Trait      GT Sub Traits  \
# Species
# Chamaedorea allenii                        Fruit Size            [small]
# Astrocaryum vulgare                   Conspicuousness      [conspicuous]
# Dypsis tenuissima                     Conspicuousness          [cryptic]
# Cyrtostachys renda                        Fruit Shape            [ovoid]
# Voanioala gerardii                         Fruit Size            [large]
# Dypsis catatiana                         Fruit Colour              [red]
# Basselinia pancheri                             Crown           [canopy]
# Mauritiella armata                        Fruit Shape          [globose]
# Geonoma deversa              Fruit Colour Description  [black, purplish]
# Chamaedorea pauciflora                    Fruit Shape            [ovoid]
# Plectocomiopsis geminiflora              Fruit Colour            [brown]
# Syagrus oleracea                                Crown           [canopy]
# Geonoma baculifera                        Fruit Shape          [globose]
# Bactris dianeura                          Fruit Shape          [globose]
# Dypsis mananjarensis                     Fruit Colour           [yellow]
# Dypsis lutescens                         Fruit Colour           [yellow]
# Pseudophoenix lediniana                         Crown           [canopy]
# Dypsis thiryana              Fruit Colour Description              [red]
# Chamaedorea ernesti-augusti                Fruit Size            [small]
# Ravenea musicalis                     Conspicuousness      [conspicuous]
#
#                                                                              1  \
# Species
# Chamaedorea allenii                                   Subshrub, Solitary palm.
# Astrocaryum vulgare          The trunk is heavily spined and even the inflo...
# Dypsis tenuissima            Infloresence interfoliar, unbranched, pistilla...
# Cyrtostachys renda           Some specimens were spectacular, while some we...
# Voanioala gerardii               Voanioala can reach up to 5 meters in height.
# Dypsis catatiana                     Entire bifid or pinnately divided leaves.
# Basselinia pancheri                              Crownshaft and flower spathe.
# Mauritiella armata           Mauritiella is a dioecious genus of flowering ...
# Geonoma deversa                                        Shrub, Caespitose palm.
# Chamaedorea pauciflora       Flowers sessile or partly enclosed in a cavity...
# Plectocomiopsis geminiflora  Clustering, moderate to robust rattan with ste...
# Syagrus oleracea             When the vigorous seeds stain slowly, they pre...
# Geonoma baculifera                                       Shrub, Solitary palm.
# Bactris dianeura             Stems generally bear spines on the internodes,...
# Dypsis mananjarensis                  Plants are mostly upright in appearance.
# Dypsis lutescens             Flowers are both male and female and after the...
# Pseudophoenix lediniana      Small tree, four to six metres tall, with pinn...
# Dypsis thiryana              It is about 40cms tall and is more glossy gree...
# Chamaedorea ernesti-augusti                 Rare Red Hibiscus Flower 20 Seeds.
# Ravenea musicalis                                                Groundcovers.
#
#                                                                              2  \
# Species
# Chamaedorea allenii          Small, sometimes moderate, erect or procumbent...
# Astrocaryum vulgare          The seed is covered externally with an orange ...
# Dypsis tenuissima                            Clustering palm in groups of 2-6.
# Cyrtostachys renda           Solitary or clustered, moderate to tall, unarm...
# Voanioala gerardii            Solitary, unarmed, pleonanthic monoecious palms.
# Dypsis catatiana                                 Solitary small or dwarf palm.
# Basselinia pancheri                     Crownshaft detail, with inflorescence.
# Mauritiella armata              This is round to ellipsoidal, located basally.
# Geonoma deversa              Definitie: An autotroph which is capable of tr...
# Chamaedorea pauciflora       Stem usually slender, covered wholly or partia...
# Plectocomiopsis geminiflora  The stems are small, densely clustering, spiny...
# Syagrus oleracea             The plumule of the embryonic axis is different...
# Geonoma baculifera           Seed Â± globose, hilum short, basal, raphe enc...
# Bactris dianeura             Most species are small trees about 2 m tall, b...
# Dypsis mananjarensis         Tall, to 25m, solitary, tristichous palm, with...
# Dypsis lutescens             Dypsis lutescens leaflets with yellow leaf rac...
# Pseudophoenix lediniana                                        Painfully slow.
# Dypsis thiryana                    It has bifurcated , hard to tell from pics.
# Chamaedorea ernesti-augusti   The stem is slender and looks a bit like bamboo.
# Ravenea musicalis            Staminate inflorescences occur in multiples of...
#
#                                                                              3  \
# Species
# Chamaedorea allenii          Seed erect, globose, or ellipsoidal, hilum sma...
# Astrocaryum vulgare          The trunk and stem parts have large black spin...
# Dypsis tenuissima            Definitie: An autotroph which is capable of tr...
# Cyrtostachys renda           The seed is brownish in color with an oval non...
# Voanioala gerardii                     It is a rediculously slow growing palm.
# Dypsis catatiana                             Solitary dwarf palm, to 1 m tall.
# Basselinia pancheri          Almost entire, stffly erect leaves, with very ...
# Mauritiella armata           Female plant with two inflorescences and one f...
# Geonoma deversa              Small to moderate, solitary or clustered, unar...
# Chamaedorea pauciflora                          Herb, Subshrub, Solitary palm.
# Plectocomiopsis geminiflora  Female flowers are usually borne in clusters o...
# Syagrus oleracea             The fruit are drupes, which vary in colour fro...
# Geonoma baculifera           Small to moderate, solitary or clustered, unar...
# Bactris dianeura             Flowers grow in triplets along the inflorescen...
# Dypsis mananjarensis         Definitie: An autotroph which is capable of tr...
# Dypsis lutescens                                        Pale-yellow in Summer.
# Pseudophoenix lediniana      Â  Like the waxy whiteÂ trunk the way it shows...
# Dypsis thiryana                               Clustering palm in tufts of 2-4.
# Chamaedorea ernesti-augusti                         Flower of Hawaii 15 Seeds.
# Ravenea musicalis            Fourteen to 16 pinnate fronds emerge from the ...
#
#                                                                              4  \
# Species
# Chamaedorea allenii          Fruit small, globose or oblong, stigmatic rema...
# Astrocaryum vulgare          The spadices are held erect, and the inner spa...
# Dypsis tenuissima                         Definition: whole plant arborescent.
# Cyrtostachys renda           Si riproduce per divisione e per seme, che man...
# Voanioala gerardii           V. gerondii is polypoid and has a chromosome c...
# Dypsis catatiana             A small, solitary palm, to about 1.5m tall, wi...
# Basselinia pancheri          Small to stout, solitary or clustered, unarmed...
# Mauritiella armata                         Definition: whole plant herbaceous.
# Geonoma deversa              Fruit Â±globose, sometimes somewhat pointed, g...
# Chamaedorea pauciflora       A small, understory palm, with entire, deeply ...
# Plectocomiopsis geminiflora  The seed is basally attached, spherical, usual...
# Syagrus oleracea             They are monoecious , with both male and femal...
# Geonoma baculifera           Geonoma baculifera differs from its two relati...
# Bactris dianeura             Spines deep blackish-brown,.those on basal par...
# Dypsis mananjarensis             Today the tips of the leaves reach about 6ft.
# Dypsis lutescens             Most frequent element in an array, return lowe...
# Pseudophoenix lediniana      Trees in this genus are medium to large palms ...
# Dypsis thiryana              The from is extremely thin, almost less than a...
# Chamaedorea ernesti-augusti  Small, solitary palm, leaves simple, two-lobed...
# Ravenea musicalis            They are small to large, dioecious palms, with...
#
#                                                                              5  \
# Species
# Chamaedorea allenii          Flowers sessile or partly enclosed in a cavity...
# Astrocaryum vulgare          The trunk and stem parts, have large black spi...
# Dypsis tenuissima                                                Groundcovers.
# Cyrtostachys renda           Stems erect, bare, conspicuously ringed with l...
# Voanioala gerardii           The flower bearing branches are numerous and b...
# Dypsis catatiana                                                        Clear.
# Basselinia pancheri          Characteristic small to moderate pinnate-leave...
# Mauritiella armata           The leaves are fairly stiff and deeply split, ...
# Geonoma deversa              Seed Â± globose, hilum short, basal, raphe enc...
# Chamaedorea pauciflora       Some features of floral anatomy, including vas...
# Plectocomiopsis geminiflora  The calyx is also thick and leathery, thrice l...
# Syagrus oleracea             The stems are normally spineless, but some spe...
# Geonoma baculifera           Definitie: An autotroph which is capable of tr...
# Bactris dianeura             Sparingly colonial palm, rare in dense primary...
# Dypsis mananjarensis                       Definitie: whole plant growth form.
# Dypsis lutescens                It bears panicles of yellow flowers in summer.
# Pseudophoenix lediniana                           P. lediniana trunk close-up.
# Dypsis thiryana                              Clustering palm, in tufts of 2-4.
# Chamaedorea ernesti-augusti                                  Valider mon avis.
# Ravenea musicalis            The trunk is relatively short and is swollen, ...
#
#                                                                            URL
# Species
# Chamaedorea allenii          https://upload.wikimedia.org/wikipedia/commons...
# Astrocaryum vulgare          https://upload.wikimedia.org/wikipedia/commons...
# Dypsis tenuissima            https://upload.wikimedia.org/wikipedia/commons...
# Cyrtostachys renda           https://upload.wikimedia.org/wikipedia/commons...
# Voanioala gerardii           https://upload.wikimedia.org/wikipedia/commons...
# Dypsis catatiana             https://upload.wikimedia.org/wikipedia/commons...
# Basselinia pancheri          https://upload.wikimedia.org/wikipedia/commons...
# Mauritiella armata           https://upload.wikimedia.org/wikipedia/commons...
# Geonoma deversa              https://upload.wikimedia.org/wikipedia/commons...
# Chamaedorea pauciflora       https://upload.wikimedia.org/wikipedia/commons...
# Plectocomiopsis geminiflora  https://upload.wikimedia.org/wikipedia/commons...
# Syagrus oleracea             https://upload.wikimedia.org/wikipedia/commons...
# Geonoma baculifera           https://upload.wikimedia.org/wikipedia/commons...
# Bactris dianeura             https://upload.wikimedia.org/wikipedia/commons...
# Dypsis mananjarensis         https://upload.wikimedia.org/wikipedia/commons...
# Dypsis lutescens             https://upload.wikimedia.org/wikipedia/commons...
# Pseudophoenix lediniana      https://upload.wikimedia.org/wikipedia/commons...
# Dypsis thiryana              https://upload.wikimedia.org/wikipedia/commons...
# Chamaedorea ernesti-augusti  https://upload.wikimedia.org/wikipedia/commons...
# Ravenea musicalis            https://upload.wikimedia.org/wikipedia/commons...
