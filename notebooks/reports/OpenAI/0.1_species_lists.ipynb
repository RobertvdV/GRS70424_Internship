# %%
import pandas as pd
import pickle

# %%
root = "../../../data/OpenAI/DataFrames/"

file = "DF_Andrei.csv"
df_Andrei = pd.read_csv(F"{root}{file}", header=[0, 1], index_col=0)\
    .rename_axis('Species', axis='index')

file = "DF_Daniel.csv"
df_Daniel = pd.read_csv(F"{root}{file}", header=[0, 1], index_col=0)\
    .rename_axis('Species', axis='index')\
    .dropna()

file = "DF_Pierre.csv"
df_Pierre = pd.read_csv(F"{root}{file}", header=[0, 1], index_col=0)\
    .rename_axis('Species', axis='index')

# %%
df_Daniel
# Out:
#                            Fruit Colour Description                    \
#                                               black blue bluish brown
# Species
# Actinokentia divaricata                           0    0      0     0
# Aiphanes minima                                   0    0      0     0
# Archontophoenix alexandrae                        0    0      0     0
# Archontophoenix maxima                            0    0      0     0
# Archontophoenix myolensis                         0    0      0     0
# ...                                             ...  ...    ...   ...
# Wettinia kalbreyeri                               0    0      0     0
# Wettinia maynensis                                0    0      0     1
# Wettinia oxycarpa                                 0    0      0     1
# Wettinia quinaria                                 0    0      0     1
# Wodyetia bifurcata                                0    0      0     0
#
#                                                                              \
#                            brownish chocolate coral crimson darkgreen green
# Species
# Actinokentia divaricata           0         0     0       0         0     0
# Aiphanes minima                   0         0     0       0         0     0
# Archontophoenix alexandrae        0         0     0       0         0     0
# Archontophoenix maxima            0         0     0       0         0     0
# Archontophoenix myolensis         0         0     0       0         0     0
# ...                             ...       ...   ...     ...       ...   ...
# Wettinia kalbreyeri               0         0     0       0         0     1
# Wettinia maynensis                0         0     0       0         0     0
# Wettinia oxycarpa                 0         0     0       0         0     0
# Wettinia quinaria                 0         0     0       0         0     1
# Wodyetia bifurcata                0         0     0       0         0     0
#
#                             ...         Measurement  \
#                             ... Maximum Leaf Number
# Species                     ...
# Actinokentia divaricata     ...                 7.0
# Aiphanes minima             ...                 9.0
# Archontophoenix alexandrae  ...                12.0
# Archontophoenix maxima      ...                11.0
# Archontophoenix myolensis   ...                12.0
# ...                         ...                 ...
# Wettinia kalbreyeri         ...                 5.0
# Wettinia maynensis          ...                10.0
# Wettinia oxycarpa           ...                 6.0
# Wettinia quinaria           ...                 6.0
# Wodyetia bifurcata          ...                10.0
#
#                                                                 \
#                            Maximum Leaf Blade Length in Meters
# Species
# Actinokentia divaricata                                   2.35
# Aiphanes minima                                           4.20
# Archontophoenix alexandrae                                4.50
# Archontophoenix maxima                                    5.00
# Archontophoenix myolensis                                 4.00
# ...                                                        ...
# Wettinia kalbreyeri                                       5.00
# Wettinia maynensis                                        5.00
# Wettinia oxycarpa                                         6.00
# Wettinia quinaria                                         5.50
# Wodyetia bifurcata                                        3.20
#
#                                                             \
#                            Maximum Rachis Length in Meters
# Species
# Actinokentia divaricata                                2.1
# Aiphanes minima                                        3.0
# Archontophoenix alexandrae                             4.0
# Archontophoenix maxima                                 3.4
# Archontophoenix myolensis                              3.8
# ...                                                    ...
# Wettinia kalbreyeri                                    2.9
# Wettinia maynensis                                     4.5
# Wettinia oxycarpa                                      3.3
# Wettinia quinaria                                      3.2
# Wodyetia bifurcata                                     2.3
#
#                                                              \
#                            Maximum Petiole Length in Meters
# Species
# Actinokentia divaricata                                1.30
# Aiphanes minima                                        1.25
# Archontophoenix alexandrae                             0.55
# Archontophoenix maxima                                 1.70
# Archontophoenix myolensis                              0.22
# ...                                                     ...
# Wettinia kalbreyeri                                    2.20
# Wettinia maynensis                                     0.55
# Wettinia oxycarpa                                      2.80
# Wettinia quinaria                                      1.35
# Wodyetia bifurcata                                     1.02
#
#                                                                 \
#                            Average Fruit Length in Centimeters
# Species
# Actinokentia divaricata                                   2.60
# Aiphanes minima                                           1.40
# Archontophoenix alexandrae                                1.10
# Archontophoenix maxima                                    1.25
# Archontophoenix myolensis                                 1.70
# ...                                                        ...
# Wettinia kalbreyeri                                       2.95
# Wettinia maynensis                                        2.15
# Wettinia oxycarpa                                         3.50
# Wettinia quinaria                                         2.75
# Wodyetia bifurcata                                        5.75
#
#                                                                 \
#                            Minimum Fruit Length in Centimeters
# Species
# Actinokentia divaricata                                    1.8
# Aiphanes minima                                            1.2
# Archontophoenix alexandrae                                 0.8
# Archontophoenix maxima                                     1.1
# Archontophoenix myolensis                                  1.3
# ...                                                        ...
# Wettinia kalbreyeri                                        2.4
# Wettinia maynensis                                         1.8
# Wettinia oxycarpa                                          2.5
# Wettinia quinaria                                          2.0
# Wodyetia bifurcata                                         5.0
#
#                                                                 \
#                            Maximum Fruit Length in Centimeters
# Species
# Actinokentia divaricata                                    3.4
# Aiphanes minima                                            1.6
# Archontophoenix alexandrae                                 1.4
# Archontophoenix maxima                                     1.4
# Archontophoenix myolensis                                  2.1
# ...                                                        ...
# Wettinia kalbreyeri                                        3.5
# Wettinia maynensis                                         3.5
# Wettinia oxycarpa                                          3.5
# Wettinia quinaria                                          3.5
# Wodyetia bifurcata                                         6.5
#
#                                                                \
#                            Average Fruit Width in Centimeters
# Species
# Actinokentia divaricata                                  1.10
# Aiphanes minima                                          1.55
# Archontophoenix alexandrae                               0.85
# Archontophoenix maxima                                   0.90
# Archontophoenix myolensis                                1.10
# ...                                                       ...
# Wettinia kalbreyeri                                      5.00
# Wettinia maynensis                                       1.75
# Wettinia oxycarpa                                        3.50
# Wettinia quinaria                                        2.00
# Wodyetia bifurcata                                       4.35
#
#                                                                \
#                            Minimum Fruit Width in Centimeters
# Species
# Actinokentia divaricata                                   0.8
# Aiphanes minima                                           1.4
# Archontophoenix alexandrae                                0.6
# Archontophoenix maxima                                    0.7
# Archontophoenix myolensis                                 1.0
# ...                                                       ...
# Wettinia kalbreyeri                                       2.0
# Wettinia maynensis                                        1.5
# Wettinia oxycarpa                                         1.5
# Wettinia quinaria                                         1.5
# Wodyetia bifurcata                                        2.7
#
#
#                            Maximum Fruit Width in Centimeters
# Species
# Actinokentia divaricata                                   1.4
# Aiphanes minima                                           1.7
# Archontophoenix alexandrae                                1.1
# Archontophoenix maxima                                    1.1
# Archontophoenix myolensis                                 1.2
# ...                                                       ...
# Wettinia kalbreyeri                                       3.0
# Wettinia maynensis                                        2.0
# Wettinia oxycarpa                                         2.0
# Wettinia quinaria                                         2.5
# Wodyetia bifurcata                                        6.0
#
# [333 rows x 69 columns]

# %%
folder = "../../../data/OpenAI/Species/"



for (df, name) in zip(
    [df_Andrei, df_Daniel, df_Pierre],
    ["caribbean_species", "palm_species", "plantnet_species"]):

    species = list(df.index)

    with open(F"{folder}{name}.pkl", 'wb') as f:
        pickle.dump(species, f)
